# %% [markdown]
# # RTED-TDS Co-Sim
#
# Authored by [Jinning Wang](https://scholar.google.com/citations?user=Wr7nQZAAAAAJ&hl=en&oi=ao), recently updated on 06/06/2022.
#
# This notebook is used to implement the Co-Simulation of Real Time Economic Dispatch (RTED) and Time-Domain Simulation (TDS).
# In the RTED, SFR is considered. In the TDS, AGC is implemented with an equation defined PI controller.
#
# RTED is seperated into two DCOPF and ACOPF: 1) DCOPF with SFR is solved in gurobipy, which is packaged into the class ``rted`` in the file ``rted.py``. 2) ACOPF is solved in pandapower.
#
# Class ``rted2`` has attributes ``mdl`` which is a gurobipy model.
#
# Table of contents:
# - Import case: import ADNES case
# - Load synthetic: build load curve as a scalar
# - Setup ``ssp`` and ``ssd``
# - Prepare: define some functions
# - Define param: define RTED loop parameters
# - Loop: Co-Sim loop
#
# List of major vars:
#
# - ``ssa`` ANDES system
# - ``ssp`` pandapower net
# - ``ssd`` DCOPF instance
# - ``sse`` EV aggregator
#
# Things need to be done when switching to other cases:
# - Assign generator cost data. The rows of gen_cost array should be the same with the length of ``ssp.gen``
#   including those uncontrollable ones, so the DCOPF model can build correctly.
# - Define generator controllability of ``ssp``, all generators are controllable by default
# - Define power system data: SFR cost, ramp limit (5-min-based)
# - Define generator type in ``ssd``, default as type I. For type I generator, generator limtis have impact on both generation and SFR capacity. For yype II generator, SFR capacity is determined by param ``pru_max`` and ``prd_max``
#
# Environment requirements:
# - ANDES (1.6.3+)
# - pandapower (2.7.0 is tested to be function correctly)
# - gurobipy
# - pandas, matplotlib, scipy

# %% [markdown]
# ## Import case

# %%
import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stat
from math import floor

import andes
from andes.interop.pandapower import to_pandapower, make_link_table, runopp_map
from andes.interop.pandapower import add_gencost, build_group_table
andes.config_logger(stream_level=20)

import pandapower as pp

from jams import rted2

from ev_ssm import ev_ssm

# %% [markdown]
# Package version

# %%
print(andes.__version__)
print(pp.__version__)
# Out:
# 1.7.2.post266.dev0+g9c2e267c
# 2.8.0

# %% [markdown]
# EV aggregator
#
# `caseH` is the start time [H] of the co-simulation, now 10 and 18 are supported.

# %%
caseH = 10
sse = ev_ssm(ts=caseH, N=10000, step=1, tp=40,
             lr=0.1, lp=40, seed=2022, name="EVA")
sse.load_A("Aest.csv")
# Out:
# EVA: ts=10[H], 10000 EVs, Total Q=250.12 MWh
# Online 1983, Q=49.73 MWh, SoC=0.9834
# Power(MW): Pt=-0.3613, Pc=-0.3613, Pd=-0.0
# Ctrl: 0=1921; 1=62;
# EVA: Load A from Aest.csv.

# %% [markdown]
# Import ADNES case

# %%
# ss0 is used for PP conversion
dir_path = os.path.abspath('..')
case_path = '/case/ieee39_ev2.xlsx'
case = dir_path + case_path
ssa = andes.load(case,
                 setup=True,
                 no_output=True,
                 default_config=False)
# stg0idx = ssa.PV.idx.v + ssa.Slack.idx.v
# pm0 = ssa.StaticGen.get(src='pmax', attr='v', idx=stg0idx)
# ssa.StaticGen.set(src='pmax', attr='v', idx=stg0idx, value=2*pm0)
# Out:
# Working directory: "/Users/jinningwang/Documents/work/andes/jwang/notes2"
# > Loaded config from file "/Users/jinningwang/.andes/andes.rc"
# > Loaded generated Python code in "/Users/jinningwang/.andes/pycode".
# Generated code for <PQ> is stale.
# Numerical code generation (rapid incremental mode) started...
# Generating code for 1 models on 8 processes.
# Saved generated pycode to "/Users/jinningwang/.andes/pycode"
# > Reloaded generated Python code of module "pycode".
# Generated numerical code for 1 models in 0.1815 seconds.
# Parsing input file "/Users/jinningwang/Documents/work/andes/jwang/case/ieee39_ev2.xlsx"...
# Input file parsed in 0.0834 seconds.
# ACEc <1> added BusFreq <BusFreq_11> linked to bus <1>
# System internal structure set up in 0.0311 seconds.

# %% [markdown]
# Set output mode as 'manual', turn off TDS progress bar

# %%
ssa.TDS.config.save_mode = 'manual'
ssa.TDS.config.no_tqdm = 1

# %% [markdown]
# Set load as constant load.

# %%
ssa.PQ.config.p2p = 1
ssa.PQ.config.q2q = 1
ssa.PQ.config.p2z = 0
ssa.PQ.config.q2z = 0
ssa.PQ.pq2z = 0

# %% [markdown]
# Turn on ``numba`` can accelerate TDS.

# %%
ssa.config.numba
# Out:
# 1

# %% [markdown]
# ## Load synthetic
#
# Create load data ``d_syn``, which is a ``DataFrame`` that have three columns: ``time``, ``s10``, ``h10``. ``time`` is by seconds, ``s10`` is scalar load.

# %%
# --- read load from ssa ---
ptotal = ssa.PQ.as_df()['p0'].sum()
print('ANDES total load is:',ptotal.round(4),'p.u.')

# --- scale load curve ---
ddata_path = '/case/dsyn.csv'
ddata = dir_path + ddata_path
d_syn = pd.read_csv(ddata)

# the coefficient can be adjusted to fit the case
if caseH == 10:
    d_syn['sload'] = 0.8*(d_syn['ha10'] - d_syn['ha10'].min()) / d_syn['ha10'].min() + 0.8
if caseH == 18:
    d_syn['sload'] = 2*(d_syn['ha18'] - d_syn['ha18'].min()) / d_syn['ha18'].min() + 1

# extensify fluc
avg = d_syn['sload'].rolling(50).mean()
d_syn['sload'] = 2.5 * (d_syn['sload'] - avg) + avg
    
# calculate expected load
step = 300
d_exp = d_syn.groupby(d_syn.index // step).mean().copy()
d_exp['time'] = range(0,3600,300)

# align starting point of load with starting point of dispatch results
d_syn['sload'][0] = d_exp['sload'].iloc[0]
d_syn['sload'][1:100] = None
d_syn['sload'] = d_syn['sload'].interpolate(method='polynomial', order=3)

# --- plot load curve ---
fig_load, ax_load = plt.subplots(figsize=(5, 4))
ax_load.plot(d_syn['time'], d_syn['sload'], color='tab:blue', linestyle='-')
ystep = list(d_exp['sload'])
ystep.insert(0, d_exp['sload'].iloc[0])
ax_load.step(range(0,3900,300), ystep, color='tab:blue', linestyle='--')
ax_load.set_xlim([0, 3600])
ax_load.legend(['Actual load', 'Forecasted load'])
ax_load.set_title(f'Load profile at {caseH}H')
ax_load.set_ylabel('ratio')
ax_load.set_xlabel('Time [s]')
# Out:
# ANDES total load is: 58.564 p.u.
# Text(0.5, 0, 'Time [s]')

# %% [markdown]
# ## Setup ``ssp`` and ``ssd``
#
# Convert ``ssa`` to pandapower net ``ssp``, add generator cost
#
# The input cost array follow the matpower/pypower format, now only poly_cost is supported

# %%
# --- set up EV generator data ---
ev_idx = 'PV_10'
ssa.PV.set(src='p0', idx=ev_idx, attr='v', value=sse.Ptc)
ssa.PV.set(src='pmax', idx=ev_idx, attr='v', value=sse.Pu)
ssa.PV.set(src='pmin', idx=ev_idx, attr='v', value=sse.Pl)
# Out:
# True

# %%
# --- convert to a pandapower instance ---
ssp = to_pandapower(ssa)

# set EV generator as uncontrollable
ssp.gen.controllable.iloc[9] = False

# add gen cost, G1-11. G10 EV, G11 Slack
linearcost = [20.14, 20.20, 20.19, 20.20, 20.25, 20.21, 20.23, 20.22, 20.15, 0, 20.30]

gen_cost = np.array([[2., 0., 0., 3., 0., 0., 0.]] * ssp.gen.shape[0])
gen_cost[:, 5] = linearcost  # c1

add_gencost(ssp, gen_cost)
# Out:
# -> System connectivity check results:
#   No islanded bus detected.
#   System is interconnected.
#   Each island has a slack bus correctly defined and enabled.
#
# -> Power flow calculation
#            Numba: On
#    Sparse solver: KLU
#  Solution method: NR method
# Numba compilation initiated with caching.
# Power flow initialized in 0.1049 seconds.
# 0: |F(x)| = 7.561249598
# 1: |F(x)| = 2.917040377
# 2: |F(x)| = 0.1312974497
# 3: |F(x)| = 0.0003563766345
# 4: |F(x)| = 4.278702725e-09
# Converged in 5 iterations in 0.0072 seconds.
# Power flow results are consistent. Conversion is successful.
# True

# %% [markdown]
# Set RTED instance ``ssd``

# %%
ssd = rted2(name='RTED', OutputFlag=1)
ssd.from_andes(ssa)
ssd.build()

# set EV generator as uncontrollable
ssd.gen.ctrl.loc[ev_idx] = 0

# set EV geenrator as type2
prumax = sse.g_frc()[0]
prdmax = sse.g_frc()[1]
ssd.def_type2([ev_idx], [prumax], [prdmax])

# set ramp5
ramp_15 = [156, 120, 130, 110, 80, 105, 90, 90, 150, 999, 200]
# ramp_hour = [80, 80, 80, 50, 50, 50, 30, 30, 30, 999, 30]
ssd.gen['ramp_5'] = np.array(ramp_15) / 3 / ssd.mva

# set cost
ssd.cost['c1'] = linearcost

# adjust SFR cost of EV lower than SynGen
ssd.cost['cru'] = [0] * ssd.gen.shape[0]
ssd.cost['cru'].loc[ev_idx] = - 0.001
ssd.cost['crd'] = ssd.cost.cru
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-04-08
# -> System connectivity check results:
#   No islanded bus detected.
#   System is interconnected.
#   Each island has a slack bus correctly defined and enabled.
#
# -> Power flow calculation
#            Numba: On
#    Sparse solver: KLU
#  Solution method: NR method
# Numba compilation initiated with caching.
# Power flow initialized in 0.0076 seconds.
# 0: |F(x)| = 7.561249598
# 1: |F(x)| = 2.917040377
# 2: |F(x)| = 0.1312974497
# 3: |F(x)| = 0.0003563766345
# 4: |F(x)| = 4.278702725e-09
# Converged in 5 iterations in 0.0062 seconds.
# Power flow results are consistent. Conversion is successful.
# GSF is consistent.
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# RTED GB model is loaded.

# %% [markdown]
# Benchmark ``ssd`` with ``ssp`` using standard DCOPF

# %%
pp.rundcopp(ssp)
ppres = ssp.res_gen.copy()
gb_res = ssd.solve(disable_sfr=True, info=False)
ppres['p_mw(GB)'] = ssd.mva * gb_res['pg'].values
print(f"pp cost={ssp.res_cost}, gb cost={ssd.res_cost}")
ppres
# Out:
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# RTED removed Constrs: ['pgmax', 'pgmin', 'sfru', 'sfrd', 'rampu', 'rampd']
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 71 rows, 33 columns and 549 nonzeros
# Model fingerprint: 0x081a7df7
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+00]
#   Objective range  [2e-03, 2e+01]
#   Bounds range     [4e-01, 1e+01]
#   RHS range        [2e-02, 2e+03]
# Presolve removed 70 rows and 24 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 9 columns, 9 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.1887289e+03   1.154464e+01   0.000000e+00      0s
#        1    1.1898976e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.189897556e+03
# RTED: total cost=1189.898
# pp cost=119054.76476573595, gb cost=1189.897555994747
#           p_mw      q_mvar  va_degree  vm_pu     p_mw(GB)
# 0   527.463570   90.396306   5.014635    1.0  1040.000000
# 1   646.000000  310.969446   5.161051    1.0   646.000000
# 2   725.000000  148.831804   8.983376    1.0   725.000000
# 3   652.000000  129.688596   9.034017    1.0   652.000000
# 4   508.000000  145.052832   7.202725    1.0   200.000000
# 5   620.247329  225.130203  10.538482    1.0   687.000000
# 6   579.999997   60.485999  14.257179    1.0   232.000000
# 7   225.600002  -26.176825   2.269216    1.0   405.528532
# 8   865.000000  116.012450  12.929514    1.0   865.000000
# 9   -36.128532    0.000000  12.929514    1.0   -36.128532
# 10  543.217636  -30.622919   0.000000    1.0   440.000000

# %% [markdown]
# ## Prepare

# %% [markdown]
# ### Make link table

# %%
# --- link_table ---
ssa_key = make_link_table(ssa)

# --- add controllable in the link table ---
ssa_bus = ssa.Bus.as_df().reset_index().rename(columns={'uid':'bus_pp', 'idx':'bus_idx'})
ssp_gen = ssp.gen.reset_index().rename(columns={'index':'gen_pp', 'name':'stg_idx', 'controllable':'ctrl'})
ssa_key2 = pd.merge(left=ssa_key,
                    right=ssp_gen[['stg_idx', 'gen_pp', 'ctrl']],
                    on='stg_idx', how='left')

# --- device idx ---
ssa_dg_idx = ssa_key2.dg_idx.dropna().tolist()
ssa_syg_idx = ssa_key2.syg_idx.dropna().tolist()
ssa_gov_idx = ssa_key2.gov_idx.dropna().tolist()
ssa_stg_idx = ssa_key2.stg_idx.dropna().tolist()

# --- online and controllable device idx ---
ctrl_cond = ssa_key2.ctrl & ssa_key2.stg_u.astype(bool)
ssa_dg_idx_ctrl = ssa_key2.dg_idx[ctrl_cond].dropna().tolist()
ssa_syg_idx_ctrl = ssa_key2.syg_idx[ctrl_cond].dropna().tolist()
ssa_gov_idx_ctrl = ssa_key2.gov_idx[ctrl_cond].dropna().tolist()
ssa_stg_idx_ctrl = ssa_key2.stg_idx[ctrl_cond].dropna().tolist()

# fill NaN with False
ssa_key2.fillna(value=False, inplace=True)

ssa_key2
# Out:
#     stg_name  stg_u   stg_idx  bus_idx dg_idx  rg_idx    syg_idx    exc_idx  \
# 0       PV_1    1.0      PV_1       30  False   False   GENROU_1   IEEEX1_1
# 1       PV_2    1.0      PV_2       31  False   False   GENROU_2   IEEEX1_2
# 2       PV_3    1.0      PV_3       32  False   False   GENROU_3   IEEEX1_3
# 3       PV_4    1.0      PV_4       33  False   False   GENROU_4   IEEEX1_4
# 4       PV_5    1.0      PV_5       34  False   False   GENROU_5   IEEEX1_5
# 5       PV_6    1.0      PV_6       35  False   False   GENROU_6   IEEEX1_6
# 6       PV_7    1.0      PV_7       36  False   False   GENROU_7   IEEEX1_7
# 7       PV_8    1.0      PV_8       37  False   False   GENROU_8   IEEEX1_8
# 8       PV_9    1.0      PV_9       38  False   False   GENROU_9   IEEEX1_9
# 9   Slack_10    1.0  Slack_10       39  False   False  GENROU_10  IEEEX1_10
# 10     PV_10    1.0     PV_10       38   EV_1   False      False      False
#
#      gov_idx bus_name  gammap  gammaq  gen_pp   ctrl
# 0    TGOV1_1    GEN30     1.0     1.0       0   True
# 1    TGOV1_2    GEN31     1.0     1.0       1   True
# 2    TGOV1_3    GEN32     1.0     1.0       2   True
# 3    TGOV1_4    GEN33     1.0     1.0       3   True
# 4    TGOV1_5    GEN34     1.0     1.0       4   True
# 5    TGOV1_6    GEN35     1.0     1.0       5   True
# 6    TGOV1_7    GEN36     1.0     1.0       6   True
# 7    TGOV1_8    GEN37     1.0     1.0       7   True
# 8    TGOV1_9    GEN38     1.0     1.0       8   True
# 9   TGOV1_10    GEN39     1.0     1.0      10   True
# 10     False    GEN38     1.0     1.0       9  False

# %% [markdown]
# ### Define functions used in loop

# %%
# --- def. functions ---

def get_pe(ssa, gov_idx, dg_idx, ssa_key2):
    """Get the active power (TurbineGov/DG) after TDS, a DataFrame"""
    # TODO: may need to sum the power of same StaticGen
    # --- TurbineGov --- 
    pe_syg = ssa.TurbineGov.get(src='pout', idx=gov_idx, attr='v')
    # --- DG ---
    Ip_dg = ssa.DG.get(src='Ipout_y', idx=dg_idx, attr='v')
    v_dg = ssa.DG.get(src='v', idx=dg_idx, attr='v')
    pe_dg = Ip_dg*v_dg
    # --- out ---
    pe = pd.DataFrame()
    pe['idx'] = gov_idx + dg_idx
    pe['pe'] = np.concatenate((pe_syg, pe_dg))
    ldf = pd.merge(left=ssa_key2.rename(columns={'dg_idx':'idx'}),
         right=pe, how='right', on='idx')
    rdf = pd.merge(left=ssa_key2.rename(columns={'gov_idx':'idx'}),
             right=pe, how='right', on='idx')
    pe['stg_idx'] = ldf['stg_idx'].fillna('') + rdf['stg_idx'].fillna('')
    return pe

def dp_calc(d_syn, idx_ed, intv_ed, ratio=0.1):
    """Calc SFR requirements, scalars, ``dpd_u``and ``dpd_d``, and load forecasted value ``load_exp``"""
    load = d_syn['sload'].iloc[idx_ed*intv_ed:(idx_ed*intv_ed + intv_ed)]
    load_exp = load.mean()
    load_d = load_exp * ratio
    load_u = load_exp * ratio
    return load_u, load_d, load_exp

# %% [markdown]
# ## Define param

# %%
# --- co-sim constants ---

rru = 0.0   # RegUp rate of EV
rrd = 0     # RegDn rate of EV
rsfr = 0.05  # ratio of SFR reserve out of total load

t_total = 700    # total simulation time

# length of each interval
intv_ed = 300  # RTED interval, 300s
intv_agc = 4    # AGC interval, 4s
intv_pq = 1     # PQ interval, 1s; alter load and AGC
intv_step = 50 # step change interval; smooth the setpoitns

# number of each interval
n_ed = int(t_total/intv_ed)
n_agc = int(intv_ed/intv_agc)
n_pq = int(intv_agc/intv_pq)
n_step = floor(intv_step/intv_agc)

# --- vars ---
# AGC table
agc_table = ssa_key2[['stg_idx', 'dg_idx', 'rg_idx', 'syg_idx', 
                      'exc_idx', 'gov_idx', 'gammap', 'ctrl']]
dcres = ssd.res
agc_table = agc_table.merge(dcres[['gen', 'bu', 'bd']].rename(columns={'gen': 'stg_idx'}),
                            on='stg_idx', how='left')
agc_table['paux'] = 0

# AGC power of each unit
agc_in = pd.DataFrame(columns=['stg_idx'] + list(np.arange(0, t_total, 4)))
agc_in['stg_idx'] = agc_table['stg_idx']
agc_out = agc_in.copy()

# ACE vars for PI controller
ACE_integral = 0
ACE_raw = 0
Kp = 0.1 # 0.05
Ki = 0.1
# SFR boundary and total AGC input
sfr_res = pd.DataFrame(columns=['cat'] + list(np.arange(0, t_total, 4)))
sfr_res['cat'] = ['time', 'ace', 'up', 'dn', 'in']

# initial load value
ssa_p0 = ssa.PQ.p0.v.copy()
ssa_q0 = ssa.PQ.q0.v.copy()
ssa_pq_idx = ssa.PQ.idx.v
ssa_p0_sum = ssa_p0.sum()

# EV results
ev_soc = pd.DataFrame(columns=range(t_total))
ev_agc = pd.DataFrame(columns=range(t_total))
ev_soc[0] = sse.ev.soc
ev_agc[0] = sse.ev.agc

# idx
ssp_res = runopp_map(ssp, ssa_key)

cond_sch_gov = ssp_res.controllable & ssp_res.gov_idx.fillna(False).astype(bool)
cond_sch_dg = ssp_res.controllable & ssp_res.dg_idx.fillna(False).astype(bool)
cond_agc_gov = agc_table.ctrl * agc_table.gov_idx.fillna(False).astype(bool)
cond_agc_dg = agc_table.ctrl * agc_table.dg_idx.fillna(False).astype(bool)

sch_gov_idx = ssp_res.gov_idx[cond_sch_gov].tolist()
sch_dg_idx = ssp_res.dg_idx[cond_sch_dg].tolist()
agc_gov_idx = agc_table.gov_idx[cond_agc_gov].tolist()
agc_dg_idx = agc_table.dg_idx[cond_agc_dg].tolist()

# %% [markdown]
# ## Loop
#
# In the loop, there are mainly X parts:
#
# - interval RTED: run DCOPF (``ssd.mdl``), run ACOPF(``ssp``),
#
# - interval AGC: do AGC, do dispatch with smooth setpoints
#
# - interval PQ: alter load, run TDS(``ssa.TDS``)
#
# Notes:
#
# - The setpoints for DG are coded but not verified yet.
#
# - After the development of ANDES control room, the dispatch and AGC part can be refactored.
#
# - interface variables: ``DG.pmx``: DPV profile, ``DG.pref0``: setpoints, ``DG.pext0``: AGC
#
# - ACOPF in pandapower considered generator limtis of ramping and SFR reserve

# %% [markdown]
# Check convergence

# %%
# Reserve some capacity to avoid TDS crush
ssp.gen.max_p_mw = ssp.gen.max_p_mw

# store original generator data
ssp_gen0 = ssp.gen.copy()

for end_time in range(3600):  # t_total
    # --- interval RTED ---
    if end_time % intv_ed == 0:
        idx_ed = end_time // intv_ed
        # --- update load ---
        sfrur, sfrdr, load_exp = dp_calc(d_syn, idx_ed, intv_ed, rsfr)
        ssp.load['scaling'] = load_exp
        ssp.gen['p_mw'][ssp.gen.name==ev_idx] = sse.Ptc
        ssd.gen['p0'][ssd.gen.idx == ev_idx] = sse.Ptc
        ssd.load['sf'] = load_exp
        ssd.update_dict()

        # --- RTED, update gen limits after SFR ---
        # set previous setpoints with `pe` from TDS
        if end_time > 0:
            vl = pd.merge(left=ssd.gen, how='left', on='idx',
                          right=ssp_res[['stg_idx', 'p']].rename(columns={'stg_idx':'idx'}))['p']
            ssd.gen.p_pre = vl.values

        # def. SFR requirements and calc. EV SFR capacities
        [prumax, prdmax] = sse.g_frc()
        # def. percentage of EV SFR capacities
        ssd.def_type2([ev_idx], [prumax*rru], [prdmax*rrd])
        ssd.def_sfr(sfrur=sfrur*ssa_p0_sum, sfrdr=sfrdr*ssa_p0_sum)

        # solve RTED
        if end_time == 0:
            dcres = ssd.solve(disable_ramp=True)
        else:
            dcres = ssd.solve()

        # reserve SFR and ramp from Generator limits in ``ssp``
        ssp_gen = pd.merge(left=ssp.gen.rename(columns={'name': 'stg_idx'}),
                           right=dcres.rename(columns={'gen': 'stg_idx'}),
                           on='stg_idx', how='left')
        # SFR limits
        ssp_gen['max_sfr'] = ssp_gen.max_p_mw - ssp_gen.pru * ssp.sn_mva
        ssp_gen['min_sfr'] = ssp_gen.min_p_mw + ssp_gen.prd * ssp.sn_mva
        # ramp limits
        if end_time > 0:
            p_pre_pp = pd.merge(left=ssp.gen.rename(columns={'name': 'stg_idx'}),
                                right=ssp_res[['stg_idx', 'p']],
                                on='stg_idx', how='left')['p']
            ssp_gen['max_ramp'] = ssp.sn_mva * (np.array(p_pre_pp) + np.array(ssd.gen['ramp_5']))
            ssp_gen['min_ramp'] = ssp.sn_mva * (np.array(p_pre_pp) - np.array(ssd.gen['ramp_5']))
            # alter generator limits
            ssp.gen.max_p_mw = ssp_gen[['max_sfr', 'max_ramp']].min(axis=1)
            ssp.gen.min_p_mw = ssp_gen[['min_sfr', 'min_ramp']].max(axis=1)
        else:
            # alter generator limits
            ssp.gen.max_p_mw = ssp_gen['max_sfr']
            ssp.gen.min_p_mw = ssp_gen['min_sfr']

        # --- ACOPF, modify setpoints ---
        # store setpoints
        if end_time > 0:
            p0 = ssp_res['p'].values  # store setpoints
        else:
            p0 = [0] * ssa_key2.shape[0]

        # solve ACOPF
        ssp_res = runopp_map(ssp, ssa_key)  # ACOPF resutls
        ssp_res['p0'] = p0                  # last setpoints
        ssp_res.fillna(False, inplace=True)  # Fill NA wil False

        # reset Generator limtis to normal limits
        ssp.gen.max_p_mw = ssp_gen0.max_p_mw
        ssp.gen.min_p_mw = ssp_gen0.min_p_mw
        print(f"RTED {idx_ed} OK!")
# Out:
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# RTED GB model is loaded.
# RTED removed Constrs: ['rampu', 'rampd']
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 95 rows, 33 columns and 613 nonzeros
# Model fingerprint: 0xe1a76a0e
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+00]
#   Objective range  [2e-03, 2e+01]
#   Bounds range     [4e-01, 1e+01]
#   RHS range        [4e-01, 2e+03]
# Presolve removed 73 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 22 rows, 29 columns, 76 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0038714e+03   8.189349e+00   0.000000e+00      0s
#        2    1.0044120e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.004411994e+03
# RTED is solved.
# RTED: total cost=1004.412
# RTED 0 OK!
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# RTED GB model is loaded.
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 117 rows, 33 columns and 635 nonzeros
# Model fingerprint: 0x916be575
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+00]
#   Objective range  [2e-03, 2e+01]
#   Bounds range     [4e-01, 1e+01]
#   RHS range        [4e-01, 2e+03]
# Presolve removed 116 rows and 24 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 9 columns, 9 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.6423101e+02   2.356271e-01   0.000000e+00      0s
#        1    9.6423573e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.642357270e+02
# RTED is solved.
# RTED: total cost=964.236
# RTED 1 OK!
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# RTED GB model is loaded.
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 117 rows, 33 columns and 635 nonzeros
# Model fingerprint: 0xb0d66680
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+00]
#   Objective range  [2e-03, 2e+01]
#   Bounds range     [4e-01, 1e+01]
#   RHS range        [4e-01, 2e+03]
# Presolve removed 116 rows and 24 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 9 columns, 9 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9755522e+02   1.968245e+00   0.000000e+00      0s
#        1    9.9774544e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.977454392e+02
# RTED is solved.
# RTED: total cost=997.745
# RTED 2 OK!
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# RTED GB model is loaded.
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 117 rows, 33 columns and 635 nonzeros
# Model fingerprint: 0xb64ab10d
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+00]
#   Objective range  [2e-03, 2e+01]
#   Bounds range     [4e-01, 1e+01]
#   RHS range        [4e-01, 2e+03]
# Presolve removed 116 rows and 24 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 9 columns, 9 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9886515e+02   1.234588e+00   0.000000e+00      0s
#        1    9.9895463e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.989546346e+02
# RTED is solved.
# RTED: total cost=998.955
# RTED 3 OK!
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# RTED GB model is loaded.
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 117 rows, 33 columns and 635 nonzeros
# Model fingerprint: 0x8e985c2d
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+00]
#   Objective range  [2e-03, 2e+01]
#   Bounds range     [4e-01, 1e+01]
#   RHS range        [4e-01, 2e+03]
# Presolve removed 116 rows and 24 columns
# Presolve time: 0.01s
# Presolved: 1 rows, 9 columns, 9 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0185595e+03   1.697987e+00   0.000000e+00      0s
#        1    1.0187090e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.018708970e+03
# RTED is solved.
# RTED: total cost=1018.709
# RTED 4 OK!
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# RTED GB model is loaded.
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 117 rows, 33 columns and 635 nonzeros
# Model fingerprint: 0xd3ff741f
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+00]
#   Objective range  [2e-03, 2e+01]
#   Bounds range     [4e-01, 1e+01]
#   RHS range        [4e-01, 2e+03]
# Presolve removed 116 rows and 24 columns
# Presolve time: 0.01s
# Presolved: 1 rows, 9 columns, 9 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0169042e+03   1.226983e+00   0.000000e+00      0s
#        1    1.0169951e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.016995142e+03
# RTED is solved.
# RTED: total cost=1016.995
# RTED 5 OK!
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# RTED GB model is loaded.
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 117 rows, 33 columns and 635 nonzeros
# Model fingerprint: 0xda844711
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+00]
#   Objective range  [2e-03, 2e+01]
#   Bounds range     [4e-01, 1e+01]
#   RHS range        [4e-01, 2e+03]
# Presolve removed 116 rows and 24 columns
# Presolve time: 0.01s
# Presolved: 1 rows, 9 columns, 9 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9588361e+02   7.479748e-01   0.000000e+00      0s
#        1    9.9591841e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.959184108e+02
# RTED is solved.
# RTED: total cost=995.918
# RTED 6 OK!
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# RTED GB model is loaded.
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 117 rows, 33 columns and 635 nonzeros
# Model fingerprint: 0x4661b057
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+00]
#   Objective range  [2e-03, 2e+01]
#   Bounds range     [4e-01, 1e+01]
#   RHS range        [4e-01, 2e+03]
# Presolve removed 116 rows and 24 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 9 columns, 9 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9447221e+02   1.157063e+00   0.000000e+00      0s
#        1    9.9455239e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  9.945523927e+02
# RTED is solved.
# RTED: total cost=994.552
# RTED 7 OK!
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# RTED GB model is loaded.
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 117 rows, 33 columns and 635 nonzeros
# Model fingerprint: 0x083f3e8b
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+00]
#   Objective range  [2e-03, 2e+01]
#   Bounds range     [4e-01, 1e+01]
#   RHS range        [4e-01, 2e+03]
# Presolve removed 116 rows and 24 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 9 columns, 9 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0075729e+03   1.512956e+00   0.000000e+00      0s
#        1    1.0076960e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.007696005e+03
# RTED is solved.
# RTED: total cost=1007.696
# RTED 8 OK!
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# RTED GB model is loaded.
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 117 rows, 33 columns and 635 nonzeros
# Model fingerprint: 0x31becb80
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+00]
#   Objective range  [2e-03, 2e+01]
#   Bounds range     [4e-01, 1e+01]
#   RHS range        [4e-01, 2e+03]
# Presolve removed 116 rows and 24 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 9 columns, 9 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0244944e+03   1.671504e+00   0.000000e+00      0s
#        1    1.0246398e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.024639846e+03
# RTED is solved.
# RTED: total cost=1024.64
# RTED 9 OK!
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# RTED GB model is loaded.
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 117 rows, 33 columns and 635 nonzeros
# Model fingerprint: 0x0738ed34
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+00]
#   Objective range  [2e-03, 2e+01]
#   Bounds range     [4e-01, 1e+01]
#   RHS range        [4e-01, 2e+03]
# Presolve removed 116 rows and 24 columns
# Presolve time: 0.01s
# Presolved: 1 rows, 9 columns, 9 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0091639e+03   8.861096e-01   0.000000e+00      0s
#        1    1.0092151e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.009215122e+03
# RTED is solved.
# RTED: total cost=1009.215
# RTED 10 OK!
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# RTED GB model is loaded.
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 117 rows, 33 columns and 635 nonzeros
# Model fingerprint: 0xb7ddcfd8
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+00]
#   Objective range  [2e-03, 2e+01]
#   Bounds range     [4e-01, 1e+01]
#   RHS range        [4e-01, 2e+03]
# Presolve removed 116 rows and 24 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 9 columns, 9 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0133305e+03   1.364131e+00   0.000000e+00      0s
#        1    1.0134359e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.013435906e+03
# RTED is solved.
# RTED: total cost=1013.436
# RTED 11 OK!

# %% [markdown]
# Loop

# %%
# Reserve some capacity to avoid TDS crush
ssp.gen.max_p_mw = ssp.gen.max_p_mw

# store original generator data
ssp_gen0 = ssp.gen.copy()

for end_time in range(t_total):  # t_total
    # --- interval RTED ---
    if end_time % intv_ed == 0:
        idx_ed = end_time // intv_ed
        # --- update load ---
        sfrur, sfrdr, load_exp = dp_calc(d_syn, idx_ed, intv_ed, rsfr)
        ssp.load['scaling'] = load_exp
        ssp.gen['p_mw'][ssp.gen.name==ev_idx] = sse.Ptc
        ssd.gen['p0'][ssd.gen.idx == ev_idx] = sse.Ptc / ssd.mva
        ssd.load['sf'] = load_exp
        ssd.update_dict()

        # --- RTED, update gen limits after SFR ---
        # set previous setpoints with `pe` from TDS
        if end_time > 0:
            pe_tds = get_pe(ssa, ssa_gov_idx, ssa_dg_idx, ssa_key2)
            pe_tds = pe_tds.merge(ssa_key2, on='stg_idx',
                                  how='right').groupby('stg_idx', as_index=False).sum()
            vl = pd.merge(left=ssd.gen, how='left', on='idx',
                          right=pe_tds[['stg_idx', 'pe']].rename(columns={'stg_idx': 'idx'}))['pe']
            ssd.gen.p_pre = vl.values

        # def. SFR requirements and calc. EV SFR capacities
        [prumax, prdmax] = sse.g_frc()
        # def. percentage of EV SFR capacities
        ssd.def_type2([ev_idx], [prumax*rru/ssd.mva], [prdmax*rrd/ssd.mva])
        ssd.def_sfr(sfrur=sfrur*ssa_p0_sum, sfrdr=sfrdr*ssa_p0_sum)

        # solve RTED
        if end_time == 0:
            dcres = ssd.solve(disable_ramp=True)
        else:
            dcres = ssd.solve()

        # reserve SFR and ramp from Generator limits in ``ssp``
        ssp_gen = pd.merge(left=ssp.gen.rename(columns={'name': 'stg_idx'}),
                           right=dcres.rename(columns={'gen': 'stg_idx'}),
                           on='stg_idx', how='left')
        # SFR limits
        ssp_gen['max_sfr'] = ssp_gen.max_p_mw - ssp_gen.pru * ssp.sn_mva
        ssp_gen['min_sfr'] = ssp_gen.min_p_mw + ssp_gen.prd * ssp.sn_mva
        # ramp limits
        if end_time > 0:
            p_pre_pp = pd.merge(left=ssp.gen.rename(columns={'name': 'stg_idx'}),
                                right=pe_tds[['stg_idx', 'pe']],
                                on='stg_idx', how='left')['pe']
            ssp_gen['max_ramp'] = ssp.sn_mva * (np.array(p_pre_pp) + np.array(ssd.gen['ramp_5']))
            ssp_gen['min_ramp'] = ssp.sn_mva * (np.array(p_pre_pp) - np.array(ssd.gen['ramp_5']))
            # alter generator limits
            ssp.gen.max_p_mw = ssp_gen[['max_sfr', 'max_ramp']].min(axis=1)
            ssp.gen.min_p_mw = ssp_gen[['min_sfr', 'min_ramp']].max(axis=1)
        else:
            # alter generator limits
            ssp.gen.max_p_mw = ssp_gen['max_sfr']
            ssp.gen.min_p_mw = ssp_gen['min_sfr']

        # --- ACOPF, modify setpoints ---
        # store setpoints
        if end_time > 0:
            p0 = ssp_res['p'].values  # store setpoints
        else:
            p0 = [0] * ssa_key2.shape[0]

        # solve ACOPF
        ssp_res = runopp_map(ssp, ssa_key)  # ACOPF resutls
        ssp_res['p0'] = p0                  # last setpoints
        ssp_res.fillna(False, inplace=True)  # Fill NA wil False

        # reset Generator limtis to normal limits
        ssp.gen.max_p_mw = ssp_gen0.max_p_mw
        ssp.gen.min_p_mw = ssp_gen0.min_p_mw

    # --- interval AGC ---
    if end_time % intv_agc == 0:
        idx_agc = end_time // intv_agc - idx_ed * n_agc
        # --- allocate AGC ---
        # assign participation factor `bu`, `bd`
        agc_table.drop(['bu', 'bd'], axis=1, inplace=True)
        agc_table = agc_table.merge(dcres[['gen', 'bu', 'bd']].rename(columns={'gen': 'stg_idx'}),
                                    on='stg_idx', how='left')
        # calc. AGC ---
        ACE_input = min(ACE_raw, dcres.pru.sum())
        if ACE_raw >= 0:
            ACE_input = min(ACE_raw, dcres.pru.sum())
            agc_table['paux'] = ACE_input * agc_table['bu'] * agc_table['gammap']
        else:
            ACE_input = max(ACE_raw, -1 * dcres.prd.sum())
            agc_table['paux'] = ACE_input * agc_table['bd'] * agc_table['gammap']
        agc_in[end_time] = agc_table['paux']
        sfr_res[end_time] = [end_time, ACE_raw, dcres.pru.sum(),
                             -1*dcres.prd.sum(), ACE_input]

        # --- record AGC ---
        if end_time > 0:
            gref = ssa.TurbineGov.get(src='pref', attr='v', idx=agc_gov_idx)
            gout = ssa.TurbineGov.get(src='pout', attr='v', idx=agc_gov_idx)
            g_aux = gout - gref
            agc_out[end_time] = np.append(g_aux, [sse.Prc/ssa.config.mva])

        # --- assign AGC ---
        # a.SynGen
        # Note: now the condition is controllable & has governor
        ssa.TurbineGov.set(src='paux0', idx=agc_gov_idx, attr='v',
                           value=agc_table.paux.values)
        # b.DG;
        ssa.DG.set(src='pext0', idx=agc_dg_idx, attr='v',
                   value=agc_table.paux.values)
        # c.EV;
        # Note: EV is in group DG, remove EV set if not used for EV SSM
        sse_agc = ssa.config.mva * agc_table[agc_table.stg_idx == ev_idx].paux.values
        # TODO: RenGen

        # --- smooth setpoints ---
        if idx_ed == 0:
            ssp_res['pref'] = ssp_res['p']
        else:
            if idx_agc == 0:
                # record `pe` from TDS in the first AGC interval
                copy = ssp_res.merge(right=pe_tds[['pe', 'stg_idx']], on='stg_idx', how='left')
                ssp_res['pe_tds'] = copy.pe
            idx_step = min((end_time - idx_ed * intv_ed) // intv_agc + 1, n_step)
            ssp_res['pref_step'] = ssp_res.p - ssp_res.p0
            # smooth change threshold: 0.01
            large_index = ssp_res['pref_step'][abs(ssp_res['pref_step']) > 0.01].index
            ssp_res['pref_delta'] = ssp_res['pref_step']
            ssp_res['pref_delta'].iloc[large_index] = ssp_res['pref_step'].iloc[large_index] / n_step * idx_step
            ssp_res['pref'] = ssp_res.p0 + ssp_res.pref_delta

            # a.SynGen
            ssa.TurbineGov.set(src='pref0', idx=sch_gov_idx,
                               attr='v', value=ssp_res.pref[cond_sch_gov].values)
            # b.DG
            ssa.DG.set(src='pref0', idx=sch_dg_idx,
                       attr='v', value=ssp_res.pref[cond_sch_dg].values)

    # --- intv_pq: alter load, run TDS ---
    # Initially, alter StaticGen: p0 and q0, run PFlow
    # Otherwise, alter Ppf and Qpf
    if end_time == 0:
        stg_opf_idx = ssp_res.stg_idx[ssp_res.controllable].tolist()
        stg_opf_val = ssp_res.p[ssp_res.controllable].tolist()
        stg_opf_v = ssp_res.vm_pu[ssp_res.controllable].tolist()
        ssa.StaticGen.set(src='p0', idx=stg_opf_idx, attr='v', value=stg_opf_val)
        ssa.StaticGen.set(src='v0', idx=stg_opf_idx, attr='v', value=stg_opf_v)
        # initial load point set as the dispatch point
        ssa.PQ.set(src='p0', idx=ssa_pq_idx, attr='v',
                   value=ssa_p0 * load_exp)
        ssa.PQ.set(src='q0', idx=ssa_pq_idx, attr='v',
                   value=ssa_q0 * load_exp)
        ssa.PFlow.run()
    else:
        ssa.PQ.set(src='Ppf', idx=ssa_pq_idx, attr='v',
                   value=ssa_p0 * d_syn['sload'].iloc[end_time])
        ssa.PQ.set(src='Qpf', idx=ssa_pq_idx, attr='v',
                   value=ssa_q0 * d_syn['sload'].iloc[end_time])
        # run `sse`
        sse.run(tf=caseH+end_time/3600, Pi=sse_agc[0],
                is_updateA=False, is_rstate=True,
                is_test=False, disable=True)
        ev_soc[end_time] = sse.ev.soc
        ev_agc[end_time] = sse.ev.agc
        sse.report(is_report=False)
        ssa.EV2.set(src='pref0', idx=ssp_res.dg_idx[ssp_res.stg_idx == ev_idx].values[0],
                    attr='v', value=sse.Ptc / ssa.config.mva)

    # run TDS
    ssa.TDS.config.tf = end_time
    if end_time == 0:
        ssa.TDS.init()
    ssa.TDS.run()
    # update AGC PI Controller
    ACE_integral = ACE_integral + ssa.ACEc.ace.v.sum()
    ACE_raw = -(Kp*ssa.ACEc.ace.v.sum() + Ki*ACE_integral)

    # ACE_raw = 0  # delete when run TDS
    # break loop if TDS run into error
    if ssa.exit_code != 0:
        raise ValueError(f"TDS error! Exit with {ssa.exit_code}, end at {end_time}s.")
# Out:
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# RTED GB model is loaded.
# RTED removed Constrs: ['rampu', 'rampd']
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 95 rows, 33 columns and 613 nonzeros
# Model fingerprint: 0xa61d875a
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+00]
#   Objective range  [2e-03, 2e+01]
#   Bounds range     [4e-03, 1e+01]
#   RHS range        [4e-01, 2e+03]
# Presolve removed 73 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 22 rows, 29 columns, 76 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9666790e+02   8.010513e+00   0.000000e+00      0s
#        2    9.9718701e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.971870103e+02
# RTED is solved.
# RTED: total cost=997.187
# -> System connectivity check results:
#   No islanded bus detected.
#   System is interconnected.
#   Each island has a slack bus correctly defined and enabled.
#
# -> Power flow calculation
#            Numba: On
#    Sparse solver: KLU
#  Solution method: NR method
# Numba compilation initiated with caching.
# Power flow initialized in 0.0059 seconds.
# 0: |F(x)| = 7.692918013
# 1: |F(x)| = 3.690526051
# 2: |F(x)| = 0.2072670266
# 3: |F(x)| = 0.001349926027
# 4: |F(x)| = 4.762082773e-08
# Converged in 5 iterations in 0.0059 seconds.
# Numba compilation initiated with caching.
# GENROU (xl <= xd2) out of typical upper limit.
#
#    idx     | values | limit
# -----------+--------+------
#  GENROU_1  | 0.014  | 0.001
#  GENROU_3  | 0.018  | 0.003
#  GENROU_4  | 0.013  | 0.001
#  GENROU_5  | 0.014  | 0.001
#  GENROU_7  | 0.015  | 0.002
#  GENROU_8  | 0.015  | 0.006
#  GENROU_9  | 0.009  | 0.001
#  GENROU_10 | 0.013  | 0.000
#
#
# Initialization for dynamics completed in 0.2040 seconds.
# Initialization was successful.
#
# -> Time Domain Simulation Summary:
# Sparse Solver: KLU
# Simulation time: 0.0-0 s.
# Fixed step size: h=33.33 ms. Shrink if not converged.
# Simulation to t=0.00 sec completed in 0.0001 seconds.
#
# -> Time Domain Simulation Summary:
# Sparse Solver: KLU
# Simulation time: 0.0-1 s.
# Fixed step size: h=33.33 ms. Shrink if not converged.
# Current step size is zero. Integration is not permitted.
# Simulation to t=1.00 sec completed in 0.0629 seconds.
# Simulation to t=2.00 sec completed in 0.0484 seconds.
# Simulation to t=3.00 sec completed in 0.0514 seconds.
# Simulation to t=4.00 sec completed in 0.0519 seconds.
# Simulation to t=5.00 sec completed in 0.0474 seconds.
# Simulation to t=6.00 sec completed in 0.0499 seconds.
# Simulation to t=7.00 sec completed in 0.0485 seconds.
# Simulation to t=8.00 sec completed in 0.0874 seconds.
# Simulation to t=564.00 sec completed in 0.0532 seconds.
# Simulation to t=565.00 sec completed in 0.0554 seconds.
# Simulation to t=566.00 sec completed in 0.0509 seconds.
# Simulation to t=567.00 sec completed in 0.0545 seconds.
# Simulation to t=568.00 sec completed in 0.0766 seconds.
# Simulation to t=569.00 sec completed in 0.0702 seconds.
# Simulation to t=570.00 sec completed in 0.0636 seconds.
# Simulation to t=571.00 sec completed in 0.0601 seconds.
# Simulation to t=572.00 sec completed in 0.0712 seconds.
# Simulation to t=573.00 sec completed in 0.0615 seconds.
# Simulation to t=574.00 sec completed in 0.0562 seconds.
# Simulation to t=575.00 sec completed in 0.0514 seconds.
# Simulation to t=576.00 sec completed in 0.1872 seconds.
# Simulation to t=577.00 sec completed in 0.1086 seconds.
# Simulation to t=578.00 sec completed in 0.0678 seconds.
# Simulation to t=579.00 sec completed in 0.0609 seconds.
# Simulation to t=580.00 sec completed in 0.0915 seconds.
# Simulation to t=581.00 sec completed in 0.0784 seconds.
# Simulation to t=582.00 sec completed in 0.0597 seconds.
# Simulation to t=583.00 sec completed in 0.0687 seconds.
# Simulation to t=584.00 sec completed in 0.0701 seconds.
# Simulation to t=585.00 sec completed in 0.0601 seconds.
# Simulation to t=586.00 sec completed in 0.0628 seconds.
# Simulation to t=587.00 sec completed in 0.0808 seconds.
# Simulation to t=588.00 sec completed in 0.2093 seconds.
# Simulation to t=589.00 sec completed in 0.0926 seconds.
# Simulation to t=590.00 sec completed in 0.1047 seconds.
# Simulation to t=591.00 sec completed in 0.0957 seconds.
# Simulation to t=592.00 sec completed in 0.1049 seconds.
# Simulation to t=593.00 sec completed in 0.3181 seconds.
# Simulation to t=594.00 sec completed in 0.1260 seconds.
# Simulation to t=595.00 sec completed in 0.1387 seconds.
# Simulation to t=596.00 sec completed in 0.1220 seconds.
# Simulation to t=597.00 sec completed in 0.1800 seconds.
# Simulation to t=598.00 sec completed in 0.2082 seconds.
# Simulation to t=599.00 sec completed in 0.1203 seconds.
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# RTED GB model is loaded.
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 117 rows, 33 columns and 635 nonzeros
# Model fingerprint: 0x56d37beb
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+00]
#   Objective range  [2e-03, 2e+01]
#   Bounds range     [3e-03, 1e+01]
#   RHS range        [4e-01, 2e+03]
# Presolve removed 116 rows and 24 columns
# Presolve time: 0.01s
# Presolved: 1 rows, 9 columns, 9 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9038556e+02   1.761967e+00   0.000000e+00      0s
#        1    9.9054222e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.905422239e+02
# RTED is solved.
# RTED: total cost=990.542
# Simulation to t=600.00 sec completed in 0.1400 seconds.
# Simulation to t=601.00 sec completed in 0.0641 seconds.
# Simulation to t=602.00 sec completed in 0.0698 seconds.
# Simulation to t=603.00 sec completed in 0.0704 seconds.
# Simulation to t=604.00 sec completed in 0.0971 seconds.
# Simulation to t=605.00 sec completed in 0.0767 seconds.
# Simulation to t=606.00 sec completed in 0.0552 seconds.
# Simulation to t=607.00 sec completed in 0.0866 seconds.
# Simulation to t=608.00 sec completed in 0.0583 seconds.
# Simulation to t=609.00 sec completed in 0.0623 seconds.
# Simulation to t=610.00 sec completed in 0.0663 seconds.
# Simulation to t=611.00 sec completed in 0.0738 seconds.
# Simulation to t=612.00 sec completed in 0.1056 seconds.
# Simulation to t=669.00 sec completed in 0.0585 seconds.
# Simulation to t=670.00 sec completed in 0.0567 seconds.
# Simulation to t=671.00 sec completed in 0.0929 seconds.
# Simulation to t=672.00 sec completed in 0.1295 seconds.
# Simulation to t=673.00 sec completed in 0.2756 seconds.
# Simulation to t=674.00 sec completed in 0.0572 seconds.
# Simulation to t=675.00 sec completed in 0.0666 seconds.
# Simulation to t=676.00 sec completed in 0.0661 seconds.
# Simulation to t=677.00 sec completed in 0.0704 seconds.
# Simulation to t=678.00 sec completed in 0.0917 seconds.
# Simulation to t=679.00 sec completed in 0.0757 seconds.
# Simulation to t=680.00 sec completed in 0.0549 seconds.
# Simulation to t=681.00 sec completed in 0.0576 seconds.
# Simulation to t=682.00 sec completed in 0.0620 seconds.
# Simulation to t=683.00 sec completed in 0.0447 seconds.
# Simulation to t=684.00 sec completed in 0.0476 seconds.
# Simulation to t=685.00 sec completed in 0.0579 seconds.
# Simulation to t=686.00 sec completed in 0.0645 seconds.
# Simulation to t=687.00 sec completed in 0.0540 seconds.
# Simulation to t=688.00 sec completed in 0.0565 seconds.
# Simulation to t=689.00 sec completed in 0.0787 seconds.
# Simulation to t=690.00 sec completed in 0.0822 seconds.
# Simulation to t=691.00 sec completed in 0.0622 seconds.
# Simulation to t=692.00 sec completed in 0.0564 seconds.
# Simulation to t=693.00 sec completed in 0.0606 seconds.
# Simulation to t=694.00 sec completed in 0.0730 seconds.
# Simulation to t=695.00 sec completed in 0.0691 seconds.
# Simulation to t=696.00 sec completed in 0.0505 seconds.
# Simulation to t=697.00 sec completed in 0.0460 seconds.
# Simulation to t=698.00 sec completed in 0.0507 seconds.
# Simulation to t=699.00 sec completed in 0.0545 seconds.

# %%
ssa.exit_code
# Out:
# 0

# %%
# ssa.TDS.save_output()

# %%
plt.style.use('default')

right = end_time

fig_gen, ax_gen = plt.subplots(2, 3, figsize=(16, 8))
plt.subplots_adjust(left=None, bottom=None, right=None,
                    top=None, wspace=0.2, hspace=0.3)

yheader = [f'G{i}' for i in range(1, 11)]

ssa.TDS.plt.plot(ssa.TGOV1N.pout,
                 linestyles=['-'],
                 yheader=yheader, ytimes=ssa.config.mva,
                 legend=True, show=False, right=right,
                 title=r'Generation (solid: pout; dash: pref)',
                 ylabel='MW',
                 fig=fig_gen, ax=ax_gen[0, 0])

ssa.TDS.plt.plot(ssa.TGOV1N.pref, ytimes=ssa.config.mva,
                 legend=False, show=False, right=right,
                 linestyles=[':'],
                 fig=fig_gen, ax=ax_gen[0, 0])

ssa.TDS.plt.plot(ssa.TGOV1N.paux,
                 linestyles=['-'],
                 yheader=yheader, ytimes=ssa.config.mva,
                 legend=False, show=False, right=right,
                 title=r'AGC power', ylabel='MW',
                 fig=fig_gen, ax=ax_gen[0, 1])

# Plot EV AGC response, hard code
ax_gen[0, 1].plot(3600*(np.array(sse.tss)-caseH), sse.Prl, color='tab:orange', linestyle=':')
ax_gen[0, 1].plot(3600*(np.array(sse.tss)-caseH), sse.Prcl, color='tab:orange', linestyle='-')
# ax_gen[0, 1].set_ylim(top=max(sse.Prl) * 1.2)

sfr_res_plot = sfr_res.drop(['cat'], axis=1).T
sfr_res_plot.columns = sfr_res['cat'].values
ax_gen[0, 2].plot(sfr_res_plot.time,
                  ssa.config.mva * sfr_res_plot['ace'],
                  label='AGC raw')
ax_gen[0, 2].plot(sfr_res_plot.time, 
                  ssa.config.mva * sfr_res_plot['in'],
                  label='AGC input')
ax_gen[0, 2].plot(sfr_res_plot.time,
                  ssa.config.mva * sfr_res_plot['up'],
                  label='SFR capacity',
                  linestyle='--', color='k')
ax_gen[0, 2].plot(sfr_res_plot.time, 
                  ssa.config.mva * sfr_res_plot['dn'],
                  linestyle='--', color='k')
ax_gen[0, 2].set_ylabel('MW')
ax_gen[0, 2].set_xlabel('Time [s]')
ax_gen[0, 2].set_title('AGC input and SFR capacity')

ssa.TDS.plt.plot(ssa.ACEc.ace,
                 legend=False, show=False, right=right,
                 linestyles=['-'], ytimes=ssa.config.mva,
                 title=r'ACE', ylabel='MW',
                 fig=fig_gen, ax=ax_gen[1, 0])

ssa.TDS.plt.plot(ssa.COI.omega,
                 legend=False, show=False, right=right,
                 linestyles=['-'], ylabel='Hz',
                 ytimes=ssa.config.freq,
                 title=r'COI Frequency',
                 fig=fig_gen, ax=ax_gen[1, 1])

f_coi = pd.DataFrame()
f_coi['f'] = ssa.dae.ts.y[:, ssa.COI.omega.a].reshape(-1).copy() * ssa.config.freq - ssa.config.freq
f_coi.plot(kind='kde', legend=False, linewidth=1,
           fig=fig_gen, ax=ax_gen[1, 2],
           title=f'Freq. D., $\mu$={f_coi.f.mean().round(4)}, $\sigma$={f_coi.f.std().round(4)}')
ax_gen[1, 2].set(xlabel='Deviation [Hz]', ylabel='')
# Out:
# [Text(0.5, 58.7222222222222, 'Deviation [Hz]'),
#  Text(1037.8913398692812, 0.5, '')]

# %%
ssa.ACEc.ace
# Out:
# Algeb: ACEc.ace, a=[90], v=[-0.24720877], e=[-7.69107e-14]

# %%
sse.plot_agc()
# Out:
# (<Figure size 600x300 with 1 Axes>,
#  <AxesSubplot:title={'center':'AGC response'}, xlabel='Time [H]', ylabel='Power (MW)'>)

# %%
# Complement AGC table
agc_smooth = pd.DataFrame(np.repeat(agc_in[list(np.arange(0, t_total, 4))].values, 4, axis=1),
                       columns=list(np.arange(0, t_total, 1)))

# Record output
sse_out = pd.DataFrame()
sse_out['time'] = sse.tss
sse_out['agc'] = agc_smooth.iloc[10]  # AGC input to EV
sse_out['Pr'] = sse.Prl
sse_out['Prc'] = sse.Prcl
sse_out.to_csv('sse_out.csv', index=False)

# %%
soc_plot = ev_soc[ev_agc.abs().sum(axis=1) > 0].reset_index(drop=True)
soc_plot = soc_plot[list(range(end_time+1))]

fig_soc, ax_soc = plt.subplots(figsize=(5, 4))
for i in range(soc_plot.shape[0]):
    ax_soc.plot(range(end_time+1), soc_plot.iloc[i])
ax_soc.set_xlabel('Time [s]')
ax_soc.set_ylabel('SOC [%]')
ax_soc.set_title('AGC EVs SOC')
ax_soc.set_xlim([0, end_time])
# Out:
# (0.0, 699.0)

# %%
sse.plot(style='ieee')
# Out:
# (<Figure size 3600x1800 with 2 Axes>,
#  <AxesSubplot:title={'center':'EVA'}, xlabel='Time [H]', ylabel='Power (MW)'>)
