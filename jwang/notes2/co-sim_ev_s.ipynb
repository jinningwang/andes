# %% [markdown]
# # RTED-TDS Co-Sim
#
# Authored by [Jinning Wang](https://scholar.google.com/citations?user=Wr7nQZAAAAAJ&hl=en&oi=ao), recently updated on 06/06/2022.
#
# This notebook is used to implement the Co-Simulation of Real Time Economic Dispatch (RTED) and Time-Domain Simulation (TDS).
# In the RTED, SFR is considered. In the TDS, AGC is implemented with an equation defined PI controller.
#
# RTED is seperated into two DCOPF and ACOPF: 1) DCOPF with SFR is solved in gurobipy, which is packaged into the class ``rted`` in the file ``rted.py``. 2) ACOPF is solved in pandapower.
#
# Class ``rted2`` has attributes ``mdl`` which is a gurobipy model.
#
# Table of contents:
# - Import case: import ADNES case
# - Load synthetic: build load curve as a scalar
# - Setup ``ssp`` and ``ssd``
# - Prepare: define some functions
# - Define param: define RTED loop parameters
# - Loop: Co-Sim loop
#
# List of major vars:
#
# - ``ssa`` ANDES system
# - ``ssp`` pandapower net
# - ``ssd`` DCOPF instance
# - ``sse`` EV aggregator
#
# Things need to be done when switching to other cases:
# - Assign generator cost data. The rows of gen_cost array should be the same with the length of ``ssp.gen``
#   including those uncontrollable ones, so the DCOPF model can build correctly.
# - Define generator controllability of ``ssp``, all generators are controllable by default
# - Define power system data: SFR cost, ramp limit (5-min-based)
# - Define generator type in ``ssd``, default as type I. For type I generator, generator limtis have impact on both generation and SFR capacity. For yype II generator, SFR capacity is determined by param ``pru_max`` and ``prd_max``
#
# Environment requirements:
# - ANDES (1.6.3+)
# - pandapower (2.7.0 is tested to be function correctly)
# - gurobipy
# - pandas, matplotlib, scipy

# %% [markdown]
# ## Import case

# %%
# %run -i 'cosim_import.py'
# Out:
# 1.7.2.post267.dev0+g60c0cc4e
# 2.9.0

# %% [markdown]
# `caseH` is the start time [H] of the co-simulation, now 10 and 18 are supported.

# %%
caseH = 10
# %run -i 'cosim_setup_andes.py'
# Out:
# EVA: ts=10[H], 10000 EVs, Total Q=250.12 MWh
# Online 1983, Q=49.73 MWh, SoC=0.9834
# Power(MW): Pt=-0.3613, Pc=-0.3613, Pd=-0.0
# Ctrl: 0=1921; 1=62;
# EVA: Load A from Aest.csv.
# Working directory: "/home/jwang175/andes/jwang/notes2"
# > Loaded config from file "/home/jwang175/.andes/andes.rc"
# > Loaded generated Python code in "/home/jwang175/.andes/pycode".
# Generated code for <PQ> is stale.
# Numerical code generation (rapid incremental mode) started...
# Generating code for 1 models on 6 processes.
# Saved generated pycode to "/home/jwang175/.andes/pycode"
# > Reloaded generated Python code of module "pycode".
# Generated numerical code for 1 models in 0.2606 seconds.
# Parsing input file "/home/jwang175/andes/jwang/case/ieee39_ev2.xlsx"...
# Input file parsed in 0.1015 seconds.
# ACEc <1> added BusFreq <BusFreq_11> linked to bus <1>
# System internal structure set up in 0.0423 seconds.

# %% [markdown]
# ## Load synthetic
#
# Create load data ``d_syn``, which is a ``DataFrame`` that have three columns: ``time``, ``s10``, ``h10``. ``time`` is by seconds, ``s10`` is scalar load.

# %%
# %run -i 'cosim_loadsyn.py'
# Out:
# ANDES total load is: 58.564 p.u.

# %% [markdown]
# ## Setup ``ssp`` and ``ssd``
#
# Convert ``ssa`` to pandapower net ``ssp``, add generator cost
#
# The input cost array follow the matpower/pypower format, now only poly_cost is supported

# %%
# %run -i 'cosim_setup_dispatch.py'
# Out:
# -> System connectivity check results:
#   No islanded bus detected.
#   System is interconnected.
#   Each island has a slack bus correctly defined and enabled.
#
# -> Power flow calculation
#            Numba: On
#    Sparse solver: KLU
#  Solution method: NR method
# Numba compilation initiated with caching.
# Power flow initialized in 0.1158 seconds.
# 0: |F(x)| = 7.561249598
# 1: |F(x)| = 2.917040377
# 2: |F(x)| = 0.1312974497
# 3: |F(x)| = 0.0003563766345
# 4: |F(x)| = 4.278702725e-09
# Converged in 5 iterations in 0.0082 seconds.
# Power flow results are consistent. Conversion is successful.
# Restricted license - for non-production use only - expires 2023-10-25
# -> System connectivity check results:
#   No islanded bus detected.
#   System is interconnected.
#   Each island has a slack bus correctly defined and enabled.
#
# -> Power flow calculation
#            Numba: On
#    Sparse solver: KLU
#  Solution method: NR method
# Numba compilation initiated with caching.
# Power flow initialized in 0.0080 seconds.
# 0: |F(x)| = 7.561249598
# 1: |F(x)| = 2.917040377
# 2: |F(x)| = 0.1312974497
# 3: |F(x)| = 0.0003563766345
# 4: |F(x)| = 4.278702725e-09
# Converged in 5 iterations in 0.0060 seconds.
# Power flow results are consistent. Conversion is successful.
# GSF is consistent.
# RTED GB model is loaded.
# RTED removed Constrs: ['pgmax', 'pgmin', 'sfru', 'sfrd', 'rampu', 'rampd']
# RTED: total cost=1189.898
# pp cost=119054.76476573595, gb cost=1189.897555994747

# %%
ppres
# Out:
#           p_mw      q_mvar  va_degree  vm_pu     p_mw(GB)
# 0   527.463570   90.396306   5.014635    1.0  1040.000000
# 1   646.000000  310.969446   5.161051    1.0   646.000000
# 2   725.000000  148.831804   8.983376    1.0   725.000000
# 3   652.000000  129.688596   9.034017    1.0   652.000000
# 4   508.000000  145.052832   7.202725    1.0   200.000000
# 5   620.247329  225.130203  10.538482    1.0   687.000000
# 6   579.999997   60.485999  14.257179    1.0   232.000000
# 7   225.600002  -26.176825   2.269216    1.0   405.528532
# 8   865.000000  116.012450  12.929514    1.0   865.000000
# 9   -36.128532    0.000000  12.929514    1.0   -36.128532
# 10  543.217636  -30.622919   0.000000    1.0   440.000000

# %% [markdown]
# ## Prepare

# %% [markdown]
# ### Make link table

# %%
# %run -i 'cosim_linktable.py'

# %%
ssa_key2
# Out:
#     stg_name  stg_u   stg_idx  bus_idx dg_idx  rg_idx    syg_idx    exc_idx  \
# 0       PV_1    1.0      PV_1       30  False   False   GENROU_1   IEEEX1_1
# 1       PV_2    1.0      PV_2       31  False   False   GENROU_2   IEEEX1_2
# 2       PV_3    1.0      PV_3       32  False   False   GENROU_3   IEEEX1_3
# 3       PV_4    1.0      PV_4       33  False   False   GENROU_4   IEEEX1_4
# 4       PV_5    1.0      PV_5       34  False   False   GENROU_5   IEEEX1_5
# 5       PV_6    1.0      PV_6       35  False   False   GENROU_6   IEEEX1_6
# 6       PV_7    1.0      PV_7       36  False   False   GENROU_7   IEEEX1_7
# 7       PV_8    1.0      PV_8       37  False   False   GENROU_8   IEEEX1_8
# 8       PV_9    1.0      PV_9       38  False   False   GENROU_9   IEEEX1_9
# 9   Slack_10    1.0  Slack_10       39  False   False  GENROU_10  IEEEX1_10
# 10     PV_10    1.0     PV_10       38   EV_1   False      False      False
#
#      gov_idx bus_name  gammap  gammaq  gen_pp   ctrl
# 0    TGOV1_1    GEN30     1.0     1.0       0   True
# 1    TGOV1_2    GEN31     1.0     1.0       1   True
# 2    TGOV1_3    GEN32     1.0     1.0       2   True
# 3    TGOV1_4    GEN33     1.0     1.0       3   True
# 4    TGOV1_5    GEN34     1.0     1.0       4   True
# 5    TGOV1_6    GEN35     1.0     1.0       5   True
# 6    TGOV1_7    GEN36     1.0     1.0       6   True
# 7    TGOV1_8    GEN37     1.0     1.0       7   True
# 8    TGOV1_9    GEN38     1.0     1.0       8   True
# 9   TGOV1_10    GEN39     1.0     1.0      10   True
# 10     False    GEN38     1.0     1.0       9  False

# %% [markdown]
# ## Loop
#
# In the loop, there are mainly X parts:
#
# - interval RTED: run DCOPF (``ssd.mdl``), run ACOPF(``ssp``),
#
# - interval AGC: do AGC, do dispatch with smooth setpoints
#
# - interval PQ: alter load, run TDS(``ssa.TDS``)
#
# Notes:
#
# - The setpoints for DG are coded but not verified yet.
#
# - After the development of ANDES control room, the dispatch and AGC part can be refactored.
#
# - interface variables: ``DG.pmx``: DPV profile, ``DG.pref0``: setpoints, ``DG.pext0``: AGC
#
# - ACOPF in pandapower considered generator limtis of ramping and SFR reserve

# %%
# Define functions and constants used in loop
# %run -i 'cosim_const.py'

# Change ``rru``, ``rrd``, ``rsfr``, ``t_total`` for necessary.
t_total = 100
rru = 0
rrd = 0

# %% [markdown]
# Check convergence

# %%
# %run -i 'cosim_bmain.py'
# Out:
# RTED GB model is loaded.
# RTED removed Constrs: ['rampu', 'rampd']
# RTED is solved.
# RTED: total cost=1004.412
# RTED GB model is loaded.
# RTED is solved.
# RTED: total cost=964.236
# RTED 0 OK!
# RTED GB model is loaded.
# RTED is solved.
# RTED: total cost=997.745
# RTED 1 OK!
# RTED GB model is loaded.
# RTED is solved.
# RTED: total cost=998.955
# RTED 2 OK!
# RTED GB model is loaded.
# RTED is solved.
# RTED: total cost=1018.709
# RTED 3 OK!
# RTED GB model is loaded.
# RTED is solved.
# RTED: total cost=1016.995
# RTED 4 OK!
# RTED GB model is loaded.
# RTED is solved.
# RTED: total cost=995.918
# RTED 5 OK!
# RTED GB model is loaded.
# RTED is solved.
# RTED: total cost=994.552
# RTED 6 OK!
# RTED GB model is loaded.
# RTED is solved.
# RTED: total cost=1007.696
# RTED 7 OK!
# RTED GB model is loaded.
# RTED is solved.
# RTED: total cost=1024.64
# RTED 8 OK!
# RTED GB model is loaded.
# RTED is solved.
# RTED: total cost=1009.215
# RTED 9 OK!
# RTED GB model is loaded.
# RTED is solved.
# RTED: total cost=1013.436
# RTED 10 OK!
# RTED 11 OK!

# %% [markdown]
# Loop

# %%
# %run -i 'cosim_main.py'
# Out:
# RTED GB model is loaded.
# RTED removed Constrs: ['rampu', 'rampd']
# RTED is solved.
# RTED: total cost=997.187
# -> System connectivity check results:
#   No islanded bus detected.
#   System is interconnected.
#   Each island has a slack bus correctly defined and enabled.
#
# -> Power flow calculation
#            Numba: On
#    Sparse solver: KLU
#  Solution method: NR method
# Numba compilation initiated with caching.
# Power flow initialized in 0.0081 seconds.
# 0: |F(x)| = 7.692918013
# 1: |F(x)| = 3.690526051
# 2: |F(x)| = 0.2072670266
# 3: |F(x)| = 0.001349926027
# 4: |F(x)| = 4.762083217e-08
# Converged in 5 iterations in 0.0085 seconds.
# Numba compilation initiated with caching.
# GENROU (xl <= xd2) out of typical upper limit.
#
#    idx     | values | limit
# -----------+--------+------
#  GENROU_1  | 0.014  | 0.001
#  GENROU_3  | 0.018  | 0.003
#  GENROU_4  | 0.013  | 0.001
#  GENROU_5  | 0.014  | 0.001
#  GENROU_7  | 0.015  | 0.002
#  GENROU_8  | 0.015  | 0.006
#  GENROU_9  | 0.009  | 0.001
#  GENROU_10 | 0.013  | 0.000
#
#
# Initialization for dynamics completed in 0.3168 seconds.
# Initialization was successful.
#
# -> Time Domain Simulation Summary:
# Sparse Solver: KLU
# Simulation time: 0.0-0 s.
# Fixed step size: h=33.33 ms. Shrink if not converged.
# Simulation to t=0.00 sec completed in 0.0000 seconds.
#
# -> Time Domain Simulation Summary:
# Sparse Solver: KLU
# Simulation time: 0.0-1 s.
# Fixed step size: h=33.33 ms. Shrink if not converged.
# Current step size is zero. Integration is not permitted.
# Simulation to t=1.00 sec completed in 0.0998 seconds.
# Simulation to t=2.00 sec completed in 0.0907 seconds.
# Simulation to t=3.00 sec completed in 0.0936 seconds.
# Simulation to t=4.00 sec completed in 0.0929 seconds.
# Simulation to t=5.00 sec completed in 0.0803 seconds.
# Simulation to t=6.00 sec completed in 0.0859 seconds.
# Simulation to t=7.00 sec completed in 0.0846 seconds.
# Simulation to t=8.00 sec completed in 0.0792 seconds.
# Simulation to t=9.00 sec completed in 0.0670 seconds.
# Simulation to t=10.00 sec completed in 0.0668 seconds.
# Simulation to t=11.00 sec completed in 0.0677 seconds.
# Simulation to t=12.00 sec completed in 0.0713 seconds.
# Simulation to t=13.00 sec completed in 0.0742 seconds.
# Simulation to t=14.00 sec completed in 0.0640 seconds.
# Simulation to t=15.00 sec completed in 0.0643 seconds.
# Simulation to t=16.00 sec completed in 0.0650 seconds.
# Simulation to t=17.00 sec completed in 0.0635 seconds.
# Simulation to t=18.00 sec completed in 0.0634 seconds.
# Simulation to t=19.00 sec completed in 0.0632 seconds.
# Simulation to t=20.00 sec completed in 0.0634 seconds.
# Simulation to t=21.00 sec completed in 0.0633 seconds.
# Simulation to t=22.00 sec completed in 0.0619 seconds.
# Simulation to t=23.00 sec completed in 0.0625 seconds.
# Simulation to t=24.00 sec completed in 0.0613 seconds.
# Simulation to t=25.00 sec completed in 0.0613 seconds.
# Simulation to t=26.00 sec completed in 0.0615 seconds.
# Simulation to t=27.00 sec completed in 0.0611 seconds.
# Simulation to t=28.00 sec completed in 0.0612 seconds.
# Simulation to t=29.00 sec completed in 0.0617 seconds.
# Simulation to t=30.00 sec completed in 0.0613 seconds.
# Simulation to t=31.00 sec completed in 0.0613 seconds.
# Simulation to t=32.00 sec completed in 0.0613 seconds.
# Simulation to t=33.00 sec completed in 0.0655 seconds.
# Simulation to t=34.00 sec completed in 0.0650 seconds.
# Simulation to t=35.00 sec completed in 0.0651 seconds.
# Simulation to t=36.00 sec completed in 0.0654 seconds.
# Simulation to t=37.00 sec completed in 0.0653 seconds.
# Simulation to t=38.00 sec completed in 0.0651 seconds.
# Simulation to t=39.00 sec completed in 0.0658 seconds.
# Simulation to t=40.00 sec completed in 0.0654 seconds.
# Simulation to t=41.00 sec completed in 0.0651 seconds.
# Simulation to t=42.00 sec completed in 0.0654 seconds.
# Simulation to t=43.00 sec completed in 0.0653 seconds.
# Simulation to t=44.00 sec completed in 0.0653 seconds.
# Simulation to t=45.00 sec completed in 0.0655 seconds.
# Simulation to t=46.00 sec completed in 0.0651 seconds.
# Simulation to t=47.00 sec completed in 0.0652 seconds.
# Simulation to t=48.00 sec completed in 0.0657 seconds.
# Simulation to t=49.00 sec completed in 0.0655 seconds.
# Simulation to t=50.00 sec completed in 0.0655 seconds.
# Simulation to t=51.00 sec completed in 0.0653 seconds.
# Simulation to t=52.00 sec completed in 0.0651 seconds.
# Simulation to t=53.00 sec completed in 0.0654 seconds.
# Simulation to t=54.00 sec completed in 0.0655 seconds.
# Simulation to t=55.00 sec completed in 0.0650 seconds.
# Simulation to t=56.00 sec completed in 0.0656 seconds.
# Simulation to t=57.00 sec completed in 0.0653 seconds.
# Simulation to t=58.00 sec completed in 0.0655 seconds.
# Simulation to t=59.00 sec completed in 0.0652 seconds.
# Simulation to t=60.00 sec completed in 0.0656 seconds.
# Simulation to t=61.00 sec completed in 0.0656 seconds.
# Simulation to t=62.00 sec completed in 0.0657 seconds.
# Simulation to t=63.00 sec completed in 0.0654 seconds.
# Simulation to t=64.00 sec completed in 0.0652 seconds.
# Simulation to t=65.00 sec completed in 0.0664 seconds.
# Simulation to t=66.00 sec completed in 0.0651 seconds.
# Simulation to t=67.00 sec completed in 0.0652 seconds.
# Simulation to t=68.00 sec completed in 0.0651 seconds.
# Simulation to t=69.00 sec completed in 0.0654 seconds.
# Simulation to t=70.00 sec completed in 0.0653 seconds.
# Simulation to t=71.00 sec completed in 0.0657 seconds.
# Simulation to t=72.00 sec completed in 0.0653 seconds.
# Simulation to t=73.00 sec completed in 0.0662 seconds.
# Simulation to t=74.00 sec completed in 0.0653 seconds.
# Simulation to t=75.00 sec completed in 0.0656 seconds.
# Simulation to t=76.00 sec completed in 0.0652 seconds.
# Simulation to t=77.00 sec completed in 0.0656 seconds.
# Simulation to t=78.00 sec completed in 0.0656 seconds.
# Simulation to t=79.00 sec completed in 0.0655 seconds.
# Simulation to t=80.00 sec completed in 0.0655 seconds.
# Simulation to t=81.00 sec completed in 0.0654 seconds.
# Simulation to t=82.00 sec completed in 0.0655 seconds.
# Simulation to t=83.00 sec completed in 0.0655 seconds.
# Simulation to t=84.00 sec completed in 0.0651 seconds.
# Simulation to t=85.00 sec completed in 0.0655 seconds.
# Simulation to t=86.00 sec completed in 0.0658 seconds.
# Simulation to t=87.00 sec completed in 0.0643 seconds.
# Simulation to t=88.00 sec completed in 0.0654 seconds.
# Simulation to t=89.00 sec completed in 0.0641 seconds.
# Simulation to t=90.00 sec completed in 0.0639 seconds.
# Simulation to t=91.00 sec completed in 0.0641 seconds.
# Simulation to t=92.00 sec completed in 0.0645 seconds.
# Simulation to t=93.00 sec completed in 0.0644 seconds.
# Simulation to t=94.00 sec completed in 0.0641 seconds.
# Simulation to t=95.00 sec completed in 0.0640 seconds.
# Simulation to t=96.00 sec completed in 0.0691 seconds.
# Simulation to t=97.00 sec completed in 0.0657 seconds.
# Simulation to t=98.00 sec completed in 0.0731 seconds.
# Simulation to t=99.00 sec completed in 0.0656 seconds.

# %%
ssa.exit_code
# Out:
# 0

# %%
# ssa.TDS.save_output()

# %%
# %run -i 'cosim_plot.py'

# %%
sse.plot_agc()
# Out:
# (<Figure size 600x300 with 1 Axes>,
#  <AxesSubplot:title={'center':'AGC response'}, xlabel='Time [H]', ylabel='Power (MW)'>)

# %%
# Complement AGC table
agc_smooth = pd.DataFrame(np.repeat(agc_in[list(np.arange(0, t_total, 4))].values, 4, axis=1),
                       columns=list(np.arange(0, t_total, 1)))

# Record output
sse_out = pd.DataFrame()
sse_out['time'] = sse.tss
sse_out['agc'] = agc_smooth.iloc[10]  # AGC input to EV
sse_out['Pr'] = sse.Prl
sse_out['Prc'] = sse.Prcl
sse_out.to_csv('sse_out.csv', index=False)

# %%
soc_plot = ev_soc[ev_agc.abs().sum(axis=1) > 0].reset_index(drop=True)
soc_plot = soc_plot[list(range(end_time+1))]

fig_soc, ax_soc = plt.subplots(figsize=(5, 4))
for i in range(soc_plot.shape[0]):
    ax_soc.plot(range(end_time+1), soc_plot.iloc[i])
ax_soc.set_xlabel('Time [s]')
ax_soc.set_ylabel('SOC [%]')
ax_soc.set_title('AGC EVs SOC')
ax_soc.set_xlim([0, end_time])
# Out:
# (0.0, 99.0)

# %%
sse.plot(style='ieee')
# Out:
# (<Figure size 3600x1800 with 2 Axes>,
#  <AxesSubplot:title={'center':'EVA'}, xlabel='Time [H]', ylabel='Power (MW)'>)
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'serif' not found because none of the following families were found: Times
