# %%
# %run -i 'cosim_import.py'
# Out:
# 1.7.2.post298.dev0+ge5e45819
# 2.9.0

# %% [markdown]
# `caseH` is the start time [H] of the co-simulation, now 10 and 18 are supported.

# %%
caseH = 18

# --- ANDES case ---
dir_path = os.path.abspath('..')
case_path = '/case/ieee39_eva.xlsx'
case = dir_path + case_path
ssa = andes.load(case,
                 setup=False,
                 no_output=True,
                 default_config=False)

# Set output mode as 'manual', turn off TDS progress bar
ssa.TDS.config.save_mode = 'manual'
ssa.TDS.config.no_tqdm = 1
ssa.TDS.criteria = 0

# Set load as constant load.
ssa.PQ.config.p2p = 1
ssa.PQ.config.q2q = 1
ssa.PQ.config.p2z = 0
ssa.PQ.config.q2z = 0
ssa.PQ.pq2z = 0

# Turn on ``numba`` can accelerate TDS.
ssa.config.numba = 1

ss2 = andes.load(case,
                 setup=False,
                 no_output=True,
                 default_config=False)

# Set output mode as 'manual', turn off TDS progress bar
ss2.TDS.config.save_mode = 'manual'
ss2.TDS.config.no_tqdm = 1
ss2.TDS.criteria = 0

# Set load as constant load.
ss2.PQ.config.p2p = 1
ss2.PQ.config.q2q = 1
ss2.PQ.config.p2z = 0
ss2.PQ.config.q2z = 0
ss2.PQ.pq2z = 0

# Turn on ``numba`` can accelerate TDS.
ss2.config.numba = 1
# Out:
# Working directory: "/home/jwang175/andes/jwang/notes"
# > Loaded config from file "/home/jwang175/.andes/andes.rc"
# > Loaded generated Python code in "/home/jwang175/.andes/pycode".
# Generated code for <PQ> is stale.
# Numerical code generation (rapid incremental mode) started...
# Generating code for 1 models on 6 processes.
# Saved generated pycode to "/home/jwang175/.andes/pycode"
# > Reloaded generated Python code of module "pycode".
# Generated numerical code for 1 models in 0.3297 seconds.
# Parsing input file "/home/jwang175/andes/jwang/case/ieee39_eva.xlsx"...
# Input file parsed in 0.1344 seconds.
# Working directory: "/home/jwang175/andes/jwang/notes"
# > Loaded config from file "/home/jwang175/.andes/andes.rc"
# > Reloaded generated Python code of module "pycode".
# Generated code for <PQ> is stale.
# Numerical code generation (rapid incremental mode) started...
# Generating code for 1 models on 6 processes.
# Saved generated pycode to "/home/jwang175/.andes/pycode"
# > Reloaded generated Python code of module "pycode".
# Generated numerical code for 1 models in 0.2715 seconds.
# Parsing input file "/home/jwang175/andes/jwang/case/ieee39_eva.xlsx"...
# Input file parsed in 0.1241 seconds.

# %%
# --- EV Aggregator ---
sse = ev_ssm(ts=caseH, N=2000, step=1, tp=40,
             lr=0.1, lp=60, seed=2022, name="EVA")
sse.load_A("Aest.csv")
# Out:
# EVA: ts=18[H], 2000 EVs, Total Q=17.46 MWh
# Online 585, Q=14.61 MWh, SoC=0.7862
# Power(MW): Pt=-1.4628, Pc=-1.4628, Pd=-0.0
# Ctrl: 0=336; 1=249;
# EVA: Load A from Aest.csv.

# %%
ssa.add('Toggler', dict(model="GENROU", dev='GENROU_2', t=1.0))
ss2.add('Toggler', dict(model="GENROU", dev='GENROU_2', t=1.0))

for i in range(sse.ev.shape[0]):
    ev_dict = {'bus':38, 'gen':'PV_10',
            'qmx': 10, 'qmn':-10, 'pmx':60, 'pmn':-70, 'pcap':1,
            'gammap': 1, 'gammaq': 1, 'En': 10, 'EtaC': 10, 'EtaD': 10, 
            'ddn':0, 'tip':0.02, 'tiq':0.02, 'ialim': 100, 'recflag':0,
            'pqflag':1, 'vrflag':0}
    ssa.add("EV2", ev_dict)
# TODO: alter gammap, gammpaq, pmx, pmn, EtaC, EtaD, En later on
ev_df = sse.ev.copy()
ev_df['p'] = -1 * ev_df['c'] * ev_df['Pc']
ev_df['gammap'] = ev_df['p'] / ev_df['p'].sum()
ev_df['gammaq'] = 1 / ev_df.u.sum()
ev_df['EtaC'] = ev_df['nc']
ev_df['EtaD'] = ev_df['nd']
ev_df['En'] = ev_df['Q'] / 1e3
ev_df['SOCinit'] = ev_df['soc'].replace(1, 0.999)
# ev_df['pmx'] = ev_df['Pc'] / 1e3 / ssa.config.mva
# ev_df['pmn'] = -1 * ev_df['Pc'] / 1e3 / ssa.config.mva
ev_df['u'] = ev_df['u']

ev_idx = ssa.EV2.idx.v
ssa.DG.set(attr='v', idx=ev_idx, src='gammap', value=ev_df['gammap'].values)
ssa.DG.set(attr='v', idx=ev_idx, src='gammaq', value=ev_df['gammaq'].values)
ssa.DG.set(attr='v', idx=ev_idx, src='EtaC', value=ev_df['EtaC'].values)
ssa.DG.set(attr='v', idx=ev_idx, src='EtaD', value=ev_df['EtaD'].values)
ssa.DG.set(attr='v', idx=ev_idx, src='En', value=ev_df['En'].values)
ssa.DG.set(attr='v', idx=ev_idx, src='SOCinit', value=ev_df['SOCinit'].values)
ssa.DG.set(attr='v', idx=ev_idx, src='u', value=ev_df['u'].values)

# TODO: alter PV_10.p0
p0 = ev_df['p'].sum() / 1e3 / ssa.config.mva
ssa.StaticGen.set(src='p0', attr='v', idx='PV_10', value=p0)
ssa.setup()
ssa.PFlow.run()
ssa.TDS.init()

ev0_dict = {'bus':38, 'gen':'PV_10',
        'qmx': 10, 'qmn':-10, 'pmx':60, 'pmn':-70, 'pcap':1,
        'gammap': 1, 'gammaq': 1, 'En': 10, 'EtaC': ev_df['EtaC'].mean(), 'EtaD': ev_df['EtaD'].mean(), 
        'ddn':0, 'tip':0.02, 'tiq':0.02, 'ialim': 100, 'recflag':0,
        'pqflag':1, 'vrflag':0}

ss2.add("EV2", ev0_dict)
ss2.setup()
ss2.StaticGen.set(src='p0', attr='v', idx='PV_10', value=p0)
ss2.PFlow.run()
xx = ss2.TDS.init()
# Out:
# ACEc <1> added BusFreq <BusFreq_11> linked to bus <1>
# System internal structure set up in 0.0696 seconds.
# -> System connectivity check results:
#   No islanded bus detected.
#   System is interconnected.
#   Each island has a slack bus correctly defined and enabled.
#
# -> Power flow calculation
#            Numba: On
#    Sparse solver: KLU
#  Solution method: NR method
# Numba compilation initiated with caching.
# Power flow initialized in 0.2831 seconds.
# 0: |F(x)| = 7.561249598
# 1: |F(x)| = 2.916475667
# 2: |F(x)| = 0.1312856926
# 3: |F(x)| = 0.0003490305806
# 4: |F(x)| = 4.217775906e-09
# Converged in 5 iterations in 0.0112 seconds.
# Numba compilation initiated with caching.
# GENROU (xl <= xd2) out of typical upper limit.
#
#    idx     | values | limit
# -----------+--------+------
#  GENROU_1  | 0.014  | 0.001
#  GENROU_3  | 0.018  | 0.003
#  GENROU_4  | 0.013  | 0.001
#  GENROU_5  | 0.014  | 0.001
#  GENROU_7  | 0.015  | 0.002
#  GENROU_8  | 0.015  | 0.006
#  GENROU_9  | 0.009  | 0.001
#  GENROU_10 | 0.013  | 0.000
#
#
# Initialization for dynamics completed in 0.5040 seconds.
# Initialization was successful.
# ACEc <1> added BusFreq <BusFreq_11> linked to bus <1>
# System internal structure set up in 0.0608 seconds.
# -> System connectivity check results:
#   No islanded bus detected.
#   System is interconnected.
#   Each island has a slack bus correctly defined and enabled.
#
# -> Power flow calculation
#            Numba: On
#    Sparse solver: KLU
#  Solution method: NR method
# Numba compilation initiated with caching.
# Power flow initialized in 0.0883 seconds.
# 0: |F(x)| = 7.561249598
# 1: |F(x)| = 2.916475667
# 2: |F(x)| = 0.1312856926
# 3: |F(x)| = 0.0003490305806
# 4: |F(x)| = 4.217775906e-09
# Converged in 5 iterations in 0.0149 seconds.
# Numba compilation initiated with caching.
# GENROU (xl <= xd2) out of typical upper limit.
#
#    idx     | values | limit
# -----------+--------+------
#  GENROU_1  | 0.014  | 0.001
#  GENROU_3  | 0.018  | 0.003
#  GENROU_4  | 0.013  | 0.001
#  GENROU_5  | 0.014  | 0.001
#  GENROU_7  | 0.015  | 0.002
#  GENROU_8  | 0.015  | 0.006
#  GENROU_9  | 0.009  | 0.001
#  GENROU_10 | 0.013  | 0.000
#
#
# Initialization for dynamics completed in 0.4327 seconds.
# Initialization was successful.

# %%
for end_time in range(1, 30):
    sse.run(tf=caseH+end_time/3600, Pi=0,
            is_updateA=False, is_rstate=True,
            is_test=False, disable=True)
    ssa.DG.set(attr='v', idx=ev_idx, src='u', value=sse.ev['u'].values)
    ssa.DG.set(attr='v', idx=ev_idx, src='pref0',
               value=list(-1 * sse.ev['c'] * sse.ev['Pc'] / ssa.config.mva / 1e3))
    ss2.DG.set(attr='v', idx='EV2_1', src='pref0',
               value=np.sum(-1 * sse.ev['c'] * sse.ev['Pc'] / ssa.config.mva / 1e3))
    
    ssa.TDS.config.tf = end_time
    ss2.TDS.config.tf = end_time
    ssa.TDS.run()
    ss2.TDS.run()
    
    if ssa.exit_code != 0 | ss2.exit_code != 0:
        break
# Out:
# -> Time Domain Simulation Summary:
# Sparse Solver: KLU
# Simulation time: 0.0-1 s.
# Fixed step size: h=33.33 ms. Shrink if not converged.
# Simulation to t=1.00 sec completed in 0.2160 seconds.
#
# -> Time Domain Simulation Summary:
# Sparse Solver: KLU
# Simulation time: 0.0-1 s.
# Fixed step size: h=33.33 ms. Shrink if not converged.
# Simulation to t=1.00 sec completed in 0.0505 seconds.
# <Toggler Toggler_2>: GENROU.GENROU_2 status changed to 0 at t=1.0 sec.
# <Toggler Toggler_2>: GENROU.GENROU_2 status changed to 0 at t=1.0 sec.
# Simulation to t=2.00 sec completed in 0.7579 seconds.
# Simulation to t=2.00 sec completed in 0.2096 seconds.
# Simulation to t=3.00 sec completed in 0.6876 seconds.
# Simulation to t=3.00 sec completed in 0.1807 seconds.
# Simulation to t=4.00 sec completed in 0.6764 seconds.
# Simulation to t=4.00 sec completed in 0.2115 seconds.
# Simulation to t=5.00 sec completed in 0.5922 seconds.
# Simulation to t=5.00 sec completed in 0.1645 seconds.
# Simulation to t=6.00 sec completed in 0.5127 seconds.
# Simulation to t=6.00 sec completed in 0.1485 seconds.
# Simulation to t=7.00 sec completed in 0.4545 seconds.
# Simulation to t=7.00 sec completed in 0.2114 seconds.
# Simulation to t=8.00 sec completed in 0.5004 seconds.
# Simulation to t=8.00 sec completed in 0.1326 seconds.
# Simulation to t=9.00 sec completed in 0.4802 seconds.
# Simulation to t=9.00 sec completed in 0.1199 seconds.
# Simulation to t=10.00 sec completed in 0.4432 seconds.
# Simulation to t=10.00 sec completed in 0.1571 seconds.
# Simulation to t=11.00 sec completed in 0.5326 seconds.
# Simulation to t=11.00 sec completed in 0.1228 seconds.
# Simulation to t=12.00 sec completed in 0.4385 seconds.
# Simulation to t=12.00 sec completed in 0.1206 seconds.
# Simulation to t=13.00 sec completed in 0.4052 seconds.
# Simulation to t=13.00 sec completed in 0.0905 seconds.
# Simulation to t=14.00 sec completed in 0.2614 seconds.
# Simulation to t=14.00 sec completed in 0.0746 seconds.
# Simulation to t=15.00 sec completed in 0.3755 seconds.
# Simulation to t=15.00 sec completed in 0.1057 seconds.
# Simulation to t=16.00 sec completed in 0.3765 seconds.
# Simulation to t=16.00 sec completed in 0.1082 seconds.
# Simulation to t=17.00 sec completed in 0.2472 seconds.
# Simulation to t=17.00 sec completed in 0.0733 seconds.
# Simulation to t=18.00 sec completed in 0.2589 seconds.
# Simulation to t=18.00 sec completed in 0.0715 seconds.
# Simulation to t=19.00 sec completed in 0.2725 seconds.
# Simulation to t=19.00 sec completed in 0.0807 seconds.
# Simulation to t=20.00 sec completed in 0.2666 seconds.
# Simulation to t=20.00 sec completed in 0.0861 seconds.
# Simulation to t=21.00 sec completed in 0.2472 seconds.
# Simulation to t=21.00 sec completed in 0.0690 seconds.
# Simulation to t=22.00 sec completed in 0.2485 seconds.
# Simulation to t=22.00 sec completed in 0.0832 seconds.
# Simulation to t=23.00 sec completed in 0.2688 seconds.
# Simulation to t=23.00 sec completed in 0.0775 seconds.
# Simulation to t=24.00 sec completed in 0.2647 seconds.
# Simulation to t=24.00 sec completed in 0.0765 seconds.
# Simulation to t=25.00 sec completed in 0.2574 seconds.
# Simulation to t=25.00 sec completed in 0.0724 seconds.
# Simulation to t=26.00 sec completed in 0.2927 seconds.
# Simulation to t=26.00 sec completed in 0.0777 seconds.
# Simulation to t=27.00 sec completed in 0.3014 seconds.
# Simulation to t=27.00 sec completed in 0.0765 seconds.
# Simulation to t=28.00 sec completed in 0.2613 seconds.
# Simulation to t=28.00 sec completed in 0.0768 seconds.
# Simulation to t=29.00 sec completed in 0.2585 seconds.
# Simulation to t=29.00 sec completed in 0.1064 seconds.

# %%
# calcualte output power
ia = ssa.dae.ts.x[:, ssa.EV2.Ipout_y.a]
va = ssa.dae.ts.y[:, ssa.EV2.v.a]
pa = np.sum(ia * va * ssa.config.mva, axis=1)

i2 = ss2.dae.ts.x[:, ss2.EV2.Ipout_y.a]
v2 = ss2.dae.ts.y[:, ss2.EV2.v.a]
p2 = np.sum(i2 * v2 * ssa.config.mva, axis=1)

# %%
plt.style.use("ieee")
fig, ax = plt.subplots(1, 2, figsize=(10, 4))
ax[0].plot(ssa.dae.ts.t, pa, label="Case1", color="tab:blue")
ax[0].plot(ssa.dae.ts.t, p2, label="Case2", color="tab:green", linestyle="--")
# ax[0].plot(3600*(np.array(sse.tss)-caseH), sse.Ptl, color="tab:orange", linestyle="-.", label="Case3")
ax[0].legend()
ax[0].set_xlim([0, end_time])
ax[0].set_xlabel("Time [s]")
ax[0].set_ylabel("Output Power [MW]")
ax[0].legend(frameon=False)
ssa.TDS.plt.plot(ssa.COI.omega, ytimes=60, ax=ax[1], fig=fig, yheader=['Case1'],
                 color="tab:blue", show=False)
ss2.TDS.plt.plot(ss2.COI.omega, ytimes=60, ax=ax[1], fig=fig, yheader=["Case2"],
                 color="tab:green",  linestyles=['--'], show=False)
ax[1].set_ylabel('Freq. [Hz]')
# ax[1].plot(ssa.dae.ts.t, ssa.COI.omega, label="ANDES + Individual", color="tab:blue")
# ax[1].plot(ssa.dae.ts.t, p2, label="ANDES + Aggregated", color="tab:green", linestyle="--")
# ax[1].legend()
# Out:
# Text(3033.954843004098, 0.5, 'Freq. [Hz]')
