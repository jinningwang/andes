# %% [markdown]
# # RTED-TDS Co-Sim
#
# Test parameters of AGC when there is EV2 but no EVA.

# %% [markdown]
# ## Import case

# %%
import os
os.chdir('../')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import andes
from andes.interop.pandapower import to_pandapower, make_link_table, runopp_map
from andes.interop.pandapower import add_gencost
andes.config_logger(stream_level=20)

import pandapower as pp

from jams import rted2, rted3

from ev_ssm import ev_ssm

print(andes.__version__)
print(pp.__version__)

caseH = 10

# --- ANDES case ---
dir_path = os.path.abspath('..')
case_path = '/case/ieee39_ev2.xlsx'
case = dir_path + case_path
ssa = andes.load(case, 
                 setup=True,
                 no_output=True,
                 default_config=False)

# Set output mode as 'manual', turn off TDS progress bar
ssa.TDS.config.save_mode = 'manual'
ssa.TDS.config.no_tqdm = 1

# Set load as constant load.
ssa.PQ.config.p2p = 1
ssa.PQ.config.q2q = 1
ssa.PQ.config.p2z = 0
ssa.PQ.config.q2z = 0
ssa.PQ.pq2z = 0

# Turn on ``numba`` can accelerate TDS.
ssa.config.numba = 1
# Out:
# Working directory: "/Users/jinningwang/Documents/work/andes/jwang/notes"
# > Loaded config from file "/Users/jinningwang/.andes/andes.rc"
# > Loaded generated Python code in "/Users/jinningwang/.andes/pycode".
# Generated code for <PQ> is stale.
# Numerical code generation (rapid incremental mode) started...
# 0.post4489.dev0+g346a428
# 2.8.0
# Generating code for 1 models on 8 processes.
# Saved generated pycode to "/Users/jinningwang/.andes/pycode"
# > Reloaded generated Python code of module "pycode".
# Generated numerical code for 1 models in 0.1397 seconds.
# Parsing input file "/Users/jinningwang/Documents/work/andes/jwang/case/ieee39_ev2.xlsx"...
# Input file parsed in 0.0636 seconds.
# System internal structure set up in 0.0223 seconds.

# %%
# --- read load from ssa ---
ptotal = ssa.PQ.as_df()['p0'].sum()
print('ANDES total load is:',ptotal.round(4),'p.u.')

# --- scale load curve ---
ddata_path = '/case/dsyn.csv'
ddata = dir_path + ddata_path
d_syn = pd.read_csv(ddata)

caseH = 18

np.random.seed(2022)
col = ['h10', 'h18', 'a10', 'a18']
col1 = ['h10', 'h18']
col2 = ['a10', 'a18']
# d_syn['a10'].iloc[200:650] *= 0.5
d_syn[col1] = (d_syn[col1] - d_syn[col1].min()) / d_syn[col1].min() + 0.8
d_syn[col2] = (d_syn[col2] - d_syn[col2].mean()) / (d_syn[col2].max() - d_syn[col2].min())

if caseH == 10:
    k = 0.4  # the coefficient can be adjusted to fit the case
    d_syn['s10'] = d_syn['h10'] + k * d_syn['a10']
    d_syn['s18'] = d_syn['h18'] + k * d_syn['a18']
    d_syn['sload'] = d_syn['s10']
    # d_syn['sload'] = d_syn['sload'].rolling(10).mean().interpolate(method='polynomial', order=1, inplace=False)
    # d_syn['sload'].iloc[0:310] -= 0.05 * k / 0.3
    # # d_syn['sload'].iloc[250:350] = None
    # # d_syn['sload'].iloc[250:350].interpolate(method='polynomial', order=3, inplace=True)
    # d_syn['sload'].iloc[400:650] += 2 * (0.8 - d_syn['sload'].iloc[300:600])
    # d_syn['sload'].iloc[600:900] += 0.02 * k / 0.3
    # # d_syn['sload'].iloc[450:650] = None
    # # d_syn['sload'].iloc[450:650].interpolate(method='polynomial', order=9, inplace=True)
    # d_syn['sload'].iloc[900:1200] += 0.03 * k / 0.3
    # d_syn['sload'].iloc[1200:1800] -= 0.06 * k / 0.3
    # d_syn['sload'].iloc[2100:2400] += 0.02 * k / 0.3
    # d_syn['sload'].iloc[2700:3000] -= 0.03 * k / 0.3
    # d_syn['sload'].iloc[3300:3600] += 0.05 * k / 0.3
if caseH == 18:
    k = 0.3  # the coefficient can be adjusted to fit the case
    d_syn['s10'] = d_syn['h10'] + k * d_syn['a10']
    d_syn['s18'] = d_syn['h18'] + k * d_syn['a18']
    d_syn['sload'] = d_syn['s10']
    d_syn['sload'].iloc[0:300] -= 0.2 * k
    # d_syn['sload'].iloc[200:700] = d_syn['sload'].iloc[200:700].rolling(80).mean()

    # d_syn['sload'] = d_syn['sload'].rolling(10).mean().interpolate(method='polynomial', order=1, inplace=False)
    # d_syn['sload'].iloc[100:600] = d_syn['sload'].iloc[100:600].rolling(10).mean().interpolate(method='polynomial', order=1, inplace=False)

# calculate expected load
step = 300
d_exp = d_syn.groupby(d_syn.index // step).mean().copy()
d_exp['time'] = range(0,3600,300)

# # align starting point of load with starting point of dispatch results
d_syn['sload'].iloc[0] = d_exp['sload'].iloc[0]
d_syn['sload'].iloc[1:50] = None
d_syn['sload'].interpolate(method='linear', inplace=True)

# --- plot load curve ---
fig_load, ax_load = plt.subplots(figsize=(5, 4))
ax_load.plot(d_syn['time'], d_syn['sload'], color='tab:blue', linestyle='-')
ystep = list(d_exp['sload'])
ystep.insert(0, d_exp['sload'].iloc[0])
ax_load.step(range(0,3900,300), ystep, color='tab:blue', linestyle='--')
ax_load.set_xlim([0, 3600])
ax_load.legend(['Actual load', 'Forecasted load'])
ax_load.set_title(f'Load profile at {caseH}H')
ax_load.set_ylabel('ratio')
ax_load.set_xlabel('Time [s]')
# Out:
# ANDES total load is: 58.564 p.u.
# Text(0.5, 0, 'Time [s]')

# %%
d_syn['sload'].iloc[100:500].plot()
# Out:
# <AxesSubplot:>

# %%
d_syn['sload'].iloc[200:400].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Setup ``ssp`` and ``ssd``

# %%
# --- set up EV generator data ---
ev_idx = 'PV_10'
ssa.PV.set(src='p0', idx=ev_idx, attr='v', value=30 / ssa.config.mva)
ssa.PV.set(src='pmax', idx=ev_idx, attr='v', value=99999 / ssa.config.mva)
ssa.PV.set(src='pmin', idx=ev_idx, attr='v', value=-99999 / ssa.config.mva)

# --- setup pandapower: ssp ---
ssp = to_pandapower(ssa)

# set EV generator as uncontrollable
ssp.gen.controllable.iloc[9] = False

# add gen cost, unit: $/MWh; G1-11. G10 EV, G11 Slack; 
# set EV as -10, for the cost of SFR mileage
c1 = [20, 20, 20, 20, 20, 20, 20, 20, 20, -10, 20]
c0 = [500, 380, 42, 380, 295, 400, 350, 330, 490, 0000, 550]
c2 = [0.014, 0.020, 0.194, 0.020, 0.0255, 0.0210, 0.230, 0.0222, 0.0150, 0.000, 0.0300]
gen_cost = np.array([[2., 0., 0., 3., 0., 0., 0.]] * ssp.gen.shape[0])
gen_cost[:, 4] = np.array(c2) / ssa.config.mva
gen_cost[:, 5] = np.array(c1) / ssa.config.mva
gen_cost[:, 6] = np.array(c0) / ssa.config.mva

add_gencost(ssp, gen_cost)

# --- setup RTED: ssd ---
ssd = rted3(name='RTED', OutputFlag=0)
ssd.from_andes(ssa)
ssd.build()

# set EV generator as uncontrollable
ssd.gen.ctrl.loc[ev_idx] = 0

# set EV geenrator as type2
prumax = 0
prdmax = 0
ssd.def_type2([ev_idx], [prumax], [prdmax])

# Case data comes from a MPCE
# https://ieeexplore.ieee.org/document/9018441
# set ramp_5
ramp_15 = [156, 120, 130, 110, 80, 105, 90, 90, 150, 99999, 200]
# ramp_hour = [80, 80, 80, 50, 50, 50, 30, 30, 30, 999, 30]
ssd.gen['ramp_5'] = 10 * np.array(ramp_15) / 3 / ssd.mva

# set cost
ssd.cost['c1'] = c1
ssd.cost['c2'] = c2
ssd.cost['c0'] = c0

# adjust SFR cost of EV lower than SynGen
ssd.cost['cru'] = [0] * ssd.gen.shape[0]
ssd.cost['cru'].loc[ev_idx] = -1
ssd.cost['crd'] = ssd.cost.cru

# --- benchmark ssd with ssp using DCOPF ---
pp.rundcopp(ssp)
dc_comp = ssp.res_gen.copy()
gb_res = ssd.solve(disable_sfr=True, disable_ramp=True, info=False)
dc_comp['p_mw(GB)'] = ssd.mva * gb_res['pg'].values
print(f"pp cost={ssp.res_cost}, gb cost={ssd.res_cost}")
# Out:
# -> System connectivity check results:
#   No islanded bus detected.
#   System is interconnected.
#   Each island has a slack bus correctly defined and enabled.
#
# -> Power flow calculation
#            Numba: On
#    Sparse solver: KLU
#  Solution method: NR method
# Numba compilation initiated with caching.
# Power flow initialized in 0.0852 seconds.
# 0: |F(x)| = 7.801234474
# 1: |F(x)| = 3.497456094
# 2: |F(x)| = 0.1830765786
# 3: |F(x)| = 0.0007183022492
# 4: |F(x)| = 1.659284843e-08
# Converged in 5 iterations in 0.0038 seconds.
# Power flow results are consistent. Conversion is successful.
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-04-08
# -> System connectivity check results:
#   No islanded bus detected.
#   System is interconnected.
#   Each island has a slack bus correctly defined and enabled.
#
# -> Power flow calculation
#            Numba: On
#    Sparse solver: KLU
#  Solution method: NR method
# Numba compilation initiated with caching.
# Power flow initialized in 0.0044 seconds.
# 0: |F(x)| = 7.801234474
# 1: |F(x)| = 3.497456094
# 2: |F(x)| = 0.1830765786
# 3: |F(x)| = 0.0007183022492
# 4: |F(x)| = 1.659284843e-08
# Converged in 5 iterations in 0.0039 seconds.
# Power flow results are consistent. Conversion is successful.
# GSF is consistent.
# RTED GB model is loaded.
# RTED removed: ['rampu', 'rampd']
# RTED limited: sfru, sfrd
# RTED: total cost=4889.131
# pp cost=2184.5741560778906, gb cost=4889.131241556355

# %%
dc_comp
# Out:
#           p_mw      q_mvar  va_degree  vm_pu    p_mw(GB)
# 0   970.031255   39.975645  15.883073    1.0  970.031250
# 1   645.999994  228.920849   2.228140    1.0  646.000000
# 2   290.000000   81.098706  -0.865261    1.0  290.000000
# 3   651.999992  114.224547   7.298529    1.0  652.000000
# 4   507.999994  137.957637   5.467236    1.0  508.000000
# 5   646.687502  212.087094   6.419596    1.0  646.687500
# 6   232.000000   55.288376   3.437886    1.0  232.000000
# 7   563.999997  -59.894996  13.953432    1.0  564.000000
# 8   864.999994   97.797233  18.946245    1.0  865.000000
# 9    30.000000    1.955945  18.946245    1.0   30.000000
# 10  452.681272 -152.198765   0.000000    1.0  452.681252

# %% [markdown]
# ## Prepare

# %% [markdown]
# ### Make link table

# %%
# --- link_table ---
ssa_key = make_link_table(ssa)

# --- add controllable in the link table ---
ssa_bus = ssa.Bus.as_df().reset_index().rename(columns={'uid':'bus_pp', 'idx':'bus_idx'})
ssp_gen = ssp.gen.reset_index().rename(columns={'index':'gen_pp', 'name':'stg_idx', 'controllable':'ctrl'})
ssa_key2 = pd.merge(left=ssa_key,
                    right=ssp_gen[['stg_idx', 'gen_pp', 'ctrl']],
                    on='stg_idx', how='left')

# --- device idx ---
ssa_dg_idx = ssa_key2.dg_idx.dropna().tolist()
ssa_syg_idx = ssa_key2.syg_idx.dropna().tolist()
ssa_gov_idx = ssa_key2.gov_idx.dropna().tolist()
ssa_stg_idx = ssa_key2.stg_idx.dropna().tolist()

# --- online and controllable device idx ---
ctrl_cond = ssa_key2.ctrl & ssa_key2.stg_u.astype(bool)
ssa_dg_idx_ctrl = ssa_key2.dg_idx[ctrl_cond].dropna().tolist()
ssa_syg_idx_ctrl = ssa_key2.syg_idx[ctrl_cond].dropna().tolist()
ssa_gov_idx_ctrl = ssa_key2.gov_idx[ctrl_cond].dropna().tolist()
ssa_stg_idx_ctrl = ssa_key2.stg_idx[ctrl_cond].dropna().tolist()

# fill NaN with False
ssa_key2.fillna(value=False, inplace=True)

# %% [markdown]
# ## Loop

# %%
# Change ``rru``, ``rrd``, ``rsfr``, ``t_total`` for necessary.
t_total = 3600

rru, rrd, rsfr = 0.0, 0.0, 0.2

# Define functions and constants used in loop
# --- def. functions ---

def get_pe(ssa, gov_idx, dg_idx, ssa_key2):
    """Get the active power (TurbineGov/DG) after TDS, a DataFrame"""
    # TODO: may need to sum the power of same StaticGen
    # --- TurbineGov --- 
    pe_syg = ssa.TurbineGov.get(src='pout', idx=gov_idx, attr='v')
    # --- DG ---
    Ip_dg = ssa.DG.get(src='Ipout_y', idx=dg_idx, attr='v')
    v_dg = ssa.DG.get(src='v', idx=dg_idx, attr='v')
    pe_dg = Ip_dg*v_dg
    # --- out ---
    pe = pd.DataFrame()
    pe['idx'] = gov_idx + dg_idx
    pe['pe'] = np.concatenate((pe_syg, pe_dg))
    ldf = pd.merge(left=ssa_key2.rename(columns={'dg_idx':'idx'}),
         right=pe, how='right', on='idx')
    rdf = pd.merge(left=ssa_key2.rename(columns={'gov_idx':'idx'}),
             right=pe, how='right', on='idx')
    pe['stg_idx'] = ldf['stg_idx'].fillna('') + rdf['stg_idx'].fillna('')
    return pe

def dp_calc(d_syn, idx_ed, intv_ed, ratio=0.1):
    """Calc SFR requirements, scalars, ``dpd_u``and ``dpd_d``, and load forecasted value ``load_exp``"""
    load = d_syn['sload'].iloc[idx_ed*intv_ed:(idx_ed*intv_ed + intv_ed)]
    load_exp = load.mean()
    load_d = load_exp * ratio
    load_u = load_exp * ratio
    return load_u, load_d, load_exp

# --- co-sim constants ---

# length of each interval
intv_ed = 300  # RTED interval, 300s
intv_agc = 4    # AGC interval, 4s
intv_pq = 1     # PQ interval, 1s; alter load and AGC
intv_step = 50 # step change interval; smooth the setpoitns

# number of each interval
n_ed = int(t_total/intv_ed)
n_agc = int(intv_ed/intv_agc)
n_pq = int(intv_agc/intv_pq)
n_step = np.floor(intv_step/intv_agc)

# --- vars ---
# AGC table
agc_table = ssa_key2[['stg_idx', 'dg_idx', 'rg_idx', 'syg_idx', 
                      'exc_idx', 'gov_idx', 'gammap', 'ctrl']]
dc_res = ssd.res
agc_table = agc_table.merge(dc_res[['gen', 'bu', 'bd']].rename(columns={'gen': 'stg_idx'}),
                            on='stg_idx', how='left')
agc_table['paux'] = 0

# AGC power of each unit
agc_in = pd.DataFrame(columns=['stg_idx'] + list(np.arange(0, t_total, 4)))
agc_in['stg_idx'] = agc_table['stg_idx']
agc_out = agc_in.copy()

# ACE vars for PI controller
ACE_integral = 0
ACE_raw = 0
Kp = 0.1 # 0.05
Ki = 0.1
# SFR boundary and total AGC input
sfr_res_data = -1 * np.ones((int(np.ceil(t_total / intv_agc)), 5))

# initial load value
ssa_p0 = ssa.PQ.p0.v.copy()
ssa_q0 = ssa.PQ.q0.v.copy()
ssa_pq_idx = ssa.PQ.idx.v
ssa_p0_sum = ssa_p0.sum()

# idx
ac_res = runopp_map(ssp, ssa_key)
# adjust agc_table sequence
agc_table = pd.merge(left=ac_res[["stg_idx"]], right=agc_table,
                     how="left", on="stg_idx")

cond_sch_gov = ac_res.gov_idx.fillna(False).astype(bool)
cond_sch_dg = ac_res.dg_idx.fillna(False).astype(bool)
cond_agc_gov = agc_table.ctrl * agc_table.gov_idx.fillna(False).astype(bool)
cond_agc_dg = agc_table.ctrl * agc_table.dg_idx.fillna(False).astype(bool)
cond_agc_dg = cond_sch_dg  # DEBUG

sch_gov_idx = ac_res.gov_idx[cond_sch_gov].tolist()
sch_dg_idx = ac_res.dg_idx[cond_sch_dg].tolist()
agc_gov_idx = agc_table.gov_idx[cond_agc_gov].tolist()
agc_dg_idx = agc_table.dg_idx[cond_agc_dg].tolist()

# dispatch results
rted_res = {}

# %%
# EV load data
evp = pd.read_csv("cosim_18_S_EV.csv")["Pt"].values
evp = np.append(evp, evp[-1])

# EV beta data
evbu = pd.read_csv("cosim_18_F_bu.csv")["PV_10"].values
evbd = pd.read_csv("cosim_18_F_bd.csv")["PV_10"].values

# Reserve some capacity to avoid TDS crush
ssp.gen.max_p_mw = ssp.gen.max_p_mw

# store original generator data
ssp_gen0 = ssp.gen.copy()

ssp.gen['p_mw'][ssp.gen.name==ev_idx] = evp[0]
ssd.gen['p0'][ssd.gen.idx == ev_idx] = evp[0] / ssd.mva
ssa.StaticGen.set(src='p0', attr='v', idx=ev_idx, value=evp[0] / ssa.config.mva)

for end_time in range(t_total):  # t_total
    # --- interval RTED ---
    if end_time % intv_ed == 0:
        idx_ed = end_time // intv_ed
        # --- update load ---
        sfrur, sfrdr, load_exp = dp_calc(d_syn, idx_ed, intv_ed, rsfr)
        ssp.load['scaling'] = load_exp
        ssp.gen['p_mw'][ssp.gen.name==ev_idx] = evp[end_time]
        ssd.gen['p0'][ssd.gen.idx == ev_idx] = evp[end_time] / ssd.mva
        ssd.load['sf'] = load_exp
        ssd.update_dict()

        # --- RTED, update gen limits after SFR ---
        # set previous setpoints with `pe` from TDS
        if end_time > 0:
            pe_tds = get_pe(ssa, ssa_gov_idx, ssa_dg_idx, ssa_key2)
            pe_tds = pe_tds.merge(ssa_key2, on='stg_idx',
                                  how='right').groupby('stg_idx', as_index=False).sum()
            vl = pd.merge(left=ssd.gen, how='left', on='idx',
                          right=pe_tds[['stg_idx', 'pe']].rename(columns={'stg_idx': 'idx'}))['pe']
            ssd.gen.p_pre = vl.values

        # def. percentage of EV SFR capacities
        ssd.def_type2([ev_idx], [999], [999])
        ssd.def_sfr(sfrur=sfrur*ssa_p0_sum, sfrdr=sfrdr*ssa_p0_sum)

        # solve RTED
        if end_time == 0:
            dc_res = ssd.solve(disable_ramp=True)
        else:
            dc_res = ssd.solve()

        # reserve SFR and ramp from Generator limits in ``ssp``
        ssp_gen = pd.merge(left=ssp.gen.rename(columns={'name': 'stg_idx'}),
                           right=dc_res.rename(columns={'gen': 'stg_idx'}),
                           on='stg_idx', how='left')
        # SFR limits
        ssp_gen['max_sfr'] = ssp_gen.max_p_mw - ssp_gen.pru * ssp.sn_mva
        ssp_gen['min_sfr'] = ssp_gen.min_p_mw + ssp_gen.prd * ssp.sn_mva
        # ramp limits
        if end_time > 0:
            p_pre_pp = pd.merge(left=ssp.gen.rename(columns={'name': 'stg_idx'}),
                                right=pe_tds[['stg_idx', 'pe']],
                                on='stg_idx', how='left')['pe']
            ssp_gen['max_ramp'] = ssp.sn_mva * (np.array(p_pre_pp) + np.array(ssd.gen['ramp_5']))
            ssp_gen['min_ramp'] = ssp.sn_mva * (np.array(p_pre_pp) - np.array(ssd.gen['ramp_5']))
            # alter generator limits
            ssp.gen.max_p_mw = ssp_gen[['max_sfr', 'max_ramp']].min(axis=1)
            ssp.gen.min_p_mw = ssp_gen[['min_sfr', 'min_ramp']].max(axis=1)
        else:
            # alter generator limits
            ssp.gen.max_p_mw = ssp_gen['max_sfr']
            ssp.gen.min_p_mw = ssp_gen['min_sfr']

        # --- ACOPF, modify setpoints ---
        # store setpoints
        if end_time > 0:
            p0 = ac_res['p'].values  # store setpoints
        else:
            p0 = [0] * ssa_key2.shape[0]

        # solve ACOPF
        ac_res = runopp_map(ssp, ssa_key)  # ACOPF resutls
        ac_res['p0'] = p0                  # last setpoints
        ac_res.fillna(False, inplace=True)  # Fill NA wil False

        # reset Generator limtis to normal limits
        ssp.gen.max_p_mw = ssp_gen0.max_p_mw
        ssp.gen.min_p_mw = ssp_gen0.min_p_mw

        # store dispatch results
        dc_res_copy = dc_res.copy()
        dc_res_copy['pg'] = ac_res.p
        rted_res[idx_ed] = dc_res_copy.T.to_dict()

    # --- interval AGC ---
    if end_time % intv_agc == 0:
        idx_agc = end_time // intv_agc - idx_ed * n_agc
        # --- allocate AGC ---
        # assign participation factor `bu`, `bd`
        agc_table.drop(['bu', 'bd'], axis=1, inplace=True)
        agc_table = agc_table.merge(dc_res[['gen', 'bu', 'bd']].rename(columns={'gen': 'stg_idx'}),
                                    on='stg_idx', how='left')
        # calc. AGC ---
        ACE_input = min(ACE_raw, dc_res.pru.sum())
        if ACE_raw >= 0:
            ACE_input = min(ACE_raw, dc_res.pru.sum())
            agc_table['paux'] = ACE_input * agc_table['bu'] * agc_table['gammap']
        else:
            ACE_input = max(ACE_raw, -1 * dc_res.prd.sum())
            agc_table['paux'] = ACE_input * agc_table['bd'] * agc_table['gammap']
        agc_in[end_time] = agc_table['paux']
        sfr_res_data[end_time // intv_agc] = [end_time, ACE_raw, dc_res.pru.sum(),
                             -1*dc_res.prd.sum(), ACE_input]

        # --- record AGC ---
        if end_time > 0:
            gref = ssa.TurbineGov.get(src='pref', attr='v', idx=agc_gov_idx)
            gout = ssa.TurbineGov.get(src='pout', attr='v', idx=agc_gov_idx)
            g_aux = gout - gref
            agc_out[end_time] = np.append(g_aux, [0/ssa.config.mva])

        # --- assign AGC ---
        # a.SynGen
        # Note: now the condition is controllable & has governor
        ssa.TurbineGov.set(src='paux0', idx=agc_gov_idx, attr='v',
                           value=agc_table["paux"][cond_agc_gov].values)
        # b.DG;
        ssa.DG.set(src='Pext0', idx=agc_dg_idx, attr='v',
                   value=agc_table["paux"][cond_agc_dg].values)
        # c.EV;
        # Note: EV is in group DG, remove EV set if not used for EV SSM
        sse_agc = ssa.config.mva * agc_table[agc_table.stg_idx == ev_idx].paux.values
        # TODO: RenGen

        # --- smooth setpoints ---
        if idx_ed == 0:
            ac_res['pref'] = ac_res['p']
        else:
            if idx_agc == 0:
                # record `pe` from TDS in the first AGC interval
                copy = ac_res.merge(right=pe_tds[['pe', 'stg_idx']], on='stg_idx', how='left')
                ac_res['pe_tds'] = copy.pe
            idx_step = min((end_time - idx_ed * intv_ed) // intv_agc + 1, n_step)
            ac_res['pref_step'] = ac_res.p - ac_res.p0
            # smooth change threshold: 0.01
            large_index = ac_res['pref_step'][abs(ac_res['pref_step']) > 0.01].index
            ac_res['pref_delta'] = ac_res['pref_step']
            ac_res['pref_delta'].iloc[large_index] = ac_res['pref_step'].iloc[large_index] / n_step * idx_step
            ac_res['pref'] = ac_res.p0 + ac_res.pref_delta

            # a.SynGen
            ssa.TurbineGov.set(src='pref0', idx=sch_gov_idx,
                               attr='v', value=ac_res.pref[cond_sch_gov].values)
            # b.DG
            ssa.DG.set(src='pref0', idx=sch_dg_idx,
                       attr='v', value=ac_res.pref[cond_sch_dg].values)

    # --- intv_pq: alter load, run TDS ---
    # Initially, alter StaticGen: p0 and q0, run PFlow
    # Otherwise, alter Ppf and Qpf
    if end_time == 0:
        stg_opf_idx = ac_res.stg_idx[ac_res.controllable].tolist()
        stg_opf_val = ac_res.p[ac_res.controllable].tolist()
        stg_opf_v = ac_res.vm_pu[ac_res.controllable].tolist()
        ssa.StaticGen.set(src='p0', idx=stg_opf_idx, attr='v', value=stg_opf_val)
        ssa.StaticGen.set(src='v0', idx=stg_opf_idx, attr='v', value=stg_opf_v)
        # initial load point set as the dispatch point
        ssa.PQ.set(src='p0', idx=ssa_pq_idx, attr='v',
                   value=ssa_p0 * load_exp)
        ssa.PQ.set(src='q0', idx=ssa_pq_idx, attr='v',
                   value=ssa_q0 * load_exp)
        ssa.PFlow.run()
    else:
        ssa.PQ.set(src='Ppf', idx=ssa_pq_idx, attr='v',
                   value=ssa_p0 * d_syn['sload'].iloc[end_time])
        ssa.PQ.set(src='Qpf', idx=ssa_pq_idx, attr='v',
                   value=ssa_q0 * d_syn['sload'].iloc[end_time])

    # run TDS
    ssa.TDS.config.tf = end_time
    if end_time == 0:
        ssa.TDS.init()
    ssa.TDS.run()
    # update AGC PI Controller
    ACE_integral = ACE_integral + ssa.ACEc.ace.v.sum()
    ACE_raw = -(Kp*ssa.ACEc.ace.v.sum() + Ki*ACE_integral)

    # ACE_raw = 0  # delete when run TDS
    # break loop if TDS run into error
    if ssa.exit_code != 0:
        raise ValueError(f"TDS error! Exit with {ssa.exit_code}, end at {end_time}s.")
# Out:
# RTED GB model is loaded.
# RTED removed: ['rampu', 'rampd']
# RTED is solved.
# RTED: total cost=4698.234
# -> System connectivity check results:
#   No islanded bus detected.
#   System is interconnected.
#   Each island has a slack bus correctly defined and enabled.
#
# -> Power flow calculation
#            Numba: On
#    Sparse solver: KLU
#  Solution method: NR method
# Numba compilation initiated with caching.
# Power flow initialized in 0.0072 seconds.
# 0: |F(x)| = 7.898638529
# 1: |F(x)| = 3.821851314
# 2: |F(x)| = 0.2224458573
# 3: |F(x)| = 0.001773697542
# 4: |F(x)| = 7.781538791e-08
# Converged in 5 iterations in 0.0159 seconds.
# Numba compilation initiated with caching.
# GENROU (xl <= xd2) out of typical upper limit.
#
#    idx     | values | limit
# -----------+--------+------
#  GENROU_1  | 0.014  | 0.001
#  GENROU_3  | 0.018  | 0.003
#  GENROU_4  | 0.013  | 0.001
#  GENROU_5  | 0.014  | 0.001
#  GENROU_7  | 0.015  | 0.002
#  GENROU_8  | 0.015  | 0.006
#  GENROU_9  | 0.009  | 0.001
#  GENROU_10 | 0.013  | 0.000
#
#
# Initialization for dynamics completed in 0.1797 seconds.
# Initialization was successful.
#
# -> Time Domain Simulation Summary:
# Sparse Solver: KLU
# Simulation time: 0.0-0 s.
# Fixed step size: h=33.33 ms. Shrink if not converged.
# Simulation to t=0.00 sec completed in 0.0001 seconds.
#
# -> Time Domain Simulation Summary:
# Sparse Solver: KLU
# Simulation time: 0.0-1 s.
# Fixed step size: h=33.33 ms. Shrink if not converged.
# Current step size is zero. Integration is not permitted.
# Simulation to t=1.00 sec completed in 0.0391 seconds.
# Simulation to t=2.00 sec completed in 0.0370 seconds.
# Simulation to t=3.00 sec completed in 0.0377 seconds.
# Simulation to t=4.00 sec completed in 0.0431 seconds.
# Simulation to t=5.00 sec completed in 0.0402 seconds.
# Simulation to t=6.00 sec completed in 0.0319 seconds.
# Simulation to t=7.00 sec completed in 0.0294 seconds.
# Simulation to t=8.00 sec completed in 0.0299 seconds.
# Simulation to t=9.00 sec completed in 0.0305 seconds.
# Simulation to t=10.00 sec completed in 0.0306 seconds.
# Simulation to t=11.00 sec completed in 0.0300 seconds.
# Simulation to t=12.00 sec completed in 0.0441 seconds.
# Simulation to t=13.00 sec completed in 0.0358 seconds.
# Simulation to t=14.00 sec completed in 0.0360 seconds.
# Simulation to t=15.00 sec completed in 0.0316 seconds.
# Simulation to t=16.00 sec completed in 0.0297 seconds.
# Simulation to t=17.00 sec completed in 0.0289 seconds.
# Simulation to t=18.00 sec completed in 0.0281 seconds.
# Simulation to t=19.00 sec completed in 0.0290 seconds.
# Simulation to t=20.00 sec completed in 0.0387 seconds.
# Simulation to t=21.00 sec completed in 0.0305 seconds.
# Simulation to t=22.00 sec completed in 0.0303 seconds.
# Simulation to t=23.00 sec completed in 0.0293 seconds.
# Simulation to t=24.00 sec completed in 0.0447 seconds.
# Simulation to t=25.00 sec completed in 0.0361 seconds.
# Simulation to t=26.00 sec completed in 0.0310 seconds.
# Simulation to t=27.00 sec completed in 0.0443 seconds.
# Simulation to t=28.00 sec completed in 0.0504 seconds.
# Simulation to t=29.00 sec completed in 0.0371 seconds.
# Simulation to t=30.00 sec completed in 0.0513 seconds.
# Simulation to t=31.00 sec completed in 0.0506 seconds.
# Simulation to t=32.00 sec completed in 0.0528 seconds.
# Simulation to t=33.00 sec completed in 0.0405 seconds.
# Simulation to t=34.00 sec completed in 0.0444 seconds.
# Simulation to t=35.00 sec completed in 0.0452 seconds.
# Simulation to t=36.00 sec completed in 0.0584 seconds.
# Simulation to t=37.00 sec completed in 0.0431 seconds.
# Simulation to t=38.00 sec completed in 0.0508 seconds.
# Simulation to t=39.00 sec completed in 0.0444 seconds.
# Simulation to t=40.00 sec completed in 0.0848 seconds.
# Simulation to t=41.00 sec completed in 0.0578 seconds.
# Simulation to t=42.00 sec completed in 0.0549 seconds.
# Simulation to t=43.00 sec completed in 0.0579 seconds.
# Simulation to t=44.00 sec completed in 0.0575 seconds.
# Simulation to t=45.00 sec completed in 0.0441 seconds.
# Simulation to t=46.00 sec completed in 0.0526 seconds.
# Simulation to t=47.00 sec completed in 0.0690 seconds.
# Simulation to t=48.00 sec completed in 0.0528 seconds.
# Simulation to t=49.00 sec completed in 0.0602 seconds.
# Simulation to t=50.00 sec completed in 0.0522 seconds.
# Simulation to t=51.00 sec completed in 0.0534 seconds.
# Simulation to t=52.00 sec completed in 0.0577 seconds.
# Simulation to t=53.00 sec completed in 0.0492 seconds.
# Simulation to t=54.00 sec completed in 0.0537 seconds.
# Simulation to t=55.00 sec completed in 0.0512 seconds.
# Simulation to t=56.00 sec completed in 0.0534 seconds.
# Simulation to t=57.00 sec completed in 0.0336 seconds.
# Simulation to t=58.00 sec completed in 0.0327 seconds.
# Simulation to t=59.00 sec completed in 0.0307 seconds.
# Simulation to t=60.00 sec completed in 0.0310 seconds.
# Simulation to t=61.00 sec completed in 0.0323 seconds.
# Simulation to t=62.00 sec completed in 0.0324 seconds.
# Simulation to t=63.00 sec completed in 0.0314 seconds.
# Simulation to t=64.00 sec completed in 0.0469 seconds.
# Simulation to t=65.00 sec completed in 0.0567 seconds.
# Simulation to t=66.00 sec completed in 0.0382 seconds.
# Simulation to t=67.00 sec completed in 0.0370 seconds.
# Simulation to t=68.00 sec completed in 0.0429 seconds.
# Simulation to t=69.00 sec completed in 0.0337 seconds.
# Simulation to t=70.00 sec completed in 0.0376 seconds.
# Simulation to t=71.00 sec completed in 0.0342 seconds.
# Simulation to t=72.00 sec completed in 0.0431 seconds.
# Simulation to t=73.00 sec completed in 0.0376 seconds.
# Simulation to t=74.00 sec completed in 0.0383 seconds.
# Simulation to t=75.00 sec completed in 0.0405 seconds.
# Simulation to t=76.00 sec completed in 0.0438 seconds.
# Simulation to t=77.00 sec completed in 0.0370 seconds.
# Simulation to t=78.00 sec completed in 0.0362 seconds.
# Simulation to t=79.00 sec completed in 0.0331 seconds.
# Simulation to t=80.00 sec completed in 0.0407 seconds.
# Simulation to t=81.00 sec completed in 0.0330 seconds.
# Simulation to t=82.00 sec completed in 0.0332 seconds.
# Simulation to t=83.00 sec completed in 0.0303 seconds.
# Simulation to t=84.00 sec completed in 0.0444 seconds.
# Simulation to t=85.00 sec completed in 0.0320 seconds.
# Simulation to t=86.00 sec completed in 0.0298 seconds.
# Simulation to t=87.00 sec completed in 0.0310 seconds.
# Simulation to t=88.00 sec completed in 0.0374 seconds.
# Simulation to t=89.00 sec completed in 0.0300 seconds.
# Simulation to t=90.00 sec completed in 0.0298 seconds.
# Simulation to t=91.00 sec completed in 0.0315 seconds.
# Simulation to t=92.00 sec completed in 0.0410 seconds.
# Simulation to t=93.00 sec completed in 0.0358 seconds.
# Simulation to t=94.00 sec completed in 0.0303 seconds.
# Simulation to t=95.00 sec completed in 0.0304 seconds.
# Simulation to t=96.00 sec completed in 0.0427 seconds.
# Simulation to t=97.00 sec completed in 0.0413 seconds.
# Simulation to t=98.00 sec completed in 0.0378 seconds.
# Simulation to t=99.00 sec completed in 0.0315 seconds.
# Simulation to t=100.00 sec completed in 0.0417 seconds.
# Simulation to t=101.00 sec completed in 0.0411 seconds.
# Simulation to t=102.00 sec completed in 0.0370 seconds.
# Simulation to t=103.00 sec completed in 0.0383 seconds.
# Simulation to t=104.00 sec completed in 0.0425 seconds.
# Simulation to t=105.00 sec completed in 0.0419 seconds.
# Simulation to t=106.00 sec completed in 0.0389 seconds.
# Simulation to t=107.00 sec completed in 0.0374 seconds.
# Simulation to t=108.00 sec completed in 0.0419 seconds.
# Simulation to t=109.00 sec completed in 0.0342 seconds.
# Simulation to t=110.00 sec completed in 0.0342 seconds.
# Simulation to t=111.00 sec completed in 0.0319 seconds.
# Simulation to t=112.00 sec completed in 0.0377 seconds.
# Simulation to t=113.00 sec completed in 0.0355 seconds.
# Simulation to t=114.00 sec completed in 0.0346 seconds.
# Simulation to t=115.00 sec completed in 0.0319 seconds.
# Simulation to t=116.00 sec completed in 0.0404 seconds.
# Simulation to t=117.00 sec completed in 0.0329 seconds.
# Simulation to t=118.00 sec completed in 0.0309 seconds.
# Simulation to t=119.00 sec completed in 0.0301 seconds.
# Simulation to t=120.00 sec completed in 0.0297 seconds.
# Simulation to t=121.00 sec completed in 0.0313 seconds.
# Simulation to t=122.00 sec completed in 0.0302 seconds.
# Simulation to t=123.00 sec completed in 0.0298 seconds.
# Simulation to t=124.00 sec completed in 0.0357 seconds.
# Simulation to t=125.00 sec completed in 0.0296 seconds.
# Simulation to t=126.00 sec completed in 0.0302 seconds.
# Simulation to t=127.00 sec completed in 0.0305 seconds.
# Simulation to t=128.00 sec completed in 0.0369 seconds.
# Simulation to t=129.00 sec completed in 0.0296 seconds.
# Simulation to t=130.00 sec completed in 0.0296 seconds.
# Simulation to t=131.00 sec completed in 0.0309 seconds.
# Simulation to t=132.00 sec completed in 0.0398 seconds.
# Simulation to t=133.00 sec completed in 0.0296 seconds.
# Simulation to t=134.00 sec completed in 0.0296 seconds.
# Simulation to t=135.00 sec completed in 0.0314 seconds.
# Simulation to t=136.00 sec completed in 0.0428 seconds.
# Simulation to t=137.00 sec completed in 0.0314 seconds.
# Simulation to t=138.00 sec completed in 0.0307 seconds.
# Simulation to t=139.00 sec completed in 0.0300 seconds.
# Simulation to t=140.00 sec completed in 0.0408 seconds.
# Simulation to t=141.00 sec completed in 0.0382 seconds.
# Simulation to t=142.00 sec completed in 0.0331 seconds.
# Simulation to t=143.00 sec completed in 0.0325 seconds.
# Simulation to t=144.00 sec completed in 0.0393 seconds.
# Simulation to t=145.00 sec completed in 0.0315 seconds.
# Simulation to t=146.00 sec completed in 0.0298 seconds.
# Simulation to t=147.00 sec completed in 0.0301 seconds.
# Simulation to t=148.00 sec completed in 0.0411 seconds.
# Simulation to t=149.00 sec completed in 0.0381 seconds.
# Simulation to t=150.00 sec completed in 0.0370 seconds.
# Simulation to t=151.00 sec completed in 0.0321 seconds.
# Simulation to t=152.00 sec completed in 0.0435 seconds.
# Simulation to t=153.00 sec completed in 0.0402 seconds.
# Simulation to t=154.00 sec completed in 0.0392 seconds.
# Simulation to t=155.00 sec completed in 0.0384 seconds.
# Simulation to t=156.00 sec completed in 0.0439 seconds.
# Simulation to t=157.00 sec completed in 0.0498 seconds.
# Simulation to t=158.00 sec completed in 0.0417 seconds.
# Simulation to t=159.00 sec completed in 0.0428 seconds.
# Simulation to t=160.00 sec completed in 0.0449 seconds.
# Simulation to t=161.00 sec completed in 0.0490 seconds.
# Simulation to t=162.00 sec completed in 0.0425 seconds.
# Simulation to t=163.00 sec completed in 0.0410 seconds.
# Simulation to t=164.00 sec completed in 0.0423 seconds.
# Simulation to t=165.00 sec completed in 0.0393 seconds.
# Simulation to t=166.00 sec completed in 0.0397 seconds.
# Simulation to t=167.00 sec completed in 0.0393 seconds.
# Simulation to t=168.00 sec completed in 0.0428 seconds.
# Simulation to t=169.00 sec completed in 0.0397 seconds.
# Simulation to t=170.00 sec completed in 0.0392 seconds.
# Simulation to t=171.00 sec completed in 0.0437 seconds.
# Simulation to t=172.00 sec completed in 0.0364 seconds.
# Simulation to t=173.00 sec completed in 0.0334 seconds.
# Simulation to t=174.00 sec completed in 0.0295 seconds.
# Simulation to t=175.00 sec completed in 0.0315 seconds.
# Simulation to t=176.00 sec completed in 0.0450 seconds.
# Simulation to t=177.00 sec completed in 0.0365 seconds.
# Simulation to t=178.00 sec completed in 0.0310 seconds.
# Simulation to t=179.00 sec completed in 0.0348 seconds.
# Simulation to t=180.00 sec completed in 0.0367 seconds.
# Simulation to t=181.00 sec completed in 0.0318 seconds.
# Simulation to t=182.00 sec completed in 0.0319 seconds.
# Simulation to t=183.00 sec completed in 0.0342 seconds.
# Simulation to t=184.00 sec completed in 0.0432 seconds.
# Simulation to t=185.00 sec completed in 0.0410 seconds.
# Simulation to t=186.00 sec completed in 0.0496 seconds.
# Simulation to t=187.00 sec completed in 0.0495 seconds.
# Simulation to t=188.00 sec completed in 0.0428 seconds.
# Simulation to t=189.00 sec completed in 0.0418 seconds.
# Simulation to t=190.00 sec completed in 0.0415 seconds.
# Simulation to t=191.00 sec completed in 0.0418 seconds.
# Simulation to t=192.00 sec completed in 0.0516 seconds.
# Simulation to t=193.00 sec completed in 0.0478 seconds.
# Simulation to t=194.00 sec completed in 0.0463 seconds.
# Simulation to t=195.00 sec completed in 0.0578 seconds.
# Simulation to t=196.00 sec completed in 0.0480 seconds.
# Simulation to t=197.00 sec completed in 0.0419 seconds.
# Simulation to t=198.00 sec completed in 0.0388 seconds.
# Simulation to t=199.00 sec completed in 0.0327 seconds.
# Simulation to t=200.00 sec completed in 0.0399 seconds.
# Simulation to t=201.00 sec completed in 0.0452 seconds.
# Simulation to t=202.00 sec completed in 0.0393 seconds.
# Simulation to t=203.00 sec completed in 0.0379 seconds.
# Simulation to t=204.00 sec completed in 0.0419 seconds.
# Simulation to t=205.00 sec completed in 0.0355 seconds.
# Simulation to t=206.00 sec completed in 0.0361 seconds.
# Simulation to t=207.00 sec completed in 0.0344 seconds.
# Simulation to t=208.00 sec completed in 0.0381 seconds.
# Simulation to t=209.00 sec completed in 0.0398 seconds.
# Simulation to t=210.00 sec completed in 0.0318 seconds.
# Simulation to t=211.00 sec completed in 0.0340 seconds.
# Simulation to t=212.00 sec completed in 0.0499 seconds.
# Simulation to t=213.00 sec completed in 0.0365 seconds.
# Simulation to t=214.00 sec completed in 0.0349 seconds.
# Simulation to t=215.00 sec completed in 0.0358 seconds.
# Simulation to t=216.00 sec completed in 0.0440 seconds.
# Simulation to t=217.00 sec completed in 0.0555 seconds.
# Simulation to t=218.00 sec completed in 0.0403 seconds.
# Simulation to t=219.00 sec completed in 0.0432 seconds.
# Simulation to t=220.00 sec completed in 0.0428 seconds.
# Simulation to t=221.00 sec completed in 0.0411 seconds.
# Simulation to t=222.00 sec completed in 0.0451 seconds.
# Simulation to t=223.00 sec completed in 0.0451 seconds.
# Simulation to t=224.00 sec completed in 0.0454 seconds.
# Simulation to t=225.00 sec completed in 0.0427 seconds.
# Simulation to t=226.00 sec completed in 0.0461 seconds.
# Simulation to t=227.00 sec completed in 0.0431 seconds.
# Simulation to t=228.00 sec completed in 0.0449 seconds.
# Simulation to t=229.00 sec completed in 0.0413 seconds.
# Simulation to t=230.00 sec completed in 0.0477 seconds.
# Simulation to t=231.00 sec completed in 0.0482 seconds.
# Simulation to t=232.00 sec completed in 0.0479 seconds.
# Simulation to t=233.00 sec completed in 0.0431 seconds.
# Simulation to t=234.00 sec completed in 0.0427 seconds.
# Simulation to t=235.00 sec completed in 0.0461 seconds.
# Simulation to t=236.00 sec completed in 0.0441 seconds.
# Simulation to t=237.00 sec completed in 0.0427 seconds.
# Simulation to t=238.00 sec completed in 0.0412 seconds.
# Simulation to t=239.00 sec completed in 0.0424 seconds.
# Simulation to t=240.00 sec completed in 0.0476 seconds.
# Simulation to t=241.00 sec completed in 0.0448 seconds.
# Simulation to t=242.00 sec completed in 0.0409 seconds.
# Simulation to t=243.00 sec completed in 0.0410 seconds.
# Simulation to t=244.00 sec completed in 0.0425 seconds.
# Simulation to t=245.00 sec completed in 0.0407 seconds.
# Simulation to t=246.00 sec completed in 0.0398 seconds.
# Simulation to t=247.00 sec completed in 0.0405 seconds.
# Simulation to t=248.00 sec completed in 0.0405 seconds.
# Simulation to t=249.00 sec completed in 0.0324 seconds.
# Simulation to t=250.00 sec completed in 0.0323 seconds.
# Simulation to t=251.00 sec completed in 0.0328 seconds.
# Simulation to t=252.00 sec completed in 0.0322 seconds.
# Simulation to t=253.00 sec completed in 0.0302 seconds.
# Simulation to t=254.00 sec completed in 0.0312 seconds.
# Simulation to t=255.00 sec completed in 0.0300 seconds.
# Simulation to t=256.00 sec completed in 0.0435 seconds.
# Simulation to t=257.00 sec completed in 0.0287 seconds.
# Simulation to t=258.00 sec completed in 0.0301 seconds.
# Simulation to t=259.00 sec completed in 0.0316 seconds.
# Simulation to t=260.00 sec completed in 0.0433 seconds.
# Simulation to t=261.00 sec completed in 0.0362 seconds.
# Simulation to t=262.00 sec completed in 0.0365 seconds.
# Simulation to t=263.00 sec completed in 0.0360 seconds.
# Simulation to t=264.00 sec completed in 0.0441 seconds.
# Simulation to t=265.00 sec completed in 0.0397 seconds.
# Simulation to t=266.00 sec completed in 0.0399 seconds.
# Simulation to t=267.00 sec completed in 0.0369 seconds.
# Simulation to t=268.00 sec completed in 0.0430 seconds.
# Simulation to t=269.00 sec completed in 0.0435 seconds.
# Simulation to t=270.00 sec completed in 0.0390 seconds.
# Simulation to t=271.00 sec completed in 0.0444 seconds.
# Simulation to t=272.00 sec completed in 0.0491 seconds.
# Simulation to t=273.00 sec completed in 0.0450 seconds.
# Simulation to t=274.00 sec completed in 0.0486 seconds.
# Simulation to t=275.00 sec completed in 0.0430 seconds.
# Simulation to t=276.00 sec completed in 0.0541 seconds.
# Simulation to t=277.00 sec completed in 0.0504 seconds.
# Simulation to t=278.00 sec completed in 0.0508 seconds.
# Simulation to t=279.00 sec completed in 0.0492 seconds.
# Simulation to t=280.00 sec completed in 0.0521 seconds.
# Simulation to t=281.00 sec completed in 0.0513 seconds.
# Simulation to t=282.00 sec completed in 0.0514 seconds.
# Simulation to t=283.00 sec completed in 0.0502 seconds.
# Simulation to t=284.00 sec completed in 0.0591 seconds.
# Simulation to t=285.00 sec completed in 0.0528 seconds.
# Simulation to t=286.00 sec completed in 0.0549 seconds.
# Simulation to t=287.00 sec completed in 0.0513 seconds.
# Simulation to t=288.00 sec completed in 0.0548 seconds.
# Simulation to t=289.00 sec completed in 0.0532 seconds.
# Simulation to t=290.00 sec completed in 0.0529 seconds.
# Simulation to t=291.00 sec completed in 0.0532 seconds.
# Simulation to t=292.00 sec completed in 0.0697 seconds.
# Simulation to t=293.00 sec completed in 0.0599 seconds.
# Simulation to t=294.00 sec completed in 0.0666 seconds.
# Simulation to t=295.00 sec completed in 0.0723 seconds.
# Simulation to t=296.00 sec completed in 0.0853 seconds.
# Simulation to t=297.00 sec completed in 0.0770 seconds.
# Simulation to t=298.00 sec completed in 0.0780 seconds.
# Simulation to t=299.00 sec completed in 0.0897 seconds.
# RTED GB model is loaded.
# RTED is solved.
# RTED: total cost=4565.218
# Simulation to t=300.00 sec completed in 0.0613 seconds.
# Simulation to t=301.00 sec completed in 0.0595 seconds.
# Simulation to t=302.00 sec completed in 0.0836 seconds.
# Simulation to t=303.00 sec completed in 0.0730 seconds.
# Simulation to t=304.00 sec completed in 0.0555 seconds.
# Simulation to t=305.00 sec completed in 0.0542 seconds.
# Simulation to t=306.00 sec completed in 0.0525 seconds.
# Simulation to t=307.00 sec completed in 0.0509 seconds.
# Simulation to t=308.00 sec completed in 0.0504 seconds.
# Simulation to t=309.00 sec completed in 0.0472 seconds.
# Simulation to t=310.00 sec completed in 0.0432 seconds.
# Simulation to t=311.00 sec completed in 0.0405 seconds.
# Simulation to t=312.00 sec completed in 0.0585 seconds.
# Simulation to t=313.00 sec completed in 0.0519 seconds.
# Simulation to t=314.00 sec completed in 0.0595 seconds.
# Simulation to t=315.00 sec completed in 0.0567 seconds.
# Simulation to t=316.00 sec completed in 0.0551 seconds.
# Simulation to t=317.00 sec completed in 0.0538 seconds.
# Simulation to t=318.00 sec completed in 0.0498 seconds.
# Simulation to t=319.00 sec completed in 0.0419 seconds.
# Simulation to t=320.00 sec completed in 0.0695 seconds.
# Simulation to t=321.00 sec completed in 0.0562 seconds.
# Simulation to t=322.00 sec completed in 0.0573 seconds.
# Simulation to t=323.00 sec completed in 0.0504 seconds.
# Simulation to t=324.00 sec completed in 0.0480 seconds.
# Simulation to t=325.00 sec completed in 0.0535 seconds.
# Simulation to t=326.00 sec completed in 0.0413 seconds.
# Simulation to t=327.00 sec completed in 0.0403 seconds.
# Simulation to t=328.00 sec completed in 0.0538 seconds.
# Simulation to t=329.00 sec completed in 0.0548 seconds.
# Simulation to t=330.00 sec completed in 0.0546 seconds.
# Simulation to t=331.00 sec completed in 0.0579 seconds.
# Simulation to t=332.00 sec completed in 0.0553 seconds.
# Simulation to t=333.00 sec completed in 0.0495 seconds.
# Simulation to t=334.00 sec completed in 0.0449 seconds.
# Simulation to t=335.00 sec completed in 0.0485 seconds.
# Simulation to t=336.00 sec completed in 0.0559 seconds.
# Simulation to t=337.00 sec completed in 0.0552 seconds.
# Simulation to t=338.00 sec completed in 0.0544 seconds.
# Simulation to t=339.00 sec completed in 0.0537 seconds.
# Simulation to t=340.00 sec completed in 0.0568 seconds.
# Simulation to t=341.00 sec completed in 0.0588 seconds.
# Simulation to t=342.00 sec completed in 0.0554 seconds.
# Simulation to t=343.00 sec completed in 0.0544 seconds.
# Simulation to t=344.00 sec completed in 0.0574 seconds.
# Simulation to t=345.00 sec completed in 0.0561 seconds.
# Simulation to t=346.00 sec completed in 0.0540 seconds.
# Simulation to t=347.00 sec completed in 0.0545 seconds.
# Simulation to t=348.00 sec completed in 0.0540 seconds.
# Simulation to t=349.00 sec completed in 0.0538 seconds.
# Simulation to t=350.00 sec completed in 0.0544 seconds.
# Simulation to t=351.00 sec completed in 0.0535 seconds.
# Simulation to t=352.00 sec completed in 0.0568 seconds.
# Simulation to t=353.00 sec completed in 0.0549 seconds.
# Simulation to t=354.00 sec completed in 0.0559 seconds.
# Simulation to t=355.00 sec completed in 0.0543 seconds.
# Simulation to t=356.00 sec completed in 0.0554 seconds.
# Simulation to t=357.00 sec completed in 0.0546 seconds.
# Simulation to t=358.00 sec completed in 0.0623 seconds.
# Simulation to t=359.00 sec completed in 0.0550 seconds.
# Simulation to t=360.00 sec completed in 0.0656 seconds.
# Simulation to t=361.00 sec completed in 0.0552 seconds.
# Simulation to t=362.00 sec completed in 0.0539 seconds.
# Simulation to t=363.00 sec completed in 0.0546 seconds.
# Simulation to t=364.00 sec completed in 0.0535 seconds.
# Simulation to t=365.00 sec completed in 0.0536 seconds.
# Simulation to t=366.00 sec completed in 0.0539 seconds.
# Simulation to t=367.00 sec completed in 0.0543 seconds.
# Simulation to t=368.00 sec completed in 0.0650 seconds.
# Simulation to t=369.00 sec completed in 0.0552 seconds.
# Simulation to t=370.00 sec completed in 0.0560 seconds.
# Simulation to t=371.00 sec completed in 0.0577 seconds.
# Simulation to t=372.00 sec completed in 0.0760 seconds.
# Simulation to t=373.00 sec completed in 0.0607 seconds.
# Simulation to t=374.00 sec completed in 0.0683 seconds.
# Simulation to t=375.00 sec completed in 0.0702 seconds.
# Simulation to t=376.00 sec completed in 0.0640 seconds.
# Simulation to t=377.00 sec completed in 0.0751 seconds.
# Simulation to t=378.00 sec completed in 0.1027 seconds.
# Simulation to t=379.00 sec completed in 0.0843 seconds.
# Simulation to t=380.00 sec completed in 0.0735 seconds.
# Simulation to t=381.00 sec completed in 0.0846 seconds.
# Simulation to t=382.00 sec completed in 0.0976 seconds.
# Simulation to t=383.00 sec completed in 0.0692 seconds.
# Simulation to t=384.00 sec completed in 0.0844 seconds.
# Simulation to t=385.00 sec completed in 0.0580 seconds.
# Simulation to t=386.00 sec completed in 0.0853 seconds.
# Simulation to t=387.00 sec completed in 0.0579 seconds.
# Simulation to t=388.00 sec completed in 0.0646 seconds.
# Simulation to t=389.00 sec completed in 0.0643 seconds.
# Simulation to t=390.00 sec completed in 0.0648 seconds.
# Simulation to t=391.00 sec completed in 0.0727 seconds.
# Simulation to t=392.00 sec completed in 0.0784 seconds.
# Simulation to t=393.00 sec completed in 0.0655 seconds.
# Simulation to t=394.00 sec completed in 0.0629 seconds.
# Simulation to t=395.00 sec completed in 0.0566 seconds.
# Simulation to t=396.00 sec completed in 0.0552 seconds.
# Simulation to t=397.00 sec completed in 0.0528 seconds.
# Simulation to t=398.00 sec completed in 0.0433 seconds.
# Simulation to t=399.00 sec completed in 0.0473 seconds.
# Simulation to t=400.00 sec completed in 0.0468 seconds.
# Simulation to t=401.00 sec completed in 0.0454 seconds.
# Simulation to t=402.00 sec completed in 0.0449 seconds.
# Simulation to t=403.00 sec completed in 0.0433 seconds.
# Simulation to t=404.00 sec completed in 0.0627 seconds.
# Simulation to t=405.00 sec completed in 0.0617 seconds.
# Simulation to t=406.00 sec completed in 0.0650 seconds.
# Simulation to t=407.00 sec completed in 0.0774 seconds.
# Simulation to t=408.00 sec completed in 0.0667 seconds.
# Simulation to t=409.00 sec completed in 0.0596 seconds.
# Simulation to t=410.00 sec completed in 0.0677 seconds.
# Simulation to t=411.00 sec completed in 0.0779 seconds.
# Simulation to t=412.00 sec completed in 0.0660 seconds.
# Simulation to t=413.00 sec completed in 0.0755 seconds.
# Simulation to t=414.00 sec completed in 0.0656 seconds.
# Simulation to t=415.00 sec completed in 0.0573 seconds.
# Simulation to t=416.00 sec completed in 0.0759 seconds.
# Simulation to t=417.00 sec completed in 0.0668 seconds.
# Simulation to t=418.00 sec completed in 0.0780 seconds.
# Simulation to t=419.00 sec completed in 0.0759 seconds.
# Simulation to t=420.00 sec completed in 0.0566 seconds.
# Simulation to t=421.00 sec completed in 0.0488 seconds.
# Simulation to t=422.00 sec completed in 0.0511 seconds.
# Simulation to t=423.00 sec completed in 0.0600 seconds.
# Simulation to t=424.00 sec completed in 0.0499 seconds.
# Simulation to t=425.00 sec completed in 0.0627 seconds.
# Simulation to t=426.00 sec completed in 0.0595 seconds.
# Simulation to t=427.00 sec completed in 0.0513 seconds.
# Simulation to t=428.00 sec completed in 0.0589 seconds.
# Simulation to t=429.00 sec completed in 0.0530 seconds.
# Simulation to t=430.00 sec completed in 0.0533 seconds.
# Simulation to t=431.00 sec completed in 0.0463 seconds.
# Simulation to t=432.00 sec completed in 0.0519 seconds.
# Simulation to t=433.00 sec completed in 0.0573 seconds.
# Simulation to t=434.00 sec completed in 0.0531 seconds.
# Simulation to t=435.00 sec completed in 0.0958 seconds.
# Simulation to t=436.00 sec completed in 0.0530 seconds.
# Simulation to t=437.00 sec completed in 0.0516 seconds.
# Simulation to t=438.00 sec completed in 0.0544 seconds.
# Simulation to t=439.00 sec completed in 0.0805 seconds.
# Simulation to t=440.00 sec completed in 0.0618 seconds.
# Simulation to t=441.00 sec completed in 0.0534 seconds.
# Simulation to t=442.00 sec completed in 0.0451 seconds.
# Simulation to t=443.00 sec completed in 0.0355 seconds.
# Simulation to t=444.00 sec completed in 0.0732 seconds.
# Simulation to t=445.00 sec completed in 0.0683 seconds.
# Simulation to t=446.00 sec completed in 0.0903 seconds.
# Simulation to t=447.00 sec completed in 0.0457 seconds.
# Simulation to t=448.00 sec completed in 0.0706 seconds.
# Simulation to t=449.00 sec completed in 0.0563 seconds.
# Simulation to t=450.00 sec completed in 0.0538 seconds.
# Simulation to t=451.00 sec completed in 0.0593 seconds.
# Simulation to t=452.00 sec completed in 0.0673 seconds.
# Simulation to t=453.00 sec completed in 0.0758 seconds.
# Simulation to t=454.00 sec completed in 0.0642 seconds.
# Simulation to t=455.00 sec completed in 0.0472 seconds.
# Simulation to t=456.00 sec completed in 0.0485 seconds.
# Simulation to t=457.00 sec completed in 0.0493 seconds.
# Simulation to t=458.00 sec completed in 0.0546 seconds.
# Simulation to t=459.00 sec completed in 0.0456 seconds.
# Simulation to t=460.00 sec completed in 0.0498 seconds.
# Simulation to t=461.00 sec completed in 0.0467 seconds.
# Simulation to t=462.00 sec completed in 0.0552 seconds.
# Simulation to t=463.00 sec completed in 0.0482 seconds.
# Simulation to t=464.00 sec completed in 0.0474 seconds.
# Simulation to t=465.00 sec completed in 0.0599 seconds.
# Simulation to t=466.00 sec completed in 0.0456 seconds.
# Simulation to t=467.00 sec completed in 0.0438 seconds.
# Simulation to t=468.00 sec completed in 0.0552 seconds.
# Simulation to t=469.00 sec completed in 0.0461 seconds.
# Simulation to t=470.00 sec completed in 0.0426 seconds.
# Simulation to t=471.00 sec completed in 0.0520 seconds.
# Simulation to t=472.00 sec completed in 0.0522 seconds.
# Simulation to t=473.00 sec completed in 0.0532 seconds.
# Simulation to t=474.00 sec completed in 0.0548 seconds.
# Simulation to t=475.00 sec completed in 0.0446 seconds.
# Simulation to t=476.00 sec completed in 0.0800 seconds.
# Simulation to t=477.00 sec completed in 0.0432 seconds.
# Simulation to t=478.00 sec completed in 0.0444 seconds.
# Simulation to t=479.00 sec completed in 0.0433 seconds.
# Simulation to t=480.00 sec completed in 0.0442 seconds.
# Simulation to t=481.00 sec completed in 0.0449 seconds.
# Simulation to t=482.00 sec completed in 0.0419 seconds.
# Simulation to t=483.00 sec completed in 0.0504 seconds.
# Simulation to t=484.00 sec completed in 0.0597 seconds.
# Simulation to t=485.00 sec completed in 0.0559 seconds.
# Simulation to t=486.00 sec completed in 0.0542 seconds.
# Simulation to t=487.00 sec completed in 0.0534 seconds.
# Simulation to t=488.00 sec completed in 0.0583 seconds.
# Simulation to t=489.00 sec completed in 0.0711 seconds.
# Simulation to t=490.00 sec completed in 0.0785 seconds.
# Simulation to t=491.00 sec completed in 0.0767 seconds.
# Simulation to t=492.00 sec completed in 0.0831 seconds.
# Simulation to t=493.00 sec completed in 0.0920 seconds.
# Simulation to t=494.00 sec completed in 0.0797 seconds.
# Simulation to t=495.00 sec completed in 0.0930 seconds.
# Simulation to t=496.00 sec completed in 0.0910 seconds.

# %%
end_time

# %%
ssa.exit_code

# %%
# ssa.TDS.save_output()

# %%
plt.style.use('default')

right = end_time

# data format conversion
sfr_res = pd.DataFrame(sfr_res_data, columns=['time', 'ace', 'up', 'dn', 'in'])
sfr_res['ace'] = sfr_res['ace'] * ssa.config.mva
sfr_res['up'] = sfr_res['up'] * ssa.config.mva
sfr_res['dn'] = sfr_res['dn'] * ssa.config.mva
sfr_res['in'] = sfr_res['in'] * ssa.config.mva

# data save
# Complement AGC table
agc_smooth = pd.DataFrame(np.repeat(agc_in[list(np.arange(0, t_total, 4))].values, 4, axis=1),
                          columns=list(np.arange(0, t_total, 1)))

fig_gen, ax_gen = plt.subplots(2, 3, figsize=(16, 8))
plt.subplots_adjust(left=None, bottom=None, right=None,
                    top=None, wspace=0.2, hspace=0.3)

yheader = [f'G{i}' for i in range(1, 11)]

ssa.TDS.plt.plot(ssa.TGOV1N.pout,
                 linestyles=['-'],
                 yheader=yheader, ytimes=ssa.config.mva,
                 legend=True, show=False, right=right,
                 title=r'Generation (solid: pout; dash: pref)',
                 ylabel='MW',
                 fig=fig_gen, ax=ax_gen[0, 0])

ssa.TDS.plt.plot(ssa.TGOV1N.pref, ytimes=ssa.config.mva,
                 legend=False, show=False, right=right,
                 linestyles=[':'],
                 fig=fig_gen, ax=ax_gen[0, 0])

ssa.TDS.plt.plot(ssa.EV2.Pext, color='tab:orange',
                 linestyles=['-'],
                 yheader=yheader, ytimes=ssa.config.mva,
                 legend=False, show=False, right=right,
                 fig=fig_gen, ax=ax_gen[0, 1])
ssa.TDS.plt.plot(ssa.TGOV1N.paux,
                 linestyles=['-'],
                 yheader=yheader, ytimes=ssa.config.mva,
                 legend=False, show=False, right=right,
                 title=r'AGC power', ylabel='MW',
                 fig=fig_gen, ax=ax_gen[0, 1])

ax_gen[0, 2].plot(sfr_res.time,
                  ssa.config.mva * sfr_res['ace'],
                  label='AGC raw')
ax_gen[0, 2].plot(sfr_res.time, 
                  ssa.config.mva * sfr_res['in'],
                  label='AGC input')
ax_gen[0, 2].plot(sfr_res.time,
                  ssa.config.mva * sfr_res['up'],
                  label='SFR capacity',
                  linestyle='--', color='k')
ax_gen[0, 2].plot(sfr_res.time, 
                  ssa.config.mva * sfr_res['dn'],
                  linestyle='--', color='k')
ax_gen[0, 2].set_ylabel('MW')
ax_gen[0, 2].set_xlabel('Time [s]')
ax_gen[0, 2].set_title('AGC input and SFR capacity')

aced = ssa.dae.ts.y[:, ssa.ACEc.ace.a].reshape(-1) * ssa.config.mva
ssa.TDS.plt.plot(ssa.ACEc.ace,
                 legend=False, show=False, right=right,
                 linestyles=['-'], ytimes=ssa.config.mva,
                 title=f'ACE, $\sigma$={aced.std().round(4)}', ylabel='MW',
                 fig=fig_gen, ax=ax_gen[1, 0])

ssa.TDS.plt.plot(ssa.COI.omega,
                 legend=False, show=False, right=right,
                 linestyles=['-'], ylabel='Hz',
                 ytimes=ssa.config.freq,
                 title=r'COI Frequency',
                 fig=fig_gen, ax=ax_gen[1, 1])

f_coi = pd.DataFrame()
f_coi['f'] = ssa.dae.ts.y[:, ssa.COI.omega.a].reshape(-1).copy() * ssa.config.freq - ssa.config.freq
f_coi.plot(kind='kde', legend=False, linewidth=1,
           fig=fig_gen, ax=ax_gen[1, 2],
           title=f'Freq. D., $\mu$={f_coi.f.mean().round(4)}, $\sigma$={f_coi.f.std().round(4)}')
ax_gen[1, 2].set(xlabel='Deviation [Hz]', ylabel='')

# --- plot bu, bd ---
# --- collect data ---
irry = np.array(-1 * np.ones((n_ed, ssd.gen.shape[0])))
bu = irry.copy()
bd = irry.copy()
pg = irry.copy()
for rted_idx in rted_res.keys():
    bu[rted_idx] = pd.DataFrame.from_dict(rted_res[rted_idx]).loc['bu'].values
    bd[rted_idx] = pd.DataFrame.from_dict(rted_res[rted_idx]).loc['bd'].values
    pg[rted_idx] = pd.DataFrame.from_dict(rted_res[rted_idx]).loc['pg'].values
col = pd.DataFrame.from_dict(rted_res[rted_idx]).loc['gen']
bu_df = pd.DataFrame(bu, columns=col)
bd_df = pd.DataFrame(bd, columns=col)
pg_df = pd.DataFrame(pg, columns=col)

import matplotlib.font_manager
plt.style.use('ieee')

color = ['tab:blue', 'yellow', 'tab:green',
         'tab:red', 'tab:purple', 'tab:brown',
         'tab:pink', 'tab:gray', 'tab:olive', 'tab:cyan', 'tab:orange']

figs, axes = plt.subplots(1, 2, figsize=(10.5, 3))
plt.subplots_adjust(left=None, bottom=None, right=None,
                    top=None, wspace=0.35, hspace=None)
new_cols = ['PV_1', 'PV_2', 'PV_3', 'PV_4', 'PV_5', 'PV_6',
            'PV_7', 'PV_8', 'PV_9', 'Slack_10', 'PV_10']
bu_df[new_cols].plot.bar(stacked=True, ax=axes[0], legend=False, color=color)
bd_df[new_cols].plot.bar(stacked=True, ax=axes[1], legend=False, color=color)

for ax in axes:
    ax.tick_params(axis='x', labelrotation = 0)
    ax.set_ylim([0, 1])
    ax.set_yticklabels([f'{np.round(i*100,0)}\%' for i in np.arange(0, 1.1, 0.2)])
#     ax.set_xticklabels([i for i in range(1, n_ed, 1)])
    ax.set_xlabel('RTED interval')
axes[0].set_title('(a) Case 1: RegUp balancing factor')
axes[1].set_title('(b) Case 1: RegDn balancing factor')
lines_labels = [ax.get_legend_handles_labels() for ax in axes]
lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]
line_plot = lines[0:11]
line_plot.reverse()
label_g = ['G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9', 'G10', 'EV']
label_g.reverse()
figs.legend(line_plot, label_g, loc='center')

# --- generation cost ---
gtc = 0
for i in pg_df.index:
    c = ssd.cost.c2.values * np.power(pg_df.loc[i].values, 2) \
        + ssd.cost.c1.values * pg_df.loc[i].values \
        + ssd.cost.c1.values
    gtc += np.sum(c)

agc_out.fillna(0, inplace=True)
agc_out_sort = pd.merge(left=agc_out.rename(columns={'stg_idx':'idx'}),
                        right=ssd.cost[['idx']], on='idx', how='right')
agc_mile = pd.DataFrame(columns=list(np.arange(intv_agc, t_total, intv_agc)))
for col_id in np.arange(intv_agc, t_total, intv_agc):
    agc_mile[col_id] = np.abs(agc_out_sort[col_id] - agc_out_sort[int(col_id-intv_agc)])
agc_mile[agc_mile.columns] *= 100

# --- SFR mileage cost ---
ftc = 0
for i in agc_mile.columns:
    c = ssd.cost.c1.abs().values * agc_mile[i].values
    ftc += np.sum(c)

print(f"Total cost={np.round(gtc+ftc, 2)}")

# --- save data ---
cosim_out = pd.DataFrame()
cosim_out['Time'] = ssa.dae.ts.t
# alter the sign of ACE
cosim_out['ACE'] = ssa.dae.ts.y[:, ssa.ACEc.ace.a].reshape(-1).copy() * ssa.config.mva * -1
cosim_out['freq'] = ssa.dae.ts.y[:, ssa.COI.omega.a].reshape(-1).copy() * ssa.config.freq
pout9 = ssa.dae.ts.y[:, ssa.TGOV1N.pout.a[2]].reshape(-1)
pref9 = ssa.dae.ts.y[:, ssa.TGOV1N.pref.a[2]].reshape(-1)
cosim_out['paux9'] = ssa.config.mva * (pout9-pref9)

# %%
# data
iev = ssa.dae.ts.x[:, ssa.EV2.Ipout_y.a]
vev = ssa.dae.ts.y[:, ssa.EV2.v.a]
pev = iev * vev
prefev = ssa.dae.ts.y[:, ssa.EV2.Pref.a]
pauxev = (pev - prefev) * ssa.config.mva

# plot
fig_e, ax_e = plt.subplots(1, 1)
ssa.TDS.plt.plot(ssa.EV2.Pext,
                 ytimes=ssa.config.mva,
                 ax=ax_e, fig=fig_e, show=False,
                 yheader=['Control'], color='tab:blue')
ssa.TDS.plt.plot_data(ssa.dae.ts.t, pauxev,
                      yheader=['Response'], color='tab:orange',
                      ax=ax_e, fig=fig_e)

# %%
# cosim_out.to_csv('cosim_18_S_out.csv', index=False)
# sse_out.to_csv('cosim_18_S_sse.csv', index=False)
# bu_df.to_csv('cosim_18_S_bu.csv', index=False)
# bd_df.to_csv('cosim_18_S_bd.csv', index=False)
# pg_df.to_csv('cosim_18_S_pg.csv', index=False)
# agc_mile.to_csv('cosim_18_S_agcm.csv', index=False)
# sfr_res.to_csv('cosim_18_S_sfr.csv', index=False)
# ev_agc.to_csv('cosim_18_S_evagc.csv', index=False)
# ev_soc.to_csv('cosim_18_S_evsoc.csv', index=False)
# sse.ev.to_csv('cosim_18_S_evdata.csv', index=False)

# import csv
# new_path = open('cosim_18_S_rted.csv', 'w')
# z = csv.writer(new_path)
# for new_k, new_v in rted_res.items():
#     z.writerow([new_k, new_v])
# new_path.close()
