# %% [markdown]
# # RTED-TDS Co-Sim
#
# Authored by [Jinning Wang](https://scholar.google.com/citations?user=Wr7nQZAAAAAJ&hl=en&oi=ao), recently updated on 06/06/2022.
#
# This notebook is used to implement the Co-Simulation of Real Time Economic Dispatch (RTED) and Time-Domain Simulation (TDS).
# In the RTED, SFR is considered. In the TDS, AGC is implemented with an equation defined PI controller.
#
# RTED is seperated into two DCOPF and ACOPF: 1) DCOPF with SFR is solved in gurobipy, which is packaged into the class ``rted`` in the file ``rted.py``. 2) ACOPF is solved in pandapower.
#
# Class ``rted2`` has attributes ``mdl`` which is a gurobipy model.
#
# Table of contents:
# - Import case: import ADNES case
# - Load synthetic: build load curve as a scalar
# - Setup ``ssp`` and ``ssd``
# - Prepare: define some functions
# - Define param: define RTED loop parameters
# - Loop: Co-Sim loop
#
# List of major vars:
#
# - ``ssa`` ANDES system
# - ``ssp`` pandapower net
# - ``ssd`` DCOPF instance
# - ``sse`` EV aggregator
#
# Things need to be done when switching to other cases:
# - Assign generator cost data. The rows of gen_cost array should be the same with the length of ``ssp.gen``
#   including those uncontrollable ones, so the DCOPF model can build correctly.
# - Define generator controllability of ``ssp``, all generators are controllable by default
# - Define power system data: SFR cost, ramp limit (5-min-based)
# - Define generator type in ``ssd``, default as type I. For type I generator, generator limtis have impact on both generation and SFR capacity. For yype II generator, SFR capacity is determined by param ``pru_max`` and ``prd_max``
#
# Environment requirements:
# - ANDES (1.6.3+)
# - pandapower (2.7.0 is tested to be function correctly)
# - gurobipy
# - pandas, matplotlib, scipy

# %% [markdown]
# ## Import case

# %%
# %run -i 'cosim_import.py'
# Out:
# 0.post4598.dev0+gc6db20d
# 2.8.0

# %% [markdown]
# `caseH` is the start time [H] of the co-simulation, now 10 and 18 are supported.

# %%
# if save the data to CSV
save_data = True
file_beging = 'cosim_'
sim_name = 'ieee39_f'

# case parameters
case_name = 'ieee39'
caseH = 18  # start time [H] of the co-simulation
ict = False
ecc = False
agc = True

# Change ``rru``, ``rrd``, ``rsfr``, ``t_total`` for necessary.
t_total = 3600

rru, rrd, rsfr = 1.0, 1.0, 0.05

# %%
# %run -i 'cosim_setup_andes.py'
# Out:
# EVA: ts=18[H], 50000 EVs, Total Q=434.54 MWh
# Online 14477, Q=362.27 MWh, SoC=0.7435
# Power(MW): Pt=-39.0266, Pc=-39.0266, Pd=0.0
# Ctrl: 0=7897; 1=6580;
# EVA: Load A from Aest.csv.

# %% [markdown]
# ## Load synthetic
#
# Create load data ``d_syn``, which is a ``DataFrame`` that have three columns: ``time``, ``s10``, ``h10``. ``time`` is by seconds, ``s10`` is scalar load.

# %%
# %run -i 'cosim_loadsyn.py'
# Out:
# ANDES total load is: 58.564 p.u.

# %% [markdown]
# ## Setup ``ssp`` and ``ssd``
#
# Convert ``ssa`` to pandapower net ``ssp``, add generator cost
#
# The input cost array follow the matpower/pypower format, now only poly_cost is supported

# %%
# %run -i 'cosim_setup_dispatch.py'
# Out:
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 11 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2023-04-08
# RTED GB model is loaded.
# RTED removed: ['rampu', 'rampd']
# RTED limited: sfru, sfrd
# RTED: total cost=4889.131

# %% [markdown]
# ## Loop
#
# In the loop, there are mainly X parts:
#
# - interval RTED: run DCOPF (``ssd.mdl``), run ACOPF(``ssp``),
#
# - interval AGC: do AGC, do dispatch with smooth setpoints
#
# - interval PQ: alter load, run TDS(``ssa.TDS``)
#
# Notes:
#
# - The setpoints for DG are coded but not verified yet.
#
# - After the development of ANDES control room, the dispatch and AGC part can be refactored.
#
# - interface variables: ``DG.pmx``: DPV profile, ``DG.pref0``: setpoints, ``DG.pext0``: AGC
#
# - ACOPF in pandapower considered generator limtis of ramping and SFR reserve

# %% [markdown]
# Loop

# %%
# andes.config_logger(stream_level=20)

# %%
# %run -i 'cosim_main.py'
# Out:
#   0%|          | 0/3600 [00:00<?, ?it/s]RTED GB model is loaded.
# RTED removed: ['rampu', 'rampd']
# RTED is solved.
# RTED: total cost=4658.49
#   8%|▊         | 299/3600 [00:28<04:39, 11.80it/s]RTED GB model is loaded.
# RTED is solved.
# RTED: total cost=4648.12
#  17%|█▋        | 600/3600 [00:56<04:58, 10.05it/s]RTED GB model is loaded.
# RTED is solved.
# RTED: total cost=4683.936
#  25%|██▌       | 900/3600 [01:30<05:46,  7.79it/s]RTED GB model is loaded.
# RTED is solved.
# RTED: total cost=4686.505
#  33%|███▎      | 1200/3600 [02:10<07:36,  5.26it/s]RTED GB model is loaded.
# RTED is solved.
# RTED: total cost=4699.69
#  42%|████▏     | 1500/3600 [02:53<04:36,  7.61it/s]RTED GB model is loaded.
# RTED is solved.
# RTED: total cost=4696.095
#  50%|█████     | 1800/3600 [03:36<04:40,  6.41it/s]RTED GB model is loaded.
# RTED is solved.
# RTED: total cost=4706.467
#  58%|█████▊    | 2100/3600 [04:19<03:14,  7.69it/s]RTED GB model is loaded.
# RTED is solved.
# RTED: total cost=4741.653
#  67%|██████▋   | 2400/3600 [05:01<02:48,  7.13it/s]RTED GB model is loaded.
# RTED is solved.
# RTED: total cost=4734.685
#  75%|███████▌  | 2700/3600 [05:45<02:09,  6.94it/s]RTED GB model is loaded.
# RTED is solved.
# RTED: total cost=4707.368
#  83%|████████▎ | 3000/3600 [06:33<01:29,  6.71it/s]RTED GB model is loaded.
# RTED is solved.
# RTED: total cost=4673.78
#  92%|█████████▏| 3300/3600 [07:22<00:49,  6.03it/s]RTED GB model is loaded.
# RTED is solved.
# RTED: total cost=4676.939
# 100%|██████████| 3600/3600 [08:15<00:00,  7.26it/s]

# %%
ssa.exit_code
# Out:
# 0

# %%
sse.ict()
sse.plot_agc(figsize=(12, 5), style='science', dpi=400)
# Out:
# (<Figure size 4800x2000 with 1 Axes>,
#  <AxesSubplot:title={'center':'AGC response'}, xlabel='Time [s]', ylabel='Power (MW)'>)

# %%
# %run -i 'cosim_plot.py'
ax_gen[0, 1].set_ylim([-40, 60])
# Out:
# (-40.0, 60.0)

# %%
# %run -i 'cosim_savedata.py'
# Out:
# Successfully save data.

# %%
ssa.TDS.save_output()
# Out:
# True

# %%
# !andes plot ieee39_ev2_out.npz --to-csv
# Out:
# Traceback (most recent call last):
#   File "/Users/jinningwang/Documents/work/mambaforge/envs/andes/bin/andes", line 33, in <module>
#     sys.exit(load_entry_point('andes', 'console_scripts', 'andes')())
#   File "/Users/jinningwang/Documents/work/andes/andes/cli.py", line 235, in main
#     return func(cli=True, **vars(args))
#   File "/Users/jinningwang/Documents/work/andes/andes/main.py", line 698, in plot
#     return tdsplot(*args, **kwargs)
#   File "/Users/jinningwang/Documents/work/andes/andes/plot.py", line 1135, in tdsplot
#     tds_data = TDSData(filename[0])
#   File "/Users/jinningwang/Documents/work/andes/andes/plot.py", line 122, in __init__
#     self.load_lst()
#   File "/Users/jinningwang/Documents/work/andes/andes/plot.py", line 192, in load_lst
#     with open(self._lst_file, 'r') as fd:
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/jinningwang/Documents/work/andes/jwang/notes/ieee39_ev2_out.lst'

# %%
# !andes misc -C
# Out:
# "/Users/jinningwang/Documents/work/andes/jwang/notes/ieee14_ac8b_out.txt" removed.
# "/Users/jinningwang/Documents/work/andes/jwang/notes/ieee39_ev2_out.txt" removed.
# "/Users/jinningwang/Documents/work/andes/jwang/notes/ieee39_ev2_out.npz" removed.

# %%
ssa.TDS.plt.export_csv(path='/Users/jinningwang/Documents/work/andes/jwang/output/ieee39_ev_f_out.csv')
