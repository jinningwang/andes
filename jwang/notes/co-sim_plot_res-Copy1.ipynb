# %%
# %run -i 'cosim_import.py'
import csv
import multiprocessing
# Out:
# 1.7.2.post300.dev0+geda85927
# 2.9.0

# %%
caseH = 18
# %run -i 'cosim_setup_andes.py'
# Out:
# EVA: ts=18[H], 50000 EVs, Total Q=434.64 MWh
# Online 14481, Q=361.83 MWh, SoC=0.7687
# Power(MW): Pt=-39.9433, Pc=-39.9433, Pd=-0.0
# Ctrl: 0=7778; 1=6703;
# EVA: Load A from Aest.csv.
# Working directory: "/home/jwang175/andes/jwang/notes"
# > Loaded config from file "/home/jwang175/.andes/andes.rc"
# > Loaded generated Python code in "/home/jwang175/.andes/pycode".
# Generated code for <PQ> is stale.
# Numerical code generation (rapid incremental mode) started...
# Generating code for 1 models on 6 processes.
# Saved generated pycode to "/home/jwang175/.andes/pycode"
# > Reloaded generated Python code of module "pycode".
# Generated numerical code for 1 models in 0.3123 seconds.
# Parsing input file "/home/jwang175/andes/jwang/case/ieee39_ev2.xlsx"...
# Input file parsed in 0.1452 seconds.
# ACEc <1> added BusFreq <BusFreq_11> linked to bus <1>
# System internal structure set up in 0.0644 seconds.

# %%
def sumall(value):
    return sum(range(1, value + 1))

pool_obj = multiprocessing.Pool()

answer = pool_obj.map(sumall,range(0,5))
print(answer)
# Out:
# [0, 1, 3, 6, 10]

# %%
def g_frc_ev(time):
    sse1 = ev_ssm(ts=time, N=5000, step=1, tp=40,
                  lr=0.1, lp=60, seed=2022, name="EVA")
    frcu, frcd = sse1.g_frc()
    return [time, frcu, frcd, sse1.ne]

pool_obj = multiprocessing.Pool()
answer = pool_obj.map(g_frc_ev, np.arange(1/60, 24, 1/60))
# Out:
# EVA: ts=0.0167[H], 5000 EVs, Total Q=32.36 MWh
# Online 24, Q=0.6 MWh, SoC=0.2976
# Power(MW): Pt=-0.1519, Pc=-0.1519, Pd=-0.0
# Ctrl: 1=24;
# EVA: ts=1.0167[H], 5000 EVs, Total Q=48.52 MWh
# Online 1283, Q=32.12 MWh, SoC=0.4228
# Power(MW): Pt=-7.7056, Pc=-7.7056, Pd=-0.0
# Ctrl: 1=1283;
# EVA: ts=2.0167[H], 5000 EVs, Total Q=56.6 MWh
# Online 1915, Q=47.82 MWh, SoC=0.5684
# Power(MW): Pt=-10.8822, Pc=-10.8822, Pd=-0.0
# Ctrl: 1=1820; 0=95;
# EVA: ts=2.5167[H], 5000 EVs, Total Q=58.24 MWh
# Online 2111, Q=52.72 MWh, SoC=0.6447
# Power(MW): Pt=-9.9267, Pc=-9.9267, Pd=-0.0
# Ctrl: 1=1673; 0=438;
# EVA: ts=3.5167[H], 5000 EVs, Total Q=58.5 MWh
# Online 2266, Q=56.59 MWh, SoC=0.8014
# Power(MW): Pt=-5.4074, Pc=-5.4074, Pd=-0.0
# Ctrl: 0=1341; 1=925;
# EVA: ts=5.5167[H], 5000 EVs, Total Q=52.38 MWh
# Online 2096, Q=52.33 MWh, SoC=0.9629
# Power(MW): Pt=-0.8988, Pc=-0.8988, Pd=-0.0
# Ctrl: 0=1942; 1=154;
# EVA: ts=4.0167[H], 5000 EVs, Total Q=57.68 MWh
# Online 2259, Q=56.41 MWh, SoC=0.8656
# Power(MW): Pt=-3.7267, Pc=-3.7267, Pd=-0.0
# Ctrl: 0=1620; 1=639;
# EVA: ts=4.5167[H], 5000 EVs, Total Q=56.69 MWh
# Online 2238, Q=55.87 MWh, SoC=0.91
# Power(MW): Pt=-2.4539, Pc=-2.4539, Pd=-0.0
# Ctrl: 0=1818; 1=420;
# EVA: ts=5.0167[H], 5000 EVs, Total Q=54.52 MWh
# Online 2169, Q=54.16 MWh, SoC=0.9427
# Power(MW): Pt=-1.3926, Pc=-1.3926, Pd=-0.0
# Ctrl: 0=1931; 1=238;
# EVA: ts=1.5167[H], 5000 EVs, Total Q=53.72 MWh
# Online 1663, Q=41.61 MWh, SoC=0.4922
# Power(MW): Pt=-9.9681, Pc=-9.9681, Pd=-0.0
# Ctrl: 1=1659; 0=4;
# EVA: ts=3.0167[H], 5000 EVs, Total Q=58.53 MWh
# Online 2215, Q=55.28 MWh, SoC=0.7268
# Power(MW): Pt=-7.7199, Pc=-7.7199, Pd=-0.0
# Ctrl: 1=1312; 0=903;
# EVA: ts=0.5167[H], 5000 EVs, Total Q=42.04 MWh
# Online 735, Q=18.21 MWh, SoC=0.3597
# Power(MW): Pt=-4.4204, Pc=-4.4204, Pd=-0.0
# Ctrl: 1=735;
# EVA: ts=0.0333[H], 5000 EVs, Total Q=32.71 MWh
# Online 49, Q=1.22 MWh, SoC=0.3017
# Power(MW): Pt=-0.3065, Pc=-0.3065, Pd=-0.0
# Ctrl: 1=49;
# EVA: ts=1.0333[H], 5000 EVs, Total Q=48.83 MWh
# Online 1297, Q=32.47 MWh, SoC=0.4249
# Power(MW): Pt=-7.7897, Pc=-7.7897, Pd=-0.0
# Ctrl: 1=1297;
# EVA: ts=1.5333[H], 5000 EVs, Total Q=53.76 MWh
# Online 1666, Q=41.68 MWh, SoC=0.4954
# Power(MW): Pt=-9.9864, Pc=-9.9864, Pd=-0.0
# Ctrl: 1=1662; 0=4;
# EVA: ts=2.0333[H], 5000 EVs, Total Q=56.6 MWh
# Online 1927, Q=48.13 MWh, SoC=0.5704
# Power(MW): Pt=-10.9328, Pc=-10.9328, Pd=-0.0
# Ctrl: 1=1829; 0=98;
# EVA: ts=4.5333[H], 5000 EVs, Total Q=56.64 MWh
# Online 2236, Q=55.82 MWh, SoC=0.9113
# Power(MW): Pt=-2.431, Pc=-2.431, Pd=-0.0
# Ctrl: 0=1820; 1=416;
# EVA: ts=4.0333[H], 5000 EVs, Total Q=57.67 MWh
# Online 2260, Q=56.43 MWh, SoC=0.8668
# Power(MW): Pt=-3.6674, Pc=-3.6674, Pd=-0.0
# Ctrl: 0=1631; 1=629;
# EVA: ts=2.5333[H], 5000 EVs, Total Q=58.26 MWh
# Online 2114, Q=52.79 MWh, SoC=0.6479
# Power(MW): Pt=-9.8486, Pc=-9.8486, Pd=-0.0
# Ctrl: 1=1661; 0=453;
# EVA: ts=3.5333[H], 5000 EVs, Total Q=58.47 MWh
# Online 2266, Q=56.6 MWh, SoC=0.804
# Power(MW): Pt=-5.326, Pc=-5.326, Pd=-0.0
# Ctrl: 0=1354; 1=912;
# EVA: ts=5.5333[H], 5000 EVs, Total Q=52.33 MWh
# Online 2094, Q=52.29 MWh, SoC=0.9637
# Power(MW): Pt=-0.8741, Pc=-0.8741, Pd=-0.0
# Ctrl: 0=1944; 1=150;
# EVA: ts=5.0333[H], 5000 EVs, Total Q=54.46 MWh
# Online 2166, Q=54.1 MWh, SoC=0.9433
# Power(MW): Pt=-1.3879, Pc=-1.3879, Pd=-0.0
# Ctrl: 0=1929; 1=237;
# EVA: ts=3.0333[H], 5000 EVs, Total Q=58.53 MWh
# Online 2212, Q=55.21 MWh, SoC=0.7302
# Power(MW): Pt=-7.631, Pc=-7.631, Pd=-0.0
# Ctrl: 1=1297; 0=915;
# EVA: ts=0.5333[H], 5000 EVs, Total Q=42.14 MWh
# Online 757, Q=18.77 MWh, SoC=0.3618
# Power(MW): Pt=-4.5518, Pc=-4.5518, Pd=-0.0
# Ctrl: 1=757;
# EVA: ts=0.05[H], 5000 EVs, Total Q=32.9 MWh
# Online 70, Q=1.74 MWh, SoC=0.3046
# Power(MW): Pt=-0.4386, Pc=-0.4386, Pd=-0.0
# Ctrl: 1=70;
# EVA: ts=1.05[H], 5000 EVs, Total Q=49.01 MWh
# Online 1304, Q=32.66 MWh, SoC=0.4277
# Power(MW): Pt=-7.832, Pc=-7.832, Pd=-0.0
# Ctrl: 1=1304;
# EVA: ts=1.55[H], 5000 EVs, Total Q=53.82 MWh
# Online 1674, Q=41.89 MWh, SoC=0.498
# Power(MW): Pt=-10.032, Pc=-10.032, Pd=-0.0
# Ctrl: 1=1670; 0=4;
# EVA: ts=4.05[H], 5000 EVs, Total Q=57.67 MWh
# Online 2259, Q=56.41 MWh, SoC=0.8689
# Power(MW): Pt=-3.6165, Pc=-3.6165, Pd=-0.0
# Ctrl: 0=1639; 1=620;
# EVA: ts=2.55[H], 5000 EVs, Total Q=58.32 MWh
# Online 2117, Q=52.86 MWh, SoC=0.651
# Power(MW): Pt=-9.7891, Pc=-9.7891, Pd=-0.0
# Ctrl: 1=1651; 0=466;
# EVA: ts=2.05[H], 5000 EVs, Total Q=56.66 MWh
# Online 1933, Q=48.28 MWh, SoC=0.5731
# Power(MW): Pt=-10.9092, Pc=-10.9092, Pd=-0.0
# Ctrl: 1=1826; 0=107;
# EVA: ts=4.55[H], 5000 EVs, Total Q=56.61 MWh
# Online 2236, Q=55.83 MWh, SoC=0.9125
# Power(MW): Pt=-2.4248, Pc=-2.4248, Pd=-0.0
# Ctrl: 0=1821; 1=415;
# EVA: ts=5.05[H], 5000 EVs, Total Q=54.42 MWh
# Online 2165, Q=54.09 MWh, SoC=0.944
# Power(MW): Pt=-1.3657, Pc=-1.3657, Pd=-0.0
# Ctrl: 0=1932; 1=233;
# EVA: ts=5.55[H], 5000 EVs, Total Q=52.26 MWh
# Online 2091, Q=52.21 MWh, SoC=0.9643
# Power(MW): Pt=-0.8687, Pc=-0.8687, Pd=-0.0
# Ctrl: 0=1942; 1=149;
# EVA: ts=3.55[H], 5000 EVs, Total Q=58.5 MWh
# Online 2269, Q=56.67 MWh, SoC=0.806
# Power(MW): Pt=-5.2724, Pc=-5.2724, Pd=-0.0
# Ctrl: 0=1366; 1=903;
# EVA: ts=0.55[H], 5000 EVs, Total Q=42.38 MWh
# Online 780, Q=19.35 MWh, SoC=0.3634
# Power(MW): Pt=-4.6859, Pc=-4.6859, Pd=-0.0
# Ctrl: 1=780;
# EVA: ts=3.05[H], 5000 EVs, Total Q=58.49 MWh
# Online 2213, Q=55.24 MWh, SoC=0.7328
# Power(MW): Pt=-7.5198, Pc=-7.5198, Pd=-0.0
# Ctrl: 1=1278; 0=935;
# EVA: ts=0.0667[H], 5000 EVs, Total Q=33.31 MWh
# Online 94, Q=2.35 MWh, SoC=0.3077
# Power(MW): Pt=-0.5816, Pc=-0.5816, Pd=-0.0
# Ctrl: 1=94;
# EVA: ts=1.5667[H], 5000 EVs, Total Q=53.96 MWh
# Online 1676, Q=41.95 MWh, SoC=0.5013
# Power(MW): Pt=-10.0459, Pc=-10.0459, Pd=-0.0
# Ctrl: 1=1672; 0=4;
# EVA: ts=4.0667[H], 5000 EVs, Total Q=57.67 MWh
# Online 2258, Q=56.38 MWh, SoC=0.871
# Power(MW): Pt=-3.5402, Pc=-3.5402, Pd=-0.0
# Ctrl: 0=1651; 1=607;
# EVA: ts=1.0667[H], 5000 EVs, Total Q=49.15 MWh
# Online 1320, Q=33.07 MWh, SoC=0.43
# Power(MW): Pt=-7.9284, Pc=-7.9284, Pd=-0.0
# Ctrl: 1=1320;
# EVA: ts=2.5667[H], 5000 EVs, Total Q=58.34 MWh
# Online 2121, Q=52.97 MWh, SoC=0.6535
# Power(MW): Pt=-9.7, Pc=-9.7, Pd=-0.0
# Ctrl: 1=1637; 0=484;
# EVA: ts=2.0667[H], 5000 EVs, Total Q=56.64 MWh
# Online 1938, Q=48.4 MWh, SoC=0.576
# Power(MW): Pt=-10.8793, Pc=-10.8793, Pd=-0.0
# Ctrl: 1=1822; 0=116;
# EVA: ts=5.5667[H], 5000 EVs, Total Q=52.07 MWh
# Online 2084, Q=52.02 MWh, SoC=0.965
# Power(MW): Pt=-0.8503, Pc=-0.8503, Pd=-0.0
# Ctrl: 0=1938; 1=146;
# EVA: ts=0.5667[H], 5000 EVs, Total Q=42.45 MWh
# Online 805, Q=19.98 MWh, SoC=0.3651
# Power(MW): Pt=-4.8353, Pc=-4.8353, Pd=-0.0
# Ctrl: 1=805;
# EVA: ts=5.0667[H], 5000 EVs, Total Q=54.36 MWh
# Online 2164, Q=54.05 MWh, SoC=0.9447
# Power(MW): Pt=-1.3355, Pc=-1.3355, Pd=-0.0
# Ctrl: 0=1936; 1=228;
# EVA: ts=3.5667[H], 5000 EVs, Total Q=58.48 MWh
# Online 2269, Q=56.68 MWh, SoC=0.8081
# Power(MW): Pt=-5.1856, Pc=-5.1856, Pd=-0.0
# Ctrl: 0=1381; 1=888;
# EVA: ts=4.5667[H], 5000 EVs, Total Q=56.54 MWh
# Online 2235, Q=55.8 MWh, SoC=0.9135
# Power(MW): Pt=-2.4016, Pc=-2.4016, Pd=-0.0
# Ctrl: 0=1824; 1=411;
# EVA: ts=0.0833[H], 5000 EVs, Total Q=33.72 MWh
# Online 117, Q=2.93 MWh, SoC=0.3067
# Power(MW): Pt=-0.7199, Pc=-0.7199, Pd=-0.0
# Ctrl: 1=117;
# EVA: ts=3.0667[H], 5000 EVs, Total Q=58.49 MWh
# Online 2213, Q=55.24 MWh, SoC=0.7361
# Power(MW): Pt=-7.4222, Pc=-7.4222, Pd=-0.0
# Ctrl: 1=1262; 0=951;
# EVA: ts=1.5833[H], 5000 EVs, Total Q=54.11 MWh
# Online 1686, Q=42.2 MWh, SoC=0.5038
# Power(MW): Pt=-10.0994, Pc=-10.0994, Pd=-0.0
# Ctrl: 1=1681; 0=5;
# EVA: ts=2.0833[H], 5000 EVs, Total Q=56.71 MWh
# Online 1946, Q=48.6 MWh, SoC=0.5782
# Power(MW): Pt=-10.8472, Pc=-10.8472, Pd=-0.0
# Ctrl: 1=1818; 0=128;
# EVA: ts=1.0833[H], 5000 EVs, Total Q=49.36 MWh
# Online 1335, Q=33.46 MWh, SoC=0.4321
# Power(MW): Pt=-8.0234, Pc=-8.0234, Pd=-0.0
# Ctrl: 1=1335;
# EVA: ts=5.5833[H], 5000 EVs, Total Q=52.01 MWh
# Online 2082, Q=51.96 MWh, SoC=0.9656
# Power(MW): Pt=-0.8328, Pc=-0.8328, Pd=-0.0
# Ctrl: 0=1939; 1=143;
# EVA: ts=4.0833[H], 5000 EVs, Total Q=57.66 MWh
# Online 2258, Q=56.38 MWh, SoC=0.8727
# Power(MW): Pt=-3.5092, Pc=-3.5092, Pd=-0.0
# Ctrl: 0=1656; 1=602;
# EVA: ts=3.5833[H], 5000 EVs, Total Q=58.46 MWh
# Online 2268, Q=56.66 MWh, SoC=0.8105
# Power(MW): Pt=-5.1201, Pc=-5.1201, Pd=-0.0
# Ctrl: 0=1391; 1=877;
# EVA: ts=0.5833[H], 5000 EVs, Total Q=42.68 MWh
# Online 822, Q=20.42 MWh, SoC=0.367
# Power(MW): Pt=-4.9367, Pc=-4.9367, Pd=-0.0
# Ctrl: 1=822;
# EVA: ts=2.5833[H], 5000 EVs, Total Q=58.37 MWh
# Online 2127, Q=53.12 MWh, SoC=0.6561
# Power(MW): Pt=-9.6182, Pc=-9.6182, Pd=-0.0
# Ctrl: 1=1624; 0=503;
# EVA: ts=5.0833[H], 5000 EVs, Total Q=54.34 MWh
# Online 2164, Q=54.05 MWh, SoC=0.9454
# Power(MW): Pt=-1.3363, Pc=-1.3363, Pd=-0.0
# Ctrl: 0=1936; 1=228;
# EVA: ts=0.1[H], 5000 EVs, Total Q=34.21 MWh
# Online 143, Q=3.57 MWh, SoC=0.3079
# Power(MW): Pt=-0.8782, Pc=-0.8782, Pd=-0.0
# Ctrl: 1=143;
# EVA: ts=3.0833[H], 5000 EVs, Total Q=58.51 MWh
# Online 2217, Q=55.35 MWh, SoC=0.7386
# Power(MW): Pt=-7.31, Pc=-7.31, Pd=-0.0
# Ctrl: 1=1244; 0=973;
# EVA: ts=1.6[H], 5000 EVs, Total Q=54.27 MWh
# Online 1692, Q=42.33 MWh, SoC=0.5067
# Power(MW): Pt=-10.1319, Pc=-10.1319, Pd=-0.0
# Ctrl: 1=1687; 0=5;
# EVA: ts=1.1[H], 5000 EVs, Total Q=49.44 MWh
# Online 1356, Q=33.95 MWh, SoC=0.4339
# Power(MW): Pt=-8.1519, Pc=-8.1519, Pd=-0.0
# Ctrl: 1=1356;
# EVA: ts=4.5833[H], 5000 EVs, Total Q=56.47 MWh
# Online 2233, Q=55.75 MWh, SoC=0.9148
# Power(MW): Pt=-2.3542, Pc=-2.3542, Pd=-0.0
# Ctrl: 0=1830; 1=403;
# EVA: ts=5.6[H], 5000 EVs, Total Q=51.94 MWh
# Online 2079, Q=51.89 MWh, SoC=0.9662
# Power(MW): Pt=-0.8211, Pc=-0.8211, Pd=-0.0
# Ctrl: 0=1938; 1=141;
# EVA: ts=2.1[H], 5000 EVs, Total Q=56.76 MWh
# Online 1948, Q=48.66 MWh, SoC=0.5814
# Power(MW): Pt=-10.8271, Pc=-10.8271, Pd=-0.0
# Ctrl: 1=1815; 0=133;
# EVA: ts=3.6[H], 5000 EVs, Total Q=58.41 MWh
# Online 2270, Q=56.71 MWh, SoC=0.8121
# Power(MW): Pt=-5.0788, Pc=-5.0788, Pd=-0.0
# Ctrl: 0=1400; 1=870;
# EVA: ts=0.6[H], 5000 EVs, Total Q=42.87 MWh
# Online 834, Q=20.7 MWh, SoC=0.37
# Power(MW): Pt=-5.0077, Pc=-5.0077, Pd=-0.0
# Ctrl: 1=834;
# EVA: ts=3.1[H], 5000 EVs, Total Q=58.44 MWh
# Online 2216, Q=55.33 MWh, SoC=0.7413
# Power(MW): Pt=-7.231, Pc=-7.231, Pd=-0.0
# Ctrl: 1=1231; 0=985;
# EVA: ts=5.1[H], 5000 EVs, Total Q=54.24 MWh
# Online 2160, Q=53.95 MWh, SoC=0.9463
# Power(MW): Pt=-1.2753, Pc=-1.2753, Pd=-0.0
# Ctrl: 0=1942; 1=218;
# EVA: ts=1.6167[H], 5000 EVs, Total Q=54.34 MWh
# Online 1706, Q=42.67 MWh, SoC=0.5086
# Power(MW): Pt=-10.2052, Pc=-10.2052, Pd=-0.0
# Ctrl: 1=1700; 0=6;
# EVA: ts=4.1[H], 5000 EVs, Total Q=57.58 MWh
# Online 2256, Q=56.32 MWh, SoC=0.8745
# Power(MW): Pt=-3.4446, Pc=-3.4446, Pd=-0.0
# Ctrl: 0=1665; 1=591;
# EVA: ts=2.6[H], 5000 EVs, Total Q=58.46 MWh
# Online 2135, Q=53.31 MWh, SoC=0.6583
# Power(MW): Pt=-9.6291, Pc=-9.6291, Pd=-0.0
# Ctrl: 1=1626; 0=509;
# EVA: ts=0.1167[H], 5000 EVs, Total Q=34.48 MWh
# Online 171, Q=4.26 MWh, SoC=0.3114
# Power(MW): Pt=-1.0484, Pc=-1.0484, Pd=-0.0
# Ctrl: 1=171;
# EVA: ts=1.1167[H], 5000 EVs, Total Q=49.67 MWh
# Online 1366, Q=34.22 MWh, SoC=0.4366
# Power(MW): Pt=-8.2074, Pc=-8.2074, Pd=-0.0
# Ctrl: 1=1366;
# EVA: ts=5.6167[H], 5000 EVs, Total Q=51.88 MWh
# Online 2077, Q=51.83 MWh, SoC=0.9668
# Power(MW): Pt=-0.8, Pc=-0.8, Pd=-0.0
# Ctrl: 0=1940; 1=137;
# EVA: ts=3.6167[H], 5000 EVs, Total Q=58.35 MWh
# Online 2268, Q=56.66 MWh, SoC=0.8146
# Power(MW): Pt=-5.0081, Pc=-5.0081, Pd=-0.0
# Ctrl: 0=1410; 1=858;
# EVA: ts=2.1167[H], 5000 EVs, Total Q=56.79 MWh
# Online 1955, Q=48.85 MWh, SoC=0.5835
# Power(MW): Pt=-10.807, Pc=-10.807, Pd=-0.0
# Ctrl: 1=1812; 0=143;
# EVA: ts=3.1167[H], 5000 EVs, Total Q=58.44 MWh
# Online 2219, Q=55.4 MWh, SoC=0.7439
# Power(MW): Pt=-7.1739, Pc=-7.1739, Pd=-0.0
# Ctrl: 1=1222; 0=997;
# EVA: ts=4.6[H], 5000 EVs, Total Q=56.42 MWh
# Online 2232, Q=55.73 MWh, SoC=0.9162
# Power(MW): Pt=-2.3001, Pc=-2.3001, Pd=-0.0
# Ctrl: 0=1838; 1=394;
# EVA: ts=5.1167[H], 5000 EVs, Total Q=54.21 MWh
# Online 2159, Q=53.92 MWh, SoC=0.9473
# Power(MW): Pt=-1.2597, Pc=-1.2597, Pd=-0.0
# Ctrl: 0=1944; 1=215;
# EVA: ts=2.6167[H], 5000 EVs, Total Q=58.46 MWh
# Online 2137, Q=53.35 MWh, SoC=0.6614
# Power(MW): Pt=-9.5393, Pc=-9.5393, Pd=-0.0
# Ctrl: 1=1612; 0=525;
# EVA: ts=4.1167[H], 5000 EVs, Total Q=57.52 MWh
# Online 2254, Q=56.26 MWh, SoC=0.8766
# Power(MW): Pt=-3.3761, Pc=-3.3761, Pd=-0.0
# Ctrl: 0=1675; 1=579;
# EVA: ts=0.1333[H], 5000 EVs, Total Q=34.78 MWh
# Online 191, Q=4.76 MWh, SoC=0.3147
# Power(MW): Pt=-1.1689, Pc=-1.1689, Pd=-0.0
# Ctrl: 1=191;
# EVA: ts=1.1333[H], 5000 EVs, Total Q=49.88 MWh
# Online 1377, Q=34.5 MWh, SoC=0.4392
# Power(MW): Pt=-8.2738, Pc=-8.2738, Pd=-0.0
# Ctrl: 1=1377;
# EVA: ts=1.6333[H], 5000 EVs, Total Q=54.45 MWh
# Online 1718, Q=42.98 MWh, SoC=0.5107
# Power(MW): Pt=-10.265, Pc=-10.265, Pd=-0.0
# Ctrl: 1=1710; 0=8;
# EVA: ts=0.6167[H], 5000 EVs, Total Q=43.2 MWh
# Online 853, Q=21.2 MWh, SoC=0.3722
# Power(MW): Pt=-5.1238, Pc=-5.1238, Pd=-0.0
# Ctrl: 1=853;
# EVA: ts=5.6333[H], 5000 EVs, Total Q=51.86 MWh
# Online 2076, Q=51.81 MWh, SoC=0.9674
# Power(MW): Pt=-0.7891, Pc=-0.7891, Pd=-0.0
# Ctrl: 0=1941; 1=135;
# EVA: ts=3.1333[H], 5000 EVs, Total Q=58.41 MWh
# Online 2221, Q=55.45 MWh, SoC=0.7465
# Power(MW): Pt=-7.0706, Pc=-7.0706, Pd=-0.0
# Ctrl: 1=1205; 0=1016;
# EVA: ts=3.6333[H], 5000 EVs, Total Q=58.43 MWh
# Online 2268, Q=56.66 MWh, SoC=0.8172
# Power(MW): Pt=-4.931, Pc=-4.931, Pd=-0.0
# Ctrl: 0=1423; 1=845;
# EVA: ts=5.1333[H], 5000 EVs, Total Q=54.16 MWh
# Online 2157, Q=53.87 MWh, SoC=0.9482
# Power(MW): Pt=-1.2252, Pc=-1.2252, Pd=-0.0
# Ctrl: 0=1948; 1=209;
# EVA: ts=4.6167[H], 5000 EVs, Total Q=56.4 MWh
# Online 2232, Q=55.73 MWh, SoC=0.9173
# Power(MW): Pt=-2.2899, Pc=-2.2899, Pd=-0.0
# Ctrl: 0=1840; 1=392;
# EVA: ts=2.1333[H], 5000 EVs, Total Q=56.83 MWh
# Online 1962, Q=49.02 MWh, SoC=0.5858
# Power(MW): Pt=-10.7925, Pc=-10.7925, Pd=-0.0
# Ctrl: 1=1810; 0=152;
# EVA: ts=2.6333[H], 5000 EVs, Total Q=58.46 MWh
# Online 2141, Q=53.46 MWh, SoC=0.6643
# Power(MW): Pt=-9.45, Pc=-9.45, Pd=-0.0
# Ctrl: 1=1598; 0=543;
# EVA: ts=1.15[H], 5000 EVs, Total Q=50.1 MWh
# Online 1388, Q=34.76 MWh, SoC=0.4418
# Power(MW): Pt=-8.3425, Pc=-8.3425, Pd=-0.0
# Ctrl: 1=1388;
# EVA: ts=4.1333[H], 5000 EVs, Total Q=57.5 MWh
# Online 2254, Q=56.26 MWh, SoC=0.8783
# Power(MW): Pt=-3.3297, Pc=-3.3297, Pd=-0.0
# Ctrl: 0=1683; 1=571;
# EVA: ts=0.15[H], 5000 EVs, Total Q=35.04 MWh
# Online 225, Q=5.61 MWh, SoC=0.3161
# Power(MW): Pt=-1.3722, Pc=-1.3722, Pd=-0.0
# Ctrl: 1=225;
# EVA: ts=0.6333[H], 5000 EVs, Total Q=43.52 MWh
# Online 883, Q=21.97 MWh, SoC=0.3739
# Power(MW): Pt=-5.3057, Pc=-5.3057, Pd=-0.0
# Ctrl: 1=883;
# EVA: ts=5.65[H], 5000 EVs, Total Q=51.78 MWh
# Online 2073, Q=51.73 MWh, SoC=0.968
# Power(MW): Pt=-0.7714, Pc=-0.7714, Pd=-0.0
# Ctrl: 0=1941; 1=132;
# EVA: ts=1.65[H], 5000 EVs, Total Q=54.55 MWh
# Online 1732, Q=43.31 MWh, SoC=0.5124
# Power(MW): Pt=-10.3506, Pc=-10.3506, Pd=-0.0
# Ctrl: 1=1724; 0=8;
# EVA: ts=3.65[H], 5000 EVs, Total Q=58.41 MWh
# Online 2269, Q=56.68 MWh, SoC=0.8194
# Power(MW): Pt=-4.8839, Pc=-4.8839, Pd=-0.0
# Ctrl: 0=1432; 1=837;
# EVA: ts=3.15[H], 5000 EVs, Total Q=58.47 MWh
# Online 2222, Q=55.49 MWh, SoC=0.7494
# Power(MW): Pt=-6.942, Pc=-6.942, Pd=-0.0
# Ctrl: 1=1183; 0=1039;
# EVA: ts=4.6333[H], 5000 EVs, Total Q=56.34 MWh
# Online 2233, Q=55.75 MWh, SoC=0.918
# Power(MW): Pt=-2.2657, Pc=-2.2657, Pd=-0.0
# Ctrl: 0=1845; 1=388;
# EVA: ts=2.15[H], 5000 EVs, Total Q=56.87 MWh
# Online 1970, Q=49.22 MWh, SoC=0.5881
# Power(MW): Pt=-10.7857, Pc=-10.7857, Pd=-0.0
# Ctrl: 1=1809; 0=161;
# EVA: ts=0.1667[H], 5000 EVs, Total Q=35.35 MWh
# Online 256, Q=6.39 MWh, SoC=0.3189
# Power(MW): Pt=-1.5568, Pc=-1.5568, Pd=-0.0
# Ctrl: 1=256;
# EVA: ts=1.1667[H], 5000 EVs, Total Q=50.33 MWh
# Online 1400, Q=35.07 MWh, SoC=0.4441
# Power(MW): Pt=-8.4145, Pc=-8.4145, Pd=-0.0
# Ctrl: 1=1400;
# EVA: ts=5.15[H], 5000 EVs, Total Q=54.08 MWh
# Online 2155, Q=53.81 MWh, SoC=0.9487
# Power(MW): Pt=-1.2251, Pc=-1.2251, Pd=-0.0
# Ctrl: 0=1946; 1=209;
# EVA: ts=1.6667[H], 5000 EVs, Total Q=54.68 MWh
# Online 1743, Q=43.58 MWh, SoC=0.5148
# Power(MW): Pt=-10.4058, Pc=-10.4058, Pd=-0.0
# Ctrl: 1=1733; 0=10;
# EVA: ts=2.65[H], 5000 EVs, Total Q=58.48 MWh
# Online 2145, Q=53.56 MWh, SoC=0.667
# Power(MW): Pt=-9.368, Pc=-9.368, Pd=-0.0
# Ctrl: 1=1585; 0=560;
# EVA: ts=0.65[H], 5000 EVs, Total Q=43.87 MWh
# Online 902, Q=22.45 MWh, SoC=0.376
# Power(MW): Pt=-5.4226, Pc=-5.4226, Pd=-0.0
# Ctrl: 1=902;
# EVA: ts=3.1667[H], 5000 EVs, Total Q=58.5 MWh
# Online 2225, Q=55.57 MWh, SoC=0.7515
# Power(MW): Pt=-6.8835, Pc=-6.8835, Pd=-0.0
# Ctrl: 1=1173; 0=1052;
# EVA: ts=4.15[H], 5000 EVs, Total Q=57.47 MWh
# Online 2255, Q=56.29 MWh, SoC=0.8793
# Power(MW): Pt=-3.3, Pc=-3.3, Pd=-0.0
# Ctrl: 0=1689; 1=566;
# EVA: ts=5.6667[H], 5000 EVs, Total Q=51.65 MWh
# Online 2068, Q=51.6 MWh, SoC=0.9685
# Power(MW): Pt=-0.7714, Pc=-0.7714, Pd=-0.0
# Ctrl: 0=1936; 1=132;
# EVA: ts=3.6667[H], 5000 EVs, Total Q=58.33 MWh
# Online 2266, Q=56.61 MWh, SoC=0.822
# Power(MW): Pt=-4.8351, Pc=-4.8351, Pd=-0.0
# Ctrl: 0=1438; 1=828;
# EVA: ts=4.65[H], 5000 EVs, Total Q=56.25 MWh
# Online 2229, Q=55.66 MWh, SoC=0.9195
# Power(MW): Pt=-2.2357, Pc=-2.2357, Pd=-0.0
# Ctrl: 0=1846; 1=383;
# EVA: ts=0.1833[H], 5000 EVs, Total Q=35.61 MWh
# Online 289, Q=7.18 MWh, SoC=0.3212
# Power(MW): Pt=-1.7524, Pc=-1.7524, Pd=-0.0
# Ctrl: 1=289;
# EVA: ts=2.1667[H], 5000 EVs, Total Q=57.0 MWh
# Online 1979, Q=49.45 MWh, SoC=0.5905
# Power(MW): Pt=-10.7877, Pc=-10.7877, Pd=-0.0
# Ctrl: 1=1810; 0=169;
# EVA: ts=1.6833[H], 5000 EVs, Total Q=54.8 MWh
# Online 1754, Q=43.85 MWh, SoC=0.5172
# Power(MW): Pt=-10.4508, Pc=-10.4508, Pd=-0.0
# Ctrl: 1=1741; 0=13;
# EVA: ts=1.1833[H], 5000 EVs, Total Q=50.51 MWh
# Online 1409, Q=35.3 MWh, SoC=0.4468
# Power(MW): Pt=-8.4688, Pc=-8.4688, Pd=-0.0
# Ctrl: 1=1409;
# EVA: ts=5.1667[H], 5000 EVs, Total Q=54.01 MWh
# Online 2152, Q=53.74 MWh, SoC=0.9496
# Power(MW): Pt=-1.2134, Pc=-1.2134, Pd=-0.0
# Ctrl: 0=1945; 1=207;
# EVA: ts=0.6667[H], 5000 EVs, Total Q=44.12 MWh
# Online 919, Q=22.87 MWh, SoC=0.3784
# Power(MW): Pt=-5.5284, Pc=-5.5284, Pd=-0.0
# Ctrl: 1=919;
# EVA: ts=2.6667[H], 5000 EVs, Total Q=58.48 MWh
# Online 2149, Q=53.66 MWh, SoC=0.6697
# Power(MW): Pt=-9.3132, Pc=-9.3132, Pd=-0.0
# Ctrl: 1=1576; 0=573;
# EVA: ts=3.1833[H], 5000 EVs, Total Q=58.55 MWh
# Online 2233, Q=55.78 MWh, SoC=0.7531
# Power(MW): Pt=-6.8641, Pc=-6.8641, Pd=-0.0
# Ctrl: 1=1170; 0=1063;
# EVA: ts=4.1667[H], 5000 EVs, Total Q=57.45 MWh
# Online 2257, Q=56.34 MWh, SoC=0.8803
# Power(MW): Pt=-3.2722, Pc=-3.2722, Pd=-0.0
# Ctrl: 0=1696; 1=561;
# EVA: ts=5.6833[H], 5000 EVs, Total Q=51.55 MWh
# Online 2064, Q=51.5 MWh, SoC=0.969
# Power(MW): Pt=-0.7269, Pc=-0.7269, Pd=-0.0
# Ctrl: 0=1940; 1=124;
# EVA: ts=3.6833[H], 5000 EVs, Total Q=58.28 MWh
# Online 2267, Q=56.64 MWh, SoC=0.8238
# Power(MW): Pt=-4.8006, Pc=-4.8006, Pd=-0.0
# Ctrl: 0=1445; 1=822;
# EVA: ts=0.2[H], 5000 EVs, Total Q=35.88 MWh
# Online 311, Q=7.73 MWh, SoC=0.3222
# Power(MW): Pt=-1.8858, Pc=-1.8858, Pd=-0.0
# Ctrl: 1=311;
# EVA: ts=4.6667[H], 5000 EVs, Total Q=56.17 MWh
# Online 2227, Q=55.61 MWh, SoC=0.9204
# Power(MW): Pt=-2.207, Pc=-2.207, Pd=-0.0
# Ctrl: 0=1849; 1=378;
# EVA: ts=2.1833[H], 5000 EVs, Total Q=57.17 MWh
# Online 1986, Q=49.63 MWh, SoC=0.593
# Power(MW): Pt=-10.7527, Pc=-10.7527, Pd=-0.0
# Ctrl: 1=1805; 0=181;
# EVA: ts=5.1833[H], 5000 EVs, Total Q=53.91 MWh
# Online 2151, Q=53.71 MWh, SoC=0.9495
# Power(MW): Pt=-1.2165, Pc=-1.2165, Pd=-0.0
# Ctrl: 0=1944; 1=207;
# EVA: ts=1.2[H], 5000 EVs, Total Q=50.72 MWh
# Online 1420, Q=35.57 MWh, SoC=0.4494
# Power(MW): Pt=-8.5365, Pc=-8.5365, Pd=-0.0
# Ctrl: 1=1420;
# EVA: ts=0.6833[H], 5000 EVs, Total Q=44.39 MWh
# Online 938, Q=23.37 MWh, SoC=0.3803
# Power(MW): Pt=-5.6414, Pc=-5.6414, Pd=-0.0
# Ctrl: 1=938;
# EVA: ts=2.6833[H], 5000 EVs, Total Q=58.54 MWh
# Online 2153, Q=53.76 MWh, SoC=0.6726
# Power(MW): Pt=-9.2533, Pc=-9.2533, Pd=-0.0
# Ctrl: 1=1566; 0=587;
# EVA: ts=1.7[H], 5000 EVs, Total Q=54.9 MWh
# Online 1759, Q=43.98 MWh, SoC=0.5202
# Power(MW): Pt=-10.4627, Pc=-10.4627, Pd=-0.0
# Ctrl: 1=1743; 0=16;
# EVA: ts=3.2[H], 5000 EVs, Total Q=58.62 MWh
# Online 2236, Q=55.85 MWh, SoC=0.7556
# Power(MW): Pt=-6.8034, Pc=-6.8034, Pd=-0.0
# Ctrl: 1=1159; 0=1077;
# EVA: ts=0.2167[H], 5000 EVs, Total Q=36.29 MWh
# Online 338, Q=8.39 MWh, SoC=0.3255
# Power(MW): Pt=-2.047, Pc=-2.047, Pd=-0.0
# Ctrl: 1=338;
# EVA: ts=4.1833[H], 5000 EVs, Total Q=57.45 MWh
# Online 2256, Q=56.33 MWh, SoC=0.8817
# Power(MW): Pt=-3.2324, Pc=-3.2324, Pd=-0.0
# Ctrl: 0=1702; 1=554;
# EVA: ts=5.7[H], 5000 EVs, Total Q=51.42 MWh
# Online 2059, Q=51.37 MWh, SoC=0.9698
# Power(MW): Pt=-0.7161, Pc=-0.7161, Pd=-0.0
# Ctrl: 0=1937; 1=122;
# EVA: ts=2.2[H], 5000 EVs, Total Q=57.25 MWh
# Online 1995, Q=49.84 MWh, SoC=0.5953
# Power(MW): Pt=-10.7485, Pc=-10.7485, Pd=-0.0
# Ctrl: 1=1805; 0=190;
# EVA: ts=4.6833[H], 5000 EVs, Total Q=56.09 MWh
# Online 2224, Q=55.53 MWh, SoC=0.9218
# Power(MW): Pt=-2.1604, Pc=-2.1604, Pd=-0.0
# Ctrl: 0=1854; 1=370;
# EVA: ts=0.7[H], 5000 EVs, Total Q=44.52 MWh
# Online 955, Q=23.82 MWh, SoC=0.3826
# Power(MW): Pt=-5.7397, Pc=-5.7397, Pd=-0.0
# Ctrl: 1=955;
# EVA: ts=5.2[H], 5000 EVs, Total Q=53.76 MWh
# Online 2146, Q=53.59 MWh, SoC=0.95
# Power(MW): Pt=-1.1885, Pc=-1.1885, Pd=-0.0
# Ctrl: 0=1944; 1=202;
# EVA: ts=3.7[H], 5000 EVs, Total Q=58.25 MWh
# Online 2268, Q=56.66 MWh, SoC=0.826
# Power(MW): Pt=-4.6942, Pc=-4.6942, Pd=-0.0
# Ctrl: 0=1464; 1=804;
# EVA: ts=1.2167[H], 5000 EVs, Total Q=50.99 MWh
# Online 1437, Q=36.01 MWh, SoC=0.451
# Power(MW): Pt=-8.6344, Pc=-8.6344, Pd=-0.0
# Ctrl: 1=1437;
# EVA: ts=2.7[H], 5000 EVs, Total Q=58.53 MWh
# Online 2155, Q=53.81 MWh, SoC=0.6755
# Power(MW): Pt=-9.2179, Pc=-9.2179, Pd=-0.0
# Ctrl: 1=1560; 0=595;
# EVA: ts=3.2167[H], 5000 EVs, Total Q=58.62 MWh
# Online 2242, Q=55.99 MWh, SoC=0.7576
# Power(MW): Pt=-6.7225, Pc=-6.7225, Pd=-0.0
# Ctrl: 1=1145; 0=1097;
# EVA: ts=0.2333[H], 5000 EVs, Total Q=36.64 MWh
# Online 367, Q=9.08 MWh, SoC=0.3266
# Power(MW): Pt=-2.222, Pc=-2.222, Pd=-0.0
# Ctrl: 1=367;
# EVA: ts=1.7167[H], 5000 EVs, Total Q=54.98 MWh
# Online 1769, Q=44.24 MWh, SoC=0.5226
# Power(MW): Pt=-10.5085, Pc=-10.5085, Pd=-0.0
# Ctrl: 1=1751; 0=18;
# EVA: ts=5.7167[H], 5000 EVs, Total Q=51.39 MWh
# Online 2058, Q=51.34 MWh, SoC=0.9703
# Power(MW): Pt=-0.6796, Pc=-0.6796, Pd=-0.0
# Ctrl: 0=1942; 1=116;
# EVA: ts=0.7167[H], 5000 EVs, Total Q=44.78 MWh
# Online 973, Q=24.25 MWh, SoC=0.3849
# Power(MW): Pt=-5.8495, Pc=-5.8495, Pd=-0.0
# Ctrl: 1=973;
# EVA: ts=4.7[H], 5000 EVs, Total Q=56.07 MWh
# Online 2223, Q=55.51 MWh, SoC=0.9231
# Power(MW): Pt=-2.1155, Pc=-2.1155, Pd=-0.0
# Ctrl: 0=1861; 1=362;
# EVA: ts=5.2167[H], 5000 EVs, Total Q=53.71 MWh
# Online 2144, Q=53.54 MWh, SoC=0.9508
# Power(MW): Pt=-1.1572, Pc=-1.1572, Pd=-0.0
# Ctrl: 0=1947; 1=197;
# EVA: ts=4.2[H], 5000 EVs, Total Q=57.42 MWh
# Online 2257, Q=56.35 MWh, SoC=0.8828
# Power(MW): Pt=-3.1287, Pc=-3.1287, Pd=-0.0
# Ctrl: 0=1721; 1=536;
# EVA: ts=1.2333[H], 5000 EVs, Total Q=51.19 MWh
# Online 1451, Q=36.36 MWh, SoC=0.4531
# Power(MW): Pt=-8.72, Pc=-8.72, Pd=-0.0
# Ctrl: 1=1451;
# EVA: ts=2.2167[H], 5000 EVs, Total Q=57.36 MWh
# Online 2005, Q=50.08 MWh, SoC=0.5973
# Power(MW): Pt=-10.736, Pc=-10.736, Pd=-0.0
# Ctrl: 1=1803; 0=202;
# EVA: ts=3.2333[H], 5000 EVs, Total Q=58.62 MWh
# Online 2247, Q=56.13 MWh, SoC=0.7594
# Power(MW): Pt=-6.6759, Pc=-6.6759, Pd=-0.0
# Ctrl: 1=1137; 0=1110;
# EVA: ts=3.7167[H], 5000 EVs, Total Q=58.25 MWh
# Online 2269, Q=56.68 MWh, SoC=0.8281
# Power(MW): Pt=-4.6275, Pc=-4.6275, Pd=-0.0
# Ctrl: 0=1476; 1=793;
# EVA: ts=0.25[H], 5000 EVs, Total Q=37.06 MWh
# Online 397, Q=9.81 MWh, SoC=0.3283
# Power(MW): Pt=-2.3983, Pc=-2.3983, Pd=-0.0
# Ctrl: 1=397;
# EVA: ts=5.7333[H], 5000 EVs, Total Q=51.37 MWh
# Online 2057, Q=51.32 MWh, SoC=0.9708
# Power(MW): Pt=-0.6564, Pc=-0.6564, Pd=-0.0
# Ctrl: 0=1945; 1=112;
# EVA: ts=0.7333[H], 5000 EVs, Total Q=45.1 MWh
# Online 987, Q=24.62 MWh, SoC=0.3875
# Power(MW): Pt=-5.9316, Pc=-5.9316, Pd=-0.0
# Ctrl: 1=987;
# EVA: ts=2.7167[H], 5000 EVs, Total Q=58.54 MWh
# Online 2156, Q=53.83 MWh, SoC=0.6785
# Power(MW): Pt=-9.1392, Pc=-9.1392, Pd=-0.0
# Ctrl: 1=1547; 0=609;
# EVA: ts=5.2333[H], 5000 EVs, Total Q=53.69 MWh
# Online 2144, Q=53.53 MWh, SoC=0.9514
# Power(MW): Pt=-1.1575, Pc=-1.1575, Pd=-0.0
# Ctrl: 0=1947; 1=197;
# EVA: ts=4.7167[H], 5000 EVs, Total Q=55.94 MWh
# Online 2219, Q=55.41 MWh, SoC=0.9239
# Power(MW): Pt=-2.0539, Pc=-2.0539, Pd=-0.0
# Ctrl: 0=1868; 1=351;
# EVA: ts=2.2333[H], 5000 EVs, Total Q=57.5 MWh
# Online 2012, Q=50.26 MWh, SoC=0.5997
# Power(MW): Pt=-10.745, Pc=-10.745, Pd=-0.0
# Ctrl: 1=1804; 0=208;
# EVA: ts=1.25[H], 5000 EVs, Total Q=51.4 MWh
# Online 1467, Q=36.75 MWh, SoC=0.4549
# Power(MW): Pt=-8.8184, Pc=-8.8184, Pd=-0.0
# Ctrl: 1=1467;
# EVA: ts=1.7333[H], 5000 EVs, Total Q=55.07 MWh
# Online 1782, Q=44.56 MWh, SoC=0.5247
# Power(MW): Pt=-10.5731, Pc=-10.5731, Pd=-0.0
# Ctrl: 1=1762; 0=20;
# EVA: ts=4.2167[H], 5000 EVs, Total Q=57.31 MWh
# Online 2253, Q=56.24 MWh, SoC=0.8845
# Power(MW): Pt=-3.0851, Pc=-3.0851, Pd=-0.0
# Ctrl: 0=1724; 1=529;
# EVA: ts=3.25[H], 5000 EVs, Total Q=58.57 MWh
# Online 2247, Q=56.13 MWh, SoC=0.7616
# Power(MW): Pt=-6.5777, Pc=-6.5777, Pd=-0.0
# Ctrl: 0=1126; 1=1121;
# EVA: ts=3.7333[H], 5000 EVs, Total Q=58.2 MWh
# Online 2271, Q=56.73 MWh, SoC=0.8297
# Power(MW): Pt=-4.5789, Pc=-4.5789, Pd=-0.0
# Ctrl: 0=1486; 1=785;
# EVA: ts=2.7333[H], 5000 EVs, Total Q=58.61 MWh
# Online 2159, Q=53.91 MWh, SoC=0.6815
# Power(MW): Pt=-9.0498, Pc=-9.0498, Pd=-0.0
# Ctrl: 1=1532; 0=627;
# EVA: ts=5.25[H], 5000 EVs, Total Q=53.58 MWh
# Online 2142, Q=53.48 MWh, SoC=0.9516
# Power(MW): Pt=-1.1512, Pc=-1.1512, Pd=-0.0
# Ctrl: 0=1946; 1=196;
# EVA: ts=0.2667[H], 5000 EVs, Total Q=37.52 MWh
# Online 419, Q=10.33 MWh, SoC=0.3297
# Power(MW): Pt=-2.5317, Pc=-2.5317, Pd=-0.0
# Ctrl: 1=419;
# EVA: ts=2.25[H], 5000 EVs, Total Q=57.61 MWh
# Online 2021, Q=50.49 MWh, SoC=0.602
# Power(MW): Pt=-10.7424, Pc=-10.7424, Pd=-0.0
# Ctrl: 1=1804; 0=217;
# EVA: ts=0.75[H], 5000 EVs, Total Q=45.35 MWh
# Online 1009, Q=25.18 MWh, SoC=0.389
# Power(MW): Pt=-6.0618, Pc=-6.0618, Pd=-0.0
# Ctrl: 1=1009;
# EVA: ts=5.75[H], 5000 EVs, Total Q=51.32 MWh
# Online 2055, Q=51.27 MWh, SoC=0.9714
# Power(MW): Pt=-0.6445, Pc=-0.6445, Pd=-0.0
# Ctrl: 0=1945; 1=110;
# EVA: ts=1.75[H], 5000 EVs, Total Q=55.2 MWh
# Online 1792, Q=44.81 MWh, SoC=0.5271
# Power(MW): Pt=-10.6027, Pc=-10.6027, Pd=-0.0
# Ctrl: 1=1767; 0=25;
# EVA: ts=1.2667[H], 5000 EVs, Total Q=51.52 MWh
# Online 1485, Q=37.19 MWh, SoC=0.4568
# Power(MW): Pt=-8.9299, Pc=-8.9299, Pd=-0.0
# Ctrl: 1=1485;
# EVA: ts=4.7333[H], 5000 EVs, Total Q=55.9 MWh
# Online 2217, Q=55.36 MWh, SoC=0.9252
# Power(MW): Pt=-2.0034, Pc=-2.0034, Pd=-0.0
# Ctrl: 0=1875; 1=342;
# EVA: ts=3.2667[H], 5000 EVs, Total Q=58.54 MWh
# Online 2246, Q=56.11 MWh, SoC=0.7645
# Power(MW): Pt=-6.4685, Pc=-6.4685, Pd=-0.0
# Ctrl: 0=1143; 1=1103;
# EVA: ts=4.2333[H], 5000 EVs, Total Q=57.31 MWh
# Online 2253, Q=56.24 MWh, SoC=0.8861
# Power(MW): Pt=-3.0633, Pc=-3.0633, Pd=-0.0
# Ctrl: 0=1728; 1=525;
# EVA: ts=3.75[H], 5000 EVs, Total Q=58.13 MWh
# Online 2268, Q=56.65 MWh, SoC=0.8322
# Power(MW): Pt=-4.5398, Pc=-4.5398, Pd=-0.0
# Ctrl: 0=1490; 1=778;
# EVA: ts=2.75[H], 5000 EVs, Total Q=58.61 MWh
# Online 2165, Q=54.06 MWh, SoC=0.684
# Power(MW): Pt=-8.9571, Pc=-8.9571, Pd=-0.0
# Ctrl: 1=1517; 0=648;
# EVA: ts=5.7667[H], 5000 EVs, Total Q=51.3 MWh
# Online 2054, Q=51.25 MWh, SoC=0.9719
# Power(MW): Pt=-0.6263, Pc=-0.6263, Pd=-0.0
# Ctrl: 0=1947; 1=107;
# EVA: ts=1.7667[H], 5000 EVs, Total Q=55.3 MWh
# Online 1797, Q=44.93 MWh, SoC=0.5302
# Power(MW): Pt=-10.6083, Pc=-10.6083, Pd=-0.0
# Ctrl: 1=1768; 0=29;
# EVA: ts=2.2667[H], 5000 EVs, Total Q=57.64 MWh
# Online 2027, Q=50.64 MWh, SoC=0.6048
# Power(MW): Pt=-10.7335, Pc=-10.7335, Pd=-0.0
# Ctrl: 1=1803; 0=224;
# EVA: ts=4.75[H], 5000 EVs, Total Q=55.87 MWh
# Online 2216, Q=55.33 MWh, SoC=0.9264
# Power(MW): Pt=-1.9741, Pc=-1.9741, Pd=-0.0
# Ctrl: 0=1879; 1=337;
# EVA: ts=0.7667[H], 5000 EVs, Total Q=45.46 MWh
# Online 1028, Q=25.66 MWh, SoC=0.3908
# Power(MW): Pt=-6.1822, Pc=-6.1822, Pd=-0.0
# Ctrl: 1=1028;
# EVA: ts=1.2833[H], 5000 EVs, Total Q=51.7 MWh
# Online 1494, Q=37.41 MWh, SoC=0.4595
# Power(MW): Pt=-8.982, Pc=-8.982, Pd=-0.0
# Ctrl: 1=1494;
# EVA: ts=0.2833[H], 5000 EVs, Total Q=37.74 MWh
# Online 444, Q=10.96 MWh, SoC=0.3314
# Power(MW): Pt=-2.6806, Pc=-2.6806, Pd=-0.0
# Ctrl: 1=444;
# EVA: ts=5.2667[H], 5000 EVs, Total Q=53.5 MWh
# Online 2139, Q=53.4 MWh, SoC=0.9524
# Power(MW): Pt=-1.1455, Pc=-1.1455, Pd=-0.0
# Ctrl: 0=1944; 1=195;
# EVA: ts=3.2833[H], 5000 EVs, Total Q=58.52 MWh
# Online 2247, Q=56.13 MWh, SoC=0.7671
# Power(MW): Pt=-6.3777, Pc=-6.3777, Pd=-0.0
# Ctrl: 0=1160; 1=1087;
# EVA: ts=3.7667[H], 5000 EVs, Total Q=58.07 MWh
# Online 2268, Q=56.65 MWh, SoC=0.8342
# Power(MW): Pt=-4.4946, Pc=-4.4946, Pd=-0.0
# Ctrl: 0=1498; 1=770;
# EVA: ts=2.7667[H], 5000 EVs, Total Q=58.54 MWh
# Online 2164, Q=54.04 MWh, SoC=0.6868
# Power(MW): Pt=-8.8426, Pc=-8.8426, Pd=-0.0
# Ctrl: 1=1497; 0=667;
# EVA: ts=4.25[H], 5000 EVs, Total Q=57.35 MWh
# Online 2255, Q=56.28 MWh, SoC=0.8874
# Power(MW): Pt=-2.9946, Pc=-2.9946, Pd=-0.0
# Ctrl: 0=1742; 1=513;
# EVA: ts=1.7833[H], 5000 EVs, Total Q=55.36 MWh
# Online 1802, Q=45.05 MWh, SoC=0.5332
# Power(MW): Pt=-10.6124, Pc=-10.6124, Pd=-0.0
# Ctrl: 1=1769; 0=33;
# EVA: ts=5.7833[H], 5000 EVs, Total Q=51.21 MWh
# Online 2050, Q=51.16 MWh, SoC=0.9723
# Power(MW): Pt=-0.6149, Pc=-0.6149, Pd=-0.0
# Ctrl: 0=1945; 1=105;
# EVA: ts=2.2833[H], 5000 EVs, Total Q=57.66 MWh
# Online 2033, Q=50.79 MWh, SoC=0.6074
# Power(MW): Pt=-10.6964, Pc=-10.6964, Pd=-0.0
# Ctrl: 1=1797; 0=236;
# EVA: ts=0.3[H], 5000 EVs, Total Q=38.05 MWh
# Online 471, Q=11.64 MWh, SoC=0.3335
# Power(MW): Pt=-2.8405, Pc=-2.8405, Pd=-0.0
# Ctrl: 1=471;
# EVA: ts=1.3[H], 5000 EVs, Total Q=51.89 MWh
# Online 1506, Q=37.7 MWh, SoC=0.4621
# Power(MW): Pt=-9.051, Pc=-9.051, Pd=-0.0
# Ctrl: 1=1506;
# EVA: ts=4.7667[H], 5000 EVs, Total Q=55.85 MWh
# Online 2215, Q=55.31 MWh, SoC=0.9276
# Power(MW): Pt=-1.9357, Pc=-1.9357, Pd=-0.0
# Ctrl: 0=1884; 1=331;
# EVA: ts=0.7833[H], 5000 EVs, Total Q=45.56 MWh
# Online 1040, Q=25.97 MWh, SoC=0.3932
# Power(MW): Pt=-6.2553, Pc=-6.2553, Pd=-0.0
# Ctrl: 1=1040;
# EVA: ts=3.3[H], 5000 EVs, Total Q=58.54 MWh
# Online 2249, Q=56.18 MWh, SoC=0.7696
# Power(MW): Pt=-6.3182, Pc=-6.3182, Pd=-0.0
# Ctrl: 0=1172; 1=1077;
# EVA: ts=5.2833[H], 5000 EVs, Total Q=53.41 MWh
# Online 2135, Q=53.3 MWh, SoC=0.9534
# Power(MW): Pt=-1.1195, Pc=-1.1195, Pd=-0.0
# Ctrl: 0=1944; 1=191;
# EVA: ts=3.7833[H], 5000 EVs, Total Q=58.07 MWh
# Online 2268, Q=56.65 MWh, SoC=0.8366
# Power(MW): Pt=-4.4347, Pc=-4.4347, Pd=-0.0
# Ctrl: 0=1508; 1=760;
# EVA: ts=2.7833[H], 5000 EVs, Total Q=58.51 MWh
# Online 2165, Q=54.07 MWh, SoC=0.69
# Power(MW): Pt=-8.7402, Pc=-8.7402, Pd=-0.0
# Ctrl: 1=1480; 0=685;
# EVA: ts=0.3167[H], 5000 EVs, Total Q=38.4 MWh
# Online 488, Q=12.06 MWh, SoC=0.3359
# Power(MW): Pt=-2.9473, Pc=-2.9473, Pd=-0.0
# Ctrl: 1=488;
# EVA: ts=1.8[H], 5000 EVs, Total Q=55.58 MWh
# Online 1810, Q=45.24 MWh, SoC=0.5359
# Power(MW): Pt=-10.654, Pc=-10.654, Pd=-0.0
# Ctrl: 1=1776; 0=34;
# EVA: ts=2.3[H], 5000 EVs, Total Q=57.71 MWh
# Online 2040, Q=50.98 MWh, SoC=0.6099
# Power(MW): Pt=-10.6292, Pc=-10.6292, Pd=-0.0
# Ctrl: 1=1787; 0=253;
# EVA: ts=5.8[H], 5000 EVs, Total Q=51.12 MWh
# Online 2046, Q=51.07 MWh, SoC=0.9728
# Power(MW): Pt=-0.6025, Pc=-0.6025, Pd=-0.0
# Ctrl: 0=1943; 1=103;
# EVA: ts=4.2667[H], 5000 EVs, Total Q=57.28 MWh
# Online 2253, Q=56.23 MWh, SoC=0.8891
# Power(MW): Pt=-2.9536, Pc=-2.9536, Pd=-0.0
# Ctrl: 0=1747; 1=506;
# EVA: ts=1.3167[H], 5000 EVs, Total Q=52.02 MWh
# Online 1519, Q=38.02 MWh, SoC=0.4643
# Power(MW): Pt=-9.1256, Pc=-9.1256, Pd=-0.0
# Ctrl: 1=1519;
# EVA: ts=0.8[H], 5000 EVs, Total Q=45.76 MWh
# Online 1058, Q=26.43 MWh, SoC=0.3956
# Power(MW): Pt=-6.3637, Pc=-6.3637, Pd=-0.0
# Ctrl: 1=1058;
# EVA: ts=4.7833[H], 5000 EVs, Total Q=55.61 MWh
# Online 2205, Q=55.07 MWh, SoC=0.929
# Power(MW): Pt=-1.8761, Pc=-1.8761, Pd=-0.0
# Ctrl: 0=1884; 1=321;
# EVA: ts=3.8[H], 5000 EVs, Total Q=58.05 MWh
# Online 2267, Q=56.63 MWh, SoC=0.8391
# Power(MW): Pt=-4.3756, Pc=-4.3756, Pd=-0.0
# Ctrl: 0=1517; 1=750;
# EVA: ts=3.3167[H], 5000 EVs, Total Q=58.57 MWh
# Online 2250, Q=56.2 MWh, SoC=0.7721
# Power(MW): Pt=-6.2895, Pc=-6.2895, Pd=-0.0
# Ctrl: 0=1178; 1=1072;
# EVA: ts=5.3[H], 5000 EVs, Total Q=53.33 MWh
# Online 2132, Q=53.23 MWh, SoC=0.9542
# Power(MW): Pt=-1.09, Pc=-1.09, Pd=-0.0
# Ctrl: 0=1946; 1=186;
# EVA: ts=0.3333[H], 5000 EVs, Total Q=38.56 MWh
# Online 507, Q=12.53 MWh, SoC=0.3388
# Power(MW): Pt=-3.0664, Pc=-3.0664, Pd=-0.0
# Ctrl: 1=507;
# EVA: ts=2.8[H], 5000 EVs, Total Q=58.51 MWh
# Online 2174, Q=54.29 MWh, SoC=0.6918
# Power(MW): Pt=-8.7142, Pc=-8.7142, Pd=-0.0
# Ctrl: 1=1476; 0=698;
# EVA: ts=1.8167[H], 5000 EVs, Total Q=55.66 MWh
# Online 1818, Q=45.44 MWh, SoC=0.5386
# Power(MW): Pt=-10.6618, Pc=-10.6618, Pd=-0.0
# Ctrl: 1=1778; 0=40;
# EVA: ts=5.8167[H], 5000 EVs, Total Q=50.99 MWh
# Online 2041, Q=50.94 MWh, SoC=0.9736
# Power(MW): Pt=-0.59, Pc=-0.59, Pd=-0.0
# Ctrl: 0=1940; 1=101;
# EVA: ts=2.3167[H], 5000 EVs, Total Q=57.71 MWh
# Online 2045, Q=51.09 MWh, SoC=0.6125
# Power(MW): Pt=-10.5666, Pc=-10.5666, Pd=-0.0
# Ctrl: 1=1777; 0=268;
# EVA: ts=4.2833[H], 5000 EVs, Total Q=57.23 MWh
# Online 2251, Q=56.18 MWh, SoC=0.8907
# Power(MW): Pt=-2.9114, Pc=-2.9114, Pd=-0.0
# Ctrl: 0=1752; 1=499;
# EVA: ts=1.3333[H], 5000 EVs, Total Q=52.15 MWh
# Online 1526, Q=38.2 MWh, SoC=0.4672
# Power(MW): Pt=-9.1695, Pc=-9.1695, Pd=-0.0
# Ctrl: 1=1526;
# EVA: ts=0.8167[H], 5000 EVs, Total Q=45.95 MWh
# Online 1078, Q=26.94 MWh, SoC=0.3974
# Power(MW): Pt=-6.4856, Pc=-6.4856, Pd=-0.0
# Ctrl: 1=1078;
# EVA: ts=4.8[H], 5000 EVs, Total Q=55.53 MWh
# Online 2202, Q=54.99 MWh, SoC=0.9306
# Power(MW): Pt=-1.8111, Pc=-1.8111, Pd=-0.0
# Ctrl: 0=1892; 1=310;
# EVA: ts=3.8167[H], 5000 EVs, Total Q=58.08 MWh
# Online 2267, Q=56.63 MWh, SoC=0.8409
# Power(MW): Pt=-4.3461, Pc=-4.3461, Pd=-0.0
# Ctrl: 0=1522; 1=745;
# EVA: ts=0.35[H], 5000 EVs, Total Q=38.79 MWh
# Online 523, Q=12.92 MWh, SoC=0.342
# Power(MW): Pt=-3.1602, Pc=-3.1602, Pd=-0.0
# Ctrl: 1=523;
# EVA: ts=2.8167[H], 5000 EVs, Total Q=58.52 MWh
# Online 2175, Q=54.32 MWh, SoC=0.6947
# Power(MW): Pt=-8.6107, Pc=-8.6107, Pd=-0.0
# Ctrl: 1=1460; 0=715;
# EVA: ts=5.3167[H], 5000 EVs, Total Q=53.24 MWh
# Online 2129, Q=53.16 MWh, SoC=0.9546
# Power(MW): Pt=-1.0901, Pc=-1.0901, Pd=-0.0
# Ctrl: 0=1943; 1=186;
# EVA: ts=1.8333[H], 5000 EVs, Total Q=55.71 MWh
# Online 1829, Q=45.71 MWh, SoC=0.5408
# Power(MW): Pt=-10.7064, Pc=-10.7064, Pd=-0.0
# Ctrl: 1=1786; 0=43;
# EVA: ts=3.3333[H], 5000 EVs, Total Q=58.55 MWh
# Online 2250, Q=56.2 MWh, SoC=0.7749
# Power(MW): Pt=-6.1815, Pc=-6.1815, Pd=-0.0
# Ctrl: 0=1196; 1=1054;
# EVA: ts=5.8333[H], 5000 EVs, Total Q=50.95 MWh
# Online 2039, Q=50.9 MWh, SoC=0.9741
# Power(MW): Pt=-0.585, Pc=-0.585, Pd=-0.0
# Ctrl: 0=1939; 1=100;
# EVA: ts=2.3333[H], 5000 EVs, Total Q=57.76 MWh
# Online 2050, Q=51.22 MWh, SoC=0.6154
# Power(MW): Pt=-10.5469, Pc=-10.5469, Pd=-0.0
# Ctrl: 1=1774; 0=276;
# EVA: ts=1.35[H], 5000 EVs, Total Q=52.3 MWh
# Online 1535, Q=38.43 MWh, SoC=0.4699
# Power(MW): Pt=-9.2222, Pc=-9.2222, Pd=-0.0
# Ctrl: 1=1535;
# EVA: ts=4.3[H], 5000 EVs, Total Q=57.16 MWh
# Online 2250, Q=56.16 MWh, SoC=0.8922
# Power(MW): Pt=-2.8942, Pc=-2.8942, Pd=-0.0
# Ctrl: 0=1754; 1=496;
# EVA: ts=0.8333[H], 5000 EVs, Total Q=46.22 MWh
# Online 1103, Q=27.59 MWh, SoC=0.3992
# Power(MW): Pt=-6.6359, Pc=-6.6359, Pd=-0.0
# Ctrl: 1=1103;
# EVA: ts=3.8333[H], 5000 EVs, Total Q=58.05 MWh
# Online 2267, Q=56.63 MWh, SoC=0.8432
# Power(MW): Pt=-4.2892, Pc=-4.2892, Pd=-0.0
# Ctrl: 0=1532; 1=735;
# EVA: ts=4.8167[H], 5000 EVs, Total Q=55.35 MWh
# Online 2198, Q=54.89 MWh, SoC=0.9309
# Power(MW): Pt=-1.7828, Pc=-1.7828, Pd=-0.0
# Ctrl: 0=1893; 1=305;
# EVA: ts=5.3333[H], 5000 EVs, Total Q=53.19 MWh
# Online 2127, Q=53.11 MWh, SoC=0.9554
# Power(MW): Pt=-1.0849, Pc=-1.0849, Pd=-0.0
# Ctrl: 0=1942; 1=185;
# EVA: ts=1.85[H], 5000 EVs, Total Q=55.73 MWh
# Online 1837, Q=45.91 MWh, SoC=0.5431
# Power(MW): Pt=-10.7118, Pc=-10.7118, Pd=-0.0
# Ctrl: 1=1788; 0=49;
# EVA: ts=2.8333[H], 5000 EVs, Total Q=58.51 MWh
# Online 2176, Q=54.34 MWh, SoC=0.6978
# Power(MW): Pt=-8.5719, Pc=-8.5719, Pd=-0.0
# Ctrl: 1=1453; 0=723;
# EVA: ts=0.3667[H], 5000 EVs, Total Q=39.09 MWh
# Online 545, Q=13.48 MWh, SoC=0.3439
# Power(MW): Pt=-3.2873, Pc=-3.2873, Pd=-0.0
# Ctrl: 1=545;
# EVA: ts=5.85[H], 5000 EVs, Total Q=50.88 MWh
# Online 2036, Q=50.83 MWh, SoC=0.9745
# Power(MW): Pt=-0.5683, Pc=-0.5683, Pd=-0.0
# Ctrl: 0=1939; 1=97;
# EVA: ts=1.3667[H], 5000 EVs, Total Q=52.42 MWh
# Online 1547, Q=38.73 MWh, SoC=0.4722
# Power(MW): Pt=-9.2944, Pc=-9.2944, Pd=-0.0
# Ctrl: 1=1547;
# EVA: ts=0.85[H], 5000 EVs, Total Q=46.45 MWh
# Online 1120, Q=28.04 MWh, SoC=0.4012
# Power(MW): Pt=-6.7337, Pc=-6.7337, Pd=-0.0
# Ctrl: 1=1120;
# EVA: ts=2.35[H], 5000 EVs, Total Q=57.77 MWh
# Online 2055, Q=51.35 MWh, SoC=0.6181
# Power(MW): Pt=-10.5204, Pc=-10.5204, Pd=-0.0
# Ctrl: 1=1770; 0=285;
# EVA: ts=3.35[H], 5000 EVs, Total Q=58.55 MWh
# Online 2251, Q=56.23 MWh, SoC=0.7777
# Power(MW): Pt=-6.1005, Pc=-6.1005, Pd=-0.0
# Ctrl: 0=1210; 1=1041;
# EVA: ts=4.3167[H], 5000 EVs, Total Q=57.19 MWh
# Online 2252, Q=56.22 MWh, SoC=0.8933
# Power(MW): Pt=-2.8637, Pc=-2.8637, Pd=-0.0
# Ctrl: 0=1762; 1=490;
# EVA: ts=4.8333[H], 5000 EVs, Total Q=55.31 MWh
# Online 2196, Q=54.85 MWh, SoC=0.932
# Power(MW): Pt=-1.7494, Pc=-1.7494, Pd=-0.0
# Ctrl: 0=1897; 1=299;
# EVA: ts=1.8667[H], 5000 EVs, Total Q=55.83 MWh
# Online 1847, Q=46.15 MWh, SoC=0.5456
# Power(MW): Pt=-10.7533, Pc=-10.7533, Pd=-0.0
# Ctrl: 1=1795; 0=52;
# EVA: ts=3.85[H], 5000 EVs, Total Q=58.02 MWh
# Online 2267, Q=56.63 MWh, SoC=0.8453
# Power(MW): Pt=-4.1775, Pc=-4.1775, Pd=-0.0
# Ctrl: 0=1551; 1=716;
# EVA: ts=2.85[H], 5000 EVs, Total Q=58.54 MWh
# Online 2178, Q=54.39 MWh, SoC=0.7009
# Power(MW): Pt=-8.4493, Pc=-8.4493, Pd=-0.0
# Ctrl: 1=1433; 0=745;
# EVA: ts=5.35[H], 5000 EVs, Total Q=53.17 MWh
# Online 2126, Q=53.09 MWh, SoC=0.9561
# Power(MW): Pt=-1.0624, Pc=-1.0624, Pd=-0.0
# Ctrl: 0=1945; 1=181;
# EVA: ts=5.8667[H], 5000 EVs, Total Q=50.83 MWh
# Online 2034, Q=50.78 MWh, SoC=0.975
# Power(MW): Pt=-0.562, Pc=-0.562, Pd=-0.0
# Ctrl: 0=1938; 1=96;
# EVA: ts=0.8667[H], 5000 EVs, Total Q=46.71 MWh
# Online 1137, Q=28.44 MWh, SoC=0.4035
# Power(MW): Pt=-6.8375, Pc=-6.8375, Pd=-0.0
# Ctrl: 1=1137;
# EVA: ts=0.3833[H], 5000 EVs, Total Q=39.48 MWh
# Online 566, Q=14.0 MWh, SoC=0.3455
# Power(MW): Pt=-3.4107, Pc=-3.4107, Pd=-0.0
# Ctrl: 1=566;
# EVA: ts=1.3833[H], 5000 EVs, Total Q=52.52 MWh
# Online 1562, Q=39.1 MWh, SoC=0.4742
# Power(MW): Pt=-9.3834, Pc=-9.3834, Pd=-0.0
# Ctrl: 1=1562;
# EVA: ts=3.3667[H], 5000 EVs, Total Q=58.52 MWh
# Online 2253, Q=56.28 MWh, SoC=0.78
# Power(MW): Pt=-6.0397, Pc=-6.0397, Pd=-0.0
# Ctrl: 0=1222; 1=1031;
# EVA: ts=4.3333[H], 5000 EVs, Total Q=57.15 MWh
# Online 2251, Q=56.21 MWh, SoC=0.8946
# Power(MW): Pt=-2.8299, Pc=-2.8299, Pd=-0.0
# Ctrl: 0=1767; 1=484;
# EVA: ts=1.8833[H], 5000 EVs, Total Q=55.83 MWh
# Online 1853, Q=46.3 MWh, SoC=0.5483
# Power(MW): Pt=-10.7719, Pc=-10.7719, Pd=-0.0
# Ctrl: 1=1799; 0=54;
# EVA: ts=2.3667[H], 5000 EVs, Total Q=57.79 MWh
# Online 2058, Q=51.42 MWh, SoC=0.6208
# Power(MW): Pt=-10.4622, Pc=-10.4622, Pd=-0.0
# Ctrl: 1=1761; 0=297;
# EVA: ts=3.8667[H], 5000 EVs, Total Q=57.98 MWh
# Online 2266, Q=56.61 MWh, SoC=0.8472
# Power(MW): Pt=-4.1056, Pc=-4.1056, Pd=-0.0
# Ctrl: 0=1562; 1=704;
# EVA: ts=2.8667[H], 5000 EVs, Total Q=58.57 MWh
# Online 2183, Q=54.52 MWh, SoC=0.7034
# Power(MW): Pt=-8.3824, Pc=-8.3824, Pd=-0.0
# Ctrl: 1=1422; 0=761;
# EVA: ts=5.3667[H], 5000 EVs, Total Q=53.07 MWh
# Online 2122, Q=53.0 MWh, SoC=0.9568
# Power(MW): Pt=-1.0502, Pc=-1.0502, Pd=-0.0
# Ctrl: 0=1943; 1=179;
# EVA: ts=4.85[H], 5000 EVs, Total Q=55.2 MWh
# Online 2192, Q=54.74 MWh, SoC=0.9333
# Power(MW): Pt=-1.7023, Pc=-1.7023, Pd=-0.0
# Ctrl: 0=1901; 1=291;
# EVA: ts=0.8833[H], 5000 EVs, Total Q=46.89 MWh
# Online 1154, Q=28.87 MWh, SoC=0.4056
# Power(MW): Pt=-6.9369, Pc=-6.9369, Pd=-0.0
# Ctrl: 1=1154;
# EVA: ts=1.4[H], 5000 EVs, Total Q=52.65 MWh
# Online 1573, Q=39.36 MWh, SoC=0.4765
# Power(MW): Pt=-9.4491, Pc=-9.4491, Pd=-0.0
# Ctrl: 1=1573;
# EVA: ts=5.8833[H], 5000 EVs, Total Q=50.78 MWh
# Online 2032, Q=50.73 MWh, SoC=0.9755
# Power(MW): Pt=-0.5487, Pc=-0.5487, Pd=-0.0
# Ctrl: 0=1938; 1=94;
# EVA: ts=0.4[H], 5000 EVs, Total Q=39.75 MWh
# Online 585, Q=14.47 MWh, SoC=0.3477
# Power(MW): Pt=-3.5269, Pc=-3.5269, Pd=-0.0
# Ctrl: 1=585;
# EVA: ts=3.3833[H], 5000 EVs, Total Q=58.52 MWh
# Online 2255, Q=56.32 MWh, SoC=0.7826
# Power(MW): Pt=-5.9637, Pc=-5.9637, Pd=-0.0
# Ctrl: 0=1237; 1=1018;
# EVA: ts=4.35[H], 5000 EVs, Total Q=57.09 MWh
# Online 2249, Q=56.15 MWh, SoC=0.8962
# Power(MW): Pt=-2.7825, Pc=-2.7825, Pd=-0.0
# Ctrl: 0=1773; 1=476;
# EVA: ts=1.9[H], 5000 EVs, Total Q=56.02 MWh
# Online 1863, Q=46.54 MWh, SoC=0.5507
# Power(MW): Pt=-10.7885, Pc=-10.7885, Pd=-0.0
# Ctrl: 1=1802; 0=61;
# EVA: ts=3.8833[H], 5000 EVs, Total Q=57.92 MWh
# Online 2264, Q=56.56 MWh, SoC=0.8494
# Power(MW): Pt=-4.0705, Pc=-4.0705, Pd=-0.0
# Ctrl: 0=1566; 1=698;
# EVA: ts=5.3833[H], 5000 EVs, Total Q=53.0 MWh
# Online 2119, Q=52.92 MWh, SoC=0.9575
# Power(MW): Pt=-1.0336, Pc=-1.0336, Pd=-0.0
# Ctrl: 0=1943; 1=176;
# EVA: ts=2.8833[H], 5000 EVs, Total Q=58.55 MWh
# Online 2183, Q=54.52 MWh, SoC=0.7066
# Power(MW): Pt=-8.2921, Pc=-8.2921, Pd=-0.0
# Ctrl: 1=1407; 0=776;
# EVA: ts=0.9[H], 5000 EVs, Total Q=47.1 MWh
# Online 1173, Q=29.33 MWh, SoC=0.4077
# Power(MW): Pt=-7.047, Pc=-7.047, Pd=-0.0
# Ctrl: 1=1173;
# EVA: ts=1.4167[H], 5000 EVs, Total Q=52.75 MWh
# Online 1590, Q=39.79 MWh, SoC=0.4782
# Power(MW): Pt=-9.5512, Pc=-9.5512, Pd=-0.0
# Ctrl: 1=1590;
# EVA: ts=4.8667[H], 5000 EVs, Total Q=55.07 MWh
# Online 2187, Q=54.61 MWh, SoC=0.9346
# Power(MW): Pt=-1.6524, Pc=-1.6524, Pd=-0.0
# Ctrl: 0=1904; 1=283;
# EVA: ts=2.3833[H], 5000 EVs, Total Q=57.83 MWh
# Online 2063, Q=51.54 MWh, SoC=0.6237
# Power(MW): Pt=-10.4146, Pc=-10.4146, Pd=-0.0
# Ctrl: 1=1752; 0=311;
# EVA: ts=5.9[H], 5000 EVs, Total Q=50.76 MWh
# Online 2031, Q=50.71 MWh, SoC=0.9761
# Power(MW): Pt=-0.5435, Pc=-0.5435, Pd=-0.0
# Ctrl: 0=1938; 1=93;
# EVA: ts=0.4167[H], 5000 EVs, Total Q=40.17 MWh
# Online 604, Q=14.95 MWh, SoC=0.3497
# Power(MW): Pt=-3.6401, Pc=-3.6401, Pd=-0.0
# Ctrl: 1=604;
# EVA: ts=3.4[H], 5000 EVs, Total Q=58.47 MWh
# Online 2253, Q=56.28 MWh, SoC=0.7854
# Power(MW): Pt=-5.8929, Pc=-5.8929, Pd=-0.0
# Ctrl: 0=1247; 1=1006;
# EVA: ts=4.3667[H], 5000 EVs, Total Q=57.04 MWh
# Online 2247, Q=56.1 MWh, SoC=0.8978
# Power(MW): Pt=-2.7482, Pc=-2.7482, Pd=-0.0
# Ctrl: 0=1777; 1=470;
# EVA: ts=1.9167[H], 5000 EVs, Total Q=56.11 MWh
# Online 1873, Q=46.78 MWh, SoC=0.553
# Power(MW): Pt=-10.8151, Pc=-10.8151, Pd=-0.0
# Ctrl: 1=1807; 0=66;
# EVA: ts=3.9[H], 5000 EVs, Total Q=57.92 MWh
# Online 2265, Q=56.58 MWh, SoC=0.8514
# Power(MW): Pt=-4.0391, Pc=-4.0391, Pd=-0.0
# Ctrl: 0=1572; 1=693;
# EVA: ts=5.4[H], 5000 EVs, Total Q=52.85 MWh
# Online 2114, Q=52.79 MWh, SoC=0.958
# Power(MW): Pt=-1.0141, Pc=-1.0141, Pd=-0.0
# Ctrl: 0=1941; 1=173;
# EVA: ts=0.9167[H], 5000 EVs, Total Q=47.34 MWh
# Online 1187, Q=29.69 MWh, SoC=0.4101
# Power(MW): Pt=-7.1296, Pc=-7.1296, Pd=-0.0
# Ctrl: 1=1187;
# EVA: ts=1.4333[H], 5000 EVs, Total Q=52.89 MWh
# Online 1607, Q=40.21 MWh, SoC=0.4801
# Power(MW): Pt=-9.6342, Pc=-9.6342, Pd=-0.0
# Ctrl: 1=1604; 0=3;
# EVA: ts=2.9[H], 5000 EVs, Total Q=58.55 MWh
# Online 2190, Q=54.69 MWh, SoC=0.7087
# Power(MW): Pt=-8.2497, Pc=-8.2497, Pd=-0.0
# Ctrl: 1=1400; 0=790;
# EVA: ts=4.8833[H], 5000 EVs, Total Q=55.05 MWh
# Online 2186, Q=54.59 MWh, SoC=0.9357
# Power(MW): Pt=-1.6352, Pc=-1.6352, Pd=-0.0
# Ctrl: 0=1906; 1=280;
# EVA: ts=2.4[H], 5000 EVs, Total Q=57.86 MWh
# Online 2069, Q=51.68 MWh, SoC=0.6265
# Power(MW): Pt=-10.3524, Pc=-10.3524, Pd=-0.0
# Ctrl: 1=1742; 0=327;
# EVA: ts=5.9167[H], 5000 EVs, Total Q=50.71 MWh
# Online 2029, Q=50.66 MWh, SoC=0.9766
# Power(MW): Pt=-0.5435, Pc=-0.5435, Pd=-0.0
# Ctrl: 0=1936; 1=93;
# EVA: ts=0.4333[H], 5000 EVs, Total Q=40.62 MWh
# Online 626, Q=15.49 MWh, SoC=0.3517
# Power(MW): Pt=-3.7719, Pc=-3.7719, Pd=-0.0
# Ctrl: 1=626;
# EVA: ts=3.4167[H], 5000 EVs, Total Q=58.5 MWh
# Online 2254, Q=56.31 MWh, SoC=0.788
# Power(MW): Pt=-5.8132, Pc=-5.8132, Pd=-0.0
# Ctrl: 0=1261; 1=993;
# EVA: ts=1.9333[H], 5000 EVs, Total Q=56.21 MWh
# Online 1878, Q=46.9 MWh, SoC=0.556
# Power(MW): Pt=-10.8073, Pc=-10.8073, Pd=-0.0
# Ctrl: 1=1806; 0=72;
# EVA: ts=4.3833[H], 5000 EVs, Total Q=56.99 MWh
# Online 2245, Q=56.05 MWh, SoC=0.8994
# Power(MW): Pt=-2.706, Pc=-2.706, Pd=-0.0
# Ctrl: 0=1782; 1=463;
# EVA: ts=5.4167[H], 5000 EVs, Total Q=52.8 MWh
# Online 2113, Q=52.77 MWh, SoC=0.9587
# Power(MW): Pt=-1.0027, Pc=-1.0027, Pd=-0.0
# Ctrl: 0=1942; 1=171;
# EVA: ts=0.9333[H], 5000 EVs, Total Q=47.44 MWh
# Online 1200, Q=30.02 MWh, SoC=0.4127
# Power(MW): Pt=-7.2132, Pc=-7.2132, Pd=-0.0
# Ctrl: 1=1200;
# EVA: ts=1.45[H], 5000 EVs, Total Q=53.1 MWh
# Online 1620, Q=40.52 MWh, SoC=0.4827
# Power(MW): Pt=-9.7089, Pc=-9.7089, Pd=-0.0
# Ctrl: 1=1616; 0=4;
# EVA: ts=2.4167[H], 5000 EVs, Total Q=57.89 MWh
# Online 2073, Q=51.78 MWh, SoC=0.6295
# Power(MW): Pt=-10.2534, Pc=-10.2534, Pd=-0.0
# Ctrl: 1=1726; 0=347;
# EVA: ts=2.9167[H], 5000 EVs, Total Q=58.54 MWh
# Online 2194, Q=54.78 MWh, SoC=0.7114
# Power(MW): Pt=-8.1801, Pc=-8.1801, Pd=-0.0
# Ctrl: 1=1388; 0=806;
# EVA: ts=3.9167[H], 5000 EVs, Total Q=57.9 MWh
# Online 2264, Q=56.55 MWh, SoC=0.8537
# Power(MW): Pt=-3.9744, Pc=-3.9744, Pd=-0.0
# Ctrl: 0=1582; 1=682;
# EVA: ts=4.9[H], 5000 EVs, Total Q=55.0 MWh
# Online 2184, Q=54.54 MWh, SoC=0.9369
# Power(MW): Pt=-1.6002, Pc=-1.6002, Pd=-0.0
# Ctrl: 0=1910; 1=274;
# EVA: ts=0.45[H], 5000 EVs, Total Q=40.93 MWh
# Online 650, Q=16.1 MWh, SoC=0.3527
# Power(MW): Pt=-3.9155, Pc=-3.9155, Pd=-0.0
# Ctrl: 1=650;
# EVA: ts=5.9333[H], 5000 EVs, Total Q=50.73 MWh
# Online 2029, Q=50.66 MWh, SoC=0.977
# Power(MW): Pt=-0.5378, Pc=-0.5378, Pd=-0.0
# Ctrl: 0=1937; 1=92;
# EVA: ts=3.4333[H], 5000 EVs, Total Q=58.5 MWh
# Online 2253, Q=56.29 MWh, SoC=0.7909
# Power(MW): Pt=-5.7832, Pc=-5.7832, Pd=-0.0
# Ctrl: 0=1265; 1=988;
# EVA: ts=1.95[H], 5000 EVs, Total Q=56.23 MWh
# Online 1885, Q=47.08 MWh, SoC=0.5584
# Power(MW): Pt=-10.8164, Pc=-10.8164, Pd=-0.0
# Ctrl: 1=1808; 0=77;
# EVA: ts=0.95[H], 5000 EVs, Total Q=47.66 MWh
# Online 1214, Q=30.38 MWh, SoC=0.415
# Power(MW): Pt=-7.2977, Pc=-7.2977, Pd=-0.0
# Ctrl: 1=1214;
# EVA: ts=4.4[H], 5000 EVs, Total Q=57.01 MWh
# Online 2246, Q=56.07 MWh, SoC=0.9008
# Power(MW): Pt=-2.6433, Pc=-2.6433, Pd=-0.0
# Ctrl: 0=1793; 1=453;
# EVA: ts=1.4667[H], 5000 EVs, Total Q=53.28 MWh
# Online 1628, Q=40.73 MWh, SoC=0.4852
# Power(MW): Pt=-9.7564, Pc=-9.7564, Pd=-0.0
# Ctrl: 1=1624; 0=4;
# EVA: ts=5.4333[H], 5000 EVs, Total Q=52.69 MWh
# Online 2109, Q=52.66 MWh, SoC=0.9594
# Power(MW): Pt=-0.9718, Pc=-0.9718, Pd=-0.0
# Ctrl: 0=1943; 1=166;
# EVA: ts=2.4333[H], 5000 EVs, Total Q=57.86 MWh
# Online 2079, Q=51.92 MWh, SoC=0.632
# Power(MW): Pt=-10.216, Pc=-10.216, Pd=-0.0
# Ctrl: 1=1720; 0=359;
# EVA: ts=0.4667[H], 5000 EVs, Total Q=41.16 MWh
# Online 667, Q=16.51 MWh, SoC=0.3549
# Power(MW): Pt=-4.0146, Pc=-4.0146, Pd=-0.0
# Ctrl: 1=667;
# EVA: ts=2.9333[H], 5000 EVs, Total Q=58.54 MWh
# Online 2198, Q=54.88 MWh, SoC=0.7141
# Power(MW): Pt=-8.1081, Pc=-8.1081, Pd=-0.0
# Ctrl: 1=1376; 0=822;
# EVA: ts=4.9167[H], 5000 EVs, Total Q=54.89 MWh
# Online 2181, Q=54.46 MWh, SoC=0.9376
# Power(MW): Pt=-1.5816, Pc=-1.5816, Pd=-0.0
# Ctrl: 0=1910; 1=271;
# EVA: ts=3.9333[H], 5000 EVs, Total Q=57.79 MWh
# Online 2259, Q=56.42 MWh, SoC=0.8562
# Power(MW): Pt=-3.9206, Pc=-3.9206, Pd=-0.0
# Ctrl: 0=1586; 1=673;
# EVA: ts=5.95[H], 5000 EVs, Total Q=50.68 MWh
# Online 2027, Q=50.61 MWh, SoC=0.9774
# Power(MW): Pt=-0.5378, Pc=-0.5378, Pd=-0.0
# Ctrl: 0=1935; 1=92;
# EVA: ts=3.45[H], 5000 EVs, Total Q=58.53 MWh
# Online 2257, Q=56.39 MWh, SoC=0.7927
# Power(MW): Pt=-5.7384, Pc=-5.7384, Pd=-0.0
# Ctrl: 0=1277; 1=980;
# EVA: ts=1.9667[H], 5000 EVs, Total Q=56.4 MWh
# Online 1891, Q=47.23 MWh, SoC=0.5612
# Power(MW): Pt=-10.8158, Pc=-10.8158, Pd=-0.0
# Ctrl: 1=1808; 0=83;
# EVA: ts=0.9667[H], 5000 EVs, Total Q=47.82 MWh
# Online 1228, Q=30.73 MWh, SoC=0.4173
# Power(MW): Pt=-7.3814, Pc=-7.3814, Pd=-0.0
# Ctrl: 1=1228;
# EVA: ts=1.4833[H], 5000 EVs, Total Q=53.47 MWh
# Online 1641, Q=41.05 MWh, SoC=0.4875
# Power(MW): Pt=-9.8362, Pc=-9.8362, Pd=-0.0
# Ctrl: 1=1637; 0=4;
# EVA: ts=2.45[H], 5000 EVs, Total Q=57.97 MWh
# Online 2087, Q=52.1 MWh, SoC=0.6343
# Power(MW): Pt=-10.2153, Pc=-10.2153, Pd=-0.0
# Ctrl: 1=1720; 0=367;
# EVA: ts=4.4167[H], 5000 EVs, Total Q=56.99 MWh
# Online 2245, Q=56.05 MWh, SoC=0.9023
# Power(MW): Pt=-2.6148, Pc=-2.6148, Pd=-0.0
# Ctrl: 0=1797; 1=448;
# EVA: ts=4.9333[H], 5000 EVs, Total Q=54.89 MWh
# Online 2182, Q=54.48 MWh, SoC=0.9384
# Power(MW): Pt=-1.5351, Pc=-1.5351, Pd=-0.0
# Ctrl: 0=1919; 1=263;
# EVA: ts=5.45[H], 5000 EVs, Total Q=52.67 MWh
# Online 2108, Q=52.64 MWh, SoC=0.9601
# Power(MW): Pt=-0.9532, Pc=-0.9532, Pd=-0.0
# Ctrl: 0=1945; 1=163;
# EVA: ts=0.4833[H], 5000 EVs, Total Q=41.48 MWh
# Online 688, Q=17.03 MWh, SoC=0.3563
# Power(MW): Pt=-4.1418, Pc=-4.1418, Pd=-0.0
# Ctrl: 1=688;
# EVA: ts=2.95[H], 5000 EVs, Total Q=58.57 MWh
# Online 2201, Q=54.95 MWh, SoC=0.7169
# Power(MW): Pt=-8.0134, Pc=-8.0134, Pd=-0.0
# Ctrl: 1=1361; 0=840;
# EVA: ts=3.95[H], 5000 EVs, Total Q=57.74 MWh
# Online 2258, Q=56.4 MWh, SoC=0.8581
# Power(MW): Pt=-3.8612, Pc=-3.8612, Pd=-0.0
# Ctrl: 0=1595; 1=663;
# EVA: ts=5.9667[H], 5000 EVs, Total Q=50.64 MWh
# Online 2025, Q=50.57 MWh, SoC=0.9779
# Power(MW): Pt=-0.5328, Pc=-0.5328, Pd=-0.0
# Ctrl: 0=1934; 1=91;
# EVA: ts=1.9833[H], 5000 EVs, Total Q=56.54 MWh
# Online 1900, Q=47.46 MWh, SoC=0.5636
# Power(MW): Pt=-10.8441, Pc=-10.8441, Pd=-0.0
# Ctrl: 1=1813; 0=87;
# EVA: ts=3.4667[H], 5000 EVs, Total Q=58.51 MWh
# ...
# Ctrl: 0=1458; 1=595;
# EVA: ts=22.35[H], 5000 EVs, Total Q=51.17 MWh
# Online 1962, Q=48.95 MWh, SoC=0.9152
# Power(MW): Pt=-1.9, Pc=-1.9, Pd=-0.0
# Ctrl: 0=1643; 1=319;
# EVA: ts=23.3333[H], 5000 EVs, Total Q=30.16 MWh
# Online 1190, Q=29.57 MWh, SoC=0.9326
# Power(MW): Pt=-0.9451, Pc=-0.9451, Pd=-0.0
# Ctrl: 0=1031; 1=159;
# EVA: ts=23.8167[H], 5000 EVs, Total Q=10.61 MWh
# Online 419, Q=10.51 MWh, SoC=0.9361
# Power(MW): Pt=-0.3256, Pc=-0.3256, Pd=-0.0
# Ctrl: 0=363; 1=56;
# EVA: ts=19.8667[H], 5000 EVs, Total Q=53.41 MWh
# Online 1952, Q=48.75 MWh, SoC=0.8379
# Power(MW): Pt=-3.85, Pc=-3.85, Pd=-0.0
# Ctrl: 0=1303; 1=649;
# EVA: ts=21.85[H], 5000 EVs, Total Q=56.1 MWh
# Online 2127, Q=53.05 MWh, SoC=0.902
# Power(MW): Pt=-2.5186, Pc=-2.5186, Pd=-0.0
# Ctrl: 0=1706; 1=421;
# EVA: ts=20.8667[H], 5000 EVs, Total Q=57.96 MWh
# Online 2137, Q=53.35 MWh, SoC=0.8797
# Power(MW): Pt=-3.1608, Pc=-3.1608, Pd=-0.0
# Ctrl: 0=1604; 1=533;
# EVA: ts=19.3833[H], 5000 EVs, Total Q=51.31 MWh
# Online 1827, Q=45.61 MWh, SoC=0.8215
# Power(MW): Pt=-3.9606, Pc=-3.9606, Pd=-0.0
# Ctrl: 0=1160; 1=667;
# EVA: ts=22.8333[H], 5000 EVs, Total Q=43.43 MWh
# Online 1683, Q=41.97 MWh, SoC=0.9264
# Power(MW): Pt=-1.4364, Pc=-1.4364, Pd=-0.0
# Ctrl: 0=1442; 1=241;
# EVA: ts=21.35[H], 5000 EVs, Total Q=57.82 MWh
# Online 2146, Q=53.59 MWh, SoC=0.8956
# Power(MW): Pt=-2.758, Pc=-2.758, Pd=-0.0
# Ctrl: 0=1684; 1=462;
# EVA: ts=18.4333[H], 5000 EVs, Total Q=45.9 MWh
# Online 1570, Q=39.26 MWh, SoC=0.7831
# Power(MW): Pt=-4.0759, Pc=-4.0759, Pd=-0.0
# Ctrl: 0=886; 1=684;
# EVA: ts=18.9167[H], 5000 EVs, Total Q=48.92 MWh
# Online 1706, Q=42.64 MWh, SoC=0.8018
# Power(MW): Pt=-4.0546, Pc=-4.0546, Pd=-0.0
# Ctrl: 0=1024; 1=682;
# EVA: ts=20.3833[H], 5000 EVs, Total Q=55.52 MWh
# Online 2054, Q=51.25 MWh, SoC=0.8606
# Power(MW): Pt=-3.5268, Pc=-3.5268, Pd=-0.0
# Ctrl: 0=1459; 1=595;
# EVA: ts=23.35[H], 5000 EVs, Total Q=29.48 MWh
# Online 1164, Q=28.91 MWh, SoC=0.9336
# Power(MW): Pt=-0.9199, Pc=-0.9199, Pd=-0.0
# Ctrl: 0=1009; 1=155;
# EVA: ts=23.8333[H], 5000 EVs, Total Q=9.64 MWh
# Online 382, Q=9.56 MWh, SoC=0.932
# Power(MW): Pt=-0.3038, Pc=-0.3038, Pd=-0.0
# Ctrl: 0=330; 1=52;
# EVA: ts=22.3667[H], 5000 EVs, Total Q=51.11 MWh
# Online 1962, Q=48.96 MWh, SoC=0.9146
# Power(MW): Pt=-1.8825, Pc=-1.8825, Pd=-0.0
# Ctrl: 0=1646; 1=316;
# EVA: ts=19.8833[H], 5000 EVs, Total Q=53.54 MWh
# Online 1956, Q=48.85 MWh, SoC=0.8386
# Power(MW): Pt=-3.8183, Pc=-3.8183, Pd=-0.0
# Ctrl: 0=1312; 1=644;
# EVA: ts=21.8667[H], 5000 EVs, Total Q=55.9 MWh
# Online 2120, Q=52.88 MWh, SoC=0.9023
# Power(MW): Pt=-2.5069, Pc=-2.5069, Pd=-0.0
# Ctrl: 0=1701; 1=419;
# EVA: ts=20.8833[H], 5000 EVs, Total Q=58.01 MWh
# Online 2142, Q=53.48 MWh, SoC=0.8796
# Power(MW): Pt=-3.1627, Pc=-3.1627, Pd=-0.0
# Ctrl: 0=1609; 1=533;
# EVA: ts=19.4[H], 5000 EVs, Total Q=51.31 MWh
# Online 1829, Q=45.66 MWh, SoC=0.8227
# Power(MW): Pt=-3.9612, Pc=-3.9612, Pd=-0.0
# Ctrl: 0=1162; 1=667;
# EVA: ts=21.3667[H], 5000 EVs, Total Q=57.86 MWh
# Online 2148, Q=53.64 MWh, SoC=0.8954
# Power(MW): Pt=-2.7654, Pc=-2.7654, Pd=-0.0
# Ctrl: 0=1685; 1=463;
# EVA: ts=18.45[H], 5000 EVs, Total Q=46.17 MWh
# Online 1580, Q=39.52 MWh, SoC=0.7821
# Power(MW): Pt=-4.1098, Pc=-4.1098, Pd=-0.0
# Ctrl: 0=890; 1=690;
# EVA: ts=22.85[H], 5000 EVs, Total Q=43.19 MWh
# Online 1675, Q=41.78 MWh, SoC=0.926
# Power(MW): Pt=-1.4416, Pc=-1.4416, Pd=-0.0
# Ctrl: 0=1433; 1=242;
# EVA: ts=18.9333[H], 5000 EVs, Total Q=49.06 MWh
# Online 1715, Q=42.87 MWh, SoC=0.8011
# Power(MW): Pt=-4.0845, Pc=-4.0845, Pd=-0.0
# Ctrl: 0=1028; 1=687;
# EVA: ts=23.3667[H], 5000 EVs, Total Q=28.97 MWh
# Online 1145, Q=28.45 MWh, SoC=0.9334
# Power(MW): Pt=-0.9074, Pc=-0.9074, Pd=-0.0
# Ctrl: 0=992; 1=153;
# EVA: ts=20.4[H], 5000 EVs, Total Q=55.6 MWh
# Online 2054, Q=51.25 MWh, SoC=0.8621
# Power(MW): Pt=-3.478, Pc=-3.478, Pd=-0.0
# Ctrl: 0=1467; 1=587;
# EVA: ts=22.3833[H], 5000 EVs, Total Q=50.91 MWh
# Online 1954, Q=48.74 MWh, SoC=0.9151
# Power(MW): Pt=-1.876, Pc=-1.876, Pd=-0.0
# Ctrl: 0=1639; 1=315;
# EVA: ts=23.85[H], 5000 EVs, Total Q=8.68 MWh
# Online 346, Q=8.63 MWh, SoC=0.9339
# Power(MW): Pt=-0.2555, Pc=-0.2555, Pd=-0.0
# Ctrl: 0=302; 1=44;
# EVA: ts=19.9[H], 5000 EVs, Total Q=53.63 MWh
# Online 1959, Q=48.92 MWh, SoC=0.8395
# Power(MW): Pt=-3.7938, Pc=-3.7938, Pd=-0.0
# Ctrl: 0=1319; 1=640;
# EVA: ts=21.8833[H], 5000 EVs, Total Q=55.8 MWh
# Online 2117, Q=52.8 MWh, SoC=0.9032
# Power(MW): Pt=-2.4763, Pc=-2.4763, Pd=-0.0
# Ctrl: 0=1703; 1=414;
# EVA: ts=19.4167[H], 5000 EVs, Total Q=51.33 MWh
# Online 1832, Q=45.73 MWh, SoC=0.8237
# Power(MW): Pt=-3.9675, Pc=-3.9675, Pd=-0.0
# Ctrl: 0=1164; 1=668;
# EVA: ts=20.9[H], 5000 EVs, Total Q=58.03 MWh
# Online 2146, Q=53.57 MWh, SoC=0.88
# Power(MW): Pt=-3.1285, Pc=-3.1285, Pd=-0.0
# Ctrl: 0=1619; 1=527;
# EVA: ts=21.3833[H], 5000 EVs, Total Q=57.89 MWh
# Online 2149, Q=53.67 MWh, SoC=0.8963
# Power(MW): Pt=-2.7595, Pc=-2.7595, Pd=-0.0
# Ctrl: 0=1687; 1=462;
# EVA: ts=18.4667[H], 5000 EVs, Total Q=46.24 MWh
# Online 1587, Q=39.69 MWh, SoC=0.7821
# Power(MW): Pt=-4.1522, Pc=-4.1522, Pd=-0.0
# Ctrl: 0=890; 1=697;
# EVA: ts=18.95[H], 5000 EVs, Total Q=49.13 MWh
# Online 1719, Q=42.96 MWh, SoC=0.802
# Power(MW): Pt=-4.0766, Pc=-4.0766, Pd=-0.0
# Ctrl: 0=1033; 1=686;
# EVA: ts=23.3833[H], 5000 EVs, Total Q=28.39 MWh
# Online 1124, Q=27.91 MWh, SoC=0.9346
# Power(MW): Pt=-0.8709, Pc=-0.8709, Pd=-0.0
# Ctrl: 0=977; 1=147;
# EVA: ts=22.8667[H], 5000 EVs, Total Q=42.96 MWh
# Online 1668, Q=41.61 MWh, SoC=0.926
# Power(MW): Pt=-1.4462, Pc=-1.4462, Pd=-0.0
# Ctrl: 0=1425; 1=243;
# EVA: ts=20.4167[H], 5000 EVs, Total Q=55.72 MWh
# Online 2055, Q=51.28 MWh, SoC=0.8634
# Power(MW): Pt=-3.4614, Pc=-3.4614, Pd=-0.0
# Ctrl: 0=1471; 1=584;
# EVA: ts=22.4[H], 5000 EVs, Total Q=50.7 MWh
# Online 1946, Q=48.55 MWh, SoC=0.9154
# Power(MW): Pt=-1.862, Pc=-1.862, Pd=-0.0
# Ctrl: 0=1634; 1=312;
# EVA: ts=23.8667[H], 5000 EVs, Total Q=7.73 MWh
# Online 306, Q=7.67 MWh, SoC=0.9335
# Power(MW): Pt=-0.2307, Pc=-0.2307, Pd=-0.0
# Ctrl: 0=266; 1=40;
# EVA: ts=19.9167[H], 5000 EVs, Total Q=53.81 MWh
# Online 1959, Q=48.92 MWh, SoC=0.8412
# Power(MW): Pt=-3.7508, Pc=-3.7508, Pd=-0.0
# Ctrl: 0=1326; 1=633;
# EVA: ts=21.9[H], 5000 EVs, Total Q=55.75 MWh
# Online 2111, Q=52.66 MWh, SoC=0.9037
# Power(MW): Pt=-2.4649, Pc=-2.4649, Pd=-0.0
# Ctrl: 0=1699; 1=412;
# EVA: ts=20.9167[H], 5000 EVs, Total Q=58.03 MWh
# Online 2151, Q=53.7 MWh, SoC=0.8797
# Power(MW): Pt=-3.117, Pc=-3.117, Pd=-0.0
# Ctrl: 0=1626; 1=525;
# EVA: ts=18.4833[H], 5000 EVs, Total Q=46.37 MWh
# Online 1591, Q=39.79 MWh, SoC=0.7831
# Power(MW): Pt=-4.1509, Pc=-4.1509, Pd=-0.0
# Ctrl: 0=894; 1=697;
# EVA: ts=23.4[H], 5000 EVs, Total Q=27.95 MWh
# Online 1108, Q=27.53 MWh, SoC=0.9345
# Power(MW): Pt=-0.8648, Pc=-0.8648, Pd=-0.0
# Ctrl: 0=962; 1=146;
# EVA: ts=19.4333[H], 5000 EVs, Total Q=51.41 MWh
# Online 1837, Q=45.85 MWh, SoC=0.8241
# Power(MW): Pt=-3.9845, Pc=-3.9845, Pd=-0.0
# Ctrl: 0=1166; 1=671;
# EVA: ts=21.4[H], 5000 EVs, Total Q=57.88 MWh
# Online 2149, Q=53.66 MWh, SoC=0.8965
# Power(MW): Pt=-2.7613, Pc=-2.7613, Pd=-0.0
# Ctrl: 0=1687; 1=462;
# EVA: ts=18.9667[H], 5000 EVs, Total Q=49.18 MWh
# Online 1721, Q=43.01 MWh, SoC=0.8034
# Power(MW): Pt=-4.0734, Pc=-4.0734, Pd=-0.0
# Ctrl: 0=1036; 1=685;
# EVA: ts=22.8833[H], 5000 EVs, Total Q=42.74 MWh
# Online 1659, Q=41.39 MWh, SoC=0.9267
# Power(MW): Pt=-1.4409, Pc=-1.4409, Pd=-0.0
# Ctrl: 0=1417; 1=242;
# EVA: ts=23.8833[H], 5000 EVs, Total Q=7.17 MWh
# Online 285, Q=7.15 MWh, SoC=0.9331
# Power(MW): Pt=-0.2032, Pc=-0.2032, Pd=-0.0
# Ctrl: 0=250; 1=35;
# EVA: ts=20.4333[H], 5000 EVs, Total Q=55.77 MWh
# Online 2058, Q=51.35 MWh, SoC=0.8641
# Power(MW): Pt=-3.4599, Pc=-3.4599, Pd=-0.0
# Ctrl: 0=1474; 1=584;
# EVA: ts=22.4167[H], 5000 EVs, Total Q=50.52 MWh
# Online 1940, Q=48.4 MWh, SoC=0.9155
# Power(MW): Pt=-1.8257, Pc=-1.8257, Pd=-0.0
# Ctrl: 0=1634; 1=306;
# EVA: ts=19.9333[H], 5000 EVs, Total Q=53.91 MWh
# Online 1965, Q=49.06 MWh, SoC=0.8413
# Power(MW): Pt=-3.7733, Pc=-3.7733, Pd=-0.0
# Ctrl: 0=1328; 1=637;
# EVA: ts=20.9333[H], 5000 EVs, Total Q=58.17 MWh
# Online 2154, Q=53.77 MWh, SoC=0.88
# Power(MW): Pt=-3.1141, Pc=-3.1141, Pd=-0.0
# Ctrl: 0=1630; 1=524;
# EVA: ts=21.9167[H], 5000 EVs, Total Q=55.58 MWh
# Online 2106, Q=52.54 MWh, SoC=0.904
# Power(MW): Pt=-2.4441, Pc=-2.4441, Pd=-0.0
# Ctrl: 0=1697; 1=409;
# EVA: ts=18.5[H], 5000 EVs, Total Q=46.41 MWh
# Online 1595, Q=39.89 MWh, SoC=0.7836
# Power(MW): Pt=-4.1453, Pc=-4.1453, Pd=-0.0
# Ctrl: 0=899; 1=696;
# EVA: ts=23.4167[H], 5000 EVs, Total Q=27.39 MWh
# Online 1086, Q=26.99 MWh, SoC=0.9347
# Power(MW): Pt=-0.8594, Pc=-0.8594, Pd=-0.0
# Ctrl: 0=941; 1=145;
# EVA: ts=21.4167[H], 5000 EVs, Total Q=57.86 MWh
# Online 2151, Q=53.72 MWh, SoC=0.8963
# Power(MW): Pt=-2.7747, Pc=-2.7747, Pd=-0.0
# Ctrl: 0=1687; 1=464;
# EVA: ts=22.9[H], 5000 EVs, Total Q=42.41 MWh
# Online 1651, Q=41.17 MWh, SoC=0.9266
# Power(MW): Pt=-1.4307, Pc=-1.4307, Pd=-0.0
# Ctrl: 0=1411; 1=240;
# EVA: ts=19.45[H], 5000 EVs, Total Q=51.51 MWh
# Online 1847, Q=46.11 MWh, SoC=0.823
# Power(MW): Pt=-4.0211, Pc=-4.0211, Pd=-0.0
# Ctrl: 0=1170; 1=677;
# EVA: ts=18.9833[H], 5000 EVs, Total Q=49.25 MWh
# Online 1724, Q=43.08 MWh, SoC=0.8045
# Power(MW): Pt=-4.0532, Pc=-4.0532, Pd=-0.0
# Ctrl: 0=1042; 1=682;
# EVA: ts=23.9[H], 5000 EVs, Total Q=6.19 MWh
# Online 246, Q=6.17 MWh, SoC=0.9301
# Power(MW): Pt=-0.1855, Pc=-0.1855, Pd=-0.0
# Ctrl: 0=214; 1=32;
# EVA: ts=20.45[H], 5000 EVs, Total Q=55.82 MWh
# Online 2062, Q=51.45 MWh, SoC=0.8645
# Power(MW): Pt=-3.4646, Pc=-3.4646, Pd=-0.0
# Ctrl: 0=1477; 1=585;
# EVA: ts=22.4333[H], 5000 EVs, Total Q=50.29 MWh
# Online 1930, Q=48.14 MWh, SoC=0.9164
# Power(MW): Pt=-1.8038, Pc=-1.8038, Pd=-0.0
# Ctrl: 0=1628; 1=302;
# EVA: ts=19.95[H], 5000 EVs, Total Q=53.93 MWh
# Online 1968, Q=49.13 MWh, SoC=0.8423
# Power(MW): Pt=-3.7565, Pc=-3.7565, Pd=-0.0
# Ctrl: 0=1333; 1=635;
# EVA: ts=20.95[H], 5000 EVs, Total Q=58.12 MWh
# Online 2151, Q=53.69 MWh, SoC=0.8813
# Power(MW): Pt=-3.084, Pc=-3.084, Pd=-0.0
# Ctrl: 0=1632; 1=519;
# EVA: ts=23.4333[H], 5000 EVs, Total Q=26.8 MWh
# Online 1064, Q=26.42 MWh, SoC=0.9344
# Power(MW): Pt=-0.8546, Pc=-0.8546, Pd=-0.0
# Ctrl: 0=920; 1=144;
# EVA: ts=21.9333[H], 5000 EVs, Total Q=55.45 MWh
# Online 2108, Q=52.58 MWh, SoC=0.9033
# Power(MW): Pt=-2.4591, Pc=-2.4591, Pd=-0.0
# Ctrl: 0=1696; 1=412;
# EVA: ts=22.9167[H], 5000 EVs, Total Q=42.01 MWh
# Online 1634, Q=40.76 MWh, SoC=0.9273
# Power(MW): Pt=-1.413, Pc=-1.413, Pd=-0.0
# Ctrl: 0=1397; 1=237;
# EVA: ts=19.4667[H], 5000 EVs, Total Q=51.57 MWh
# Online 1850, Q=46.19 MWh, SoC=0.824
# Power(MW): Pt=-4.0213, Pc=-4.0213, Pd=-0.0
# Ctrl: 0=1173; 1=677;
# EVA: ts=21.4333[H], 5000 EVs, Total Q=57.83 MWh
# Online 2152, Q=53.75 MWh, SoC=0.8969
# Power(MW): Pt=-2.7436, Pc=-2.7436, Pd=-0.0
# Ctrl: 0=1693; 1=459;
# EVA: ts=23.9167[H], 5000 EVs, Total Q=5.33 MWh
# Online 212, Q=5.31 MWh, SoC=0.9336
# Power(MW): Pt=-0.1636, Pc=-0.1636, Pd=-0.0
# Ctrl: 0=184; 1=28;
# EVA: ts=19.0[H], 5000 EVs, Total Q=49.41 MWh
# Online 1727, Q=43.15 MWh, SoC=0.8058
# Power(MW): Pt=-4.0704, Pc=-4.0704, Pd=-0.0
# Ctrl: 0=1042; 1=685;
# EVA: ts=20.4667[H], 5000 EVs, Total Q=55.9 MWh
# Online 2064, Q=51.51 MWh, SoC=0.8654
# Power(MW): Pt=-3.4452, Pc=-3.4452, Pd=-0.0
# Ctrl: 0=1482; 1=582;
# EVA: ts=22.45[H], 5000 EVs, Total Q=50.09 MWh
# Online 1925, Q=48.0 MWh, SoC=0.9168
# Power(MW): Pt=-1.8029, Pc=-1.8029, Pd=-0.0
# Ctrl: 0=1623; 1=302;
# EVA: ts=19.9667[H], 5000 EVs, Total Q=53.98 MWh
# Online 1970, Q=49.18 MWh, SoC=0.8434
# Power(MW): Pt=-3.7499, Pc=-3.7499, Pd=-0.0
# Ctrl: 0=1336; 1=634;
# EVA: ts=23.45[H], 5000 EVs, Total Q=26.28 MWh
# Online 1043, Q=25.9 MWh, SoC=0.9352
# Power(MW): Pt=-0.8248, Pc=-0.8248, Pd=-0.0
# Ctrl: 0=904; 1=139;
# EVA: ts=20.9667[H], 5000 EVs, Total Q=58.1 MWh
# Online 2151, Q=53.7 MWh, SoC=0.882
# Power(MW): Pt=-3.0835, Pc=-3.0835, Pd=-0.0
# Ctrl: 0=1632; 1=519;
# EVA: ts=21.95[H], 5000 EVs, Total Q=55.32 MWh
# Online 2105, Q=52.5 MWh, SoC=0.9038
# Power(MW): Pt=-2.4459, Pc=-2.4459, Pd=-0.0
# Ctrl: 0=1695; 1=410;
# EVA: ts=22.9333[H], 5000 EVs, Total Q=41.68 MWh
# Online 1621, Q=40.44 MWh, SoC=0.9282
# Power(MW): Pt=-1.3816, Pc=-1.3816, Pd=-0.0
# Ctrl: 0=1389; 1=232;
# EVA: ts=23.9333[H], 5000 EVs, Total Q=4.4 MWh
# Online 176, Q=4.37 MWh, SoC=0.94
# Power(MW): Pt=-0.1273, Pc=-0.1273, Pd=-0.0
# Ctrl: 0=154; 1=22;
# EVA: ts=19.4833[H], 5000 EVs, Total Q=51.62 MWh
# Online 1855, Q=46.32 MWh, SoC=0.8243
# Power(MW): Pt=-4.0181, Pc=-4.0181, Pd=-0.0
# Ctrl: 0=1179; 1=676;
# EVA: ts=21.45[H], 5000 EVs, Total Q=57.75 MWh
# Online 2148, Q=53.65 MWh, SoC=0.8981
# Power(MW): Pt=-2.715, Pc=-2.715, Pd=-0.0
# Ctrl: 0=1693; 1=455;
# EVA: ts=20.4833[H], 5000 EVs, Total Q=55.97 MWh
# Online 2066, Q=51.56 MWh, SoC=0.8663
# Power(MW): Pt=-3.403, Pc=-3.403, Pd=-0.0
# Ctrl: 0=1491; 1=575;
# EVA: ts=22.4667[H], 5000 EVs, Total Q=49.91 MWh
# Online 1919, Q=47.85 MWh, SoC=0.9171
# Power(MW): Pt=-1.7974, Pc=-1.7974, Pd=-0.0
# Ctrl: 0=1618; 1=301;
# EVA: ts=23.4667[H], 5000 EVs, Total Q=25.58 MWh
# Online 1016, Q=25.21 MWh, SoC=0.9352
# Power(MW): Pt=-0.7996, Pc=-0.7996, Pd=-0.0
# Ctrl: 0=881; 1=135;
# EVA: ts=19.9833[H], 5000 EVs, Total Q=54.01 MWh
# Online 1973, Q=49.25 MWh, SoC=0.8443
# Power(MW): Pt=-3.7412, Pc=-3.7412, Pd=-0.0
# Ctrl: 0=1341; 1=632;
# EVA: ts=21.9667[H], 5000 EVs, Total Q=55.23 MWh
# Online 2099, Q=52.36 MWh, SoC=0.905
# Power(MW): Pt=-2.4049, Pc=-2.4049, Pd=-0.0
# Ctrl: 0=1696; 1=403;
# EVA: ts=20.9833[H], 5000 EVs, Total Q=58.07 MWh
# Online 2149, Q=53.65 MWh, SoC=0.8833
# Power(MW): Pt=-3.0471, Pc=-3.0471, Pd=-0.0
# Ctrl: 0=1636; 1=513;
# EVA: ts=22.95[H], 5000 EVs, Total Q=41.34 MWh
# Online 1606, Q=40.07 MWh, SoC=0.9291
# Power(MW): Pt=-1.3534, Pc=-1.3534, Pd=-0.0
# Ctrl: 0=1379; 1=227;
# EVA: ts=23.95[H], 5000 EVs, Total Q=3.35 MWh
# Online 134, Q=3.35 MWh, SoC=0.9251
# Power(MW): Pt=-0.1159, Pc=-0.1159, Pd=-0.0
# Ctrl: 0=114; 1=20;
# EVA: ts=19.5[H], 5000 EVs, Total Q=51.69 MWh
# Online 1858, Q=46.38 MWh, SoC=0.8253
# Power(MW): Pt=-4.0137, Pc=-4.0137, Pd=-0.0
# Ctrl: 0=1183; 1=675;
# EVA: ts=21.4667[H], 5000 EVs, Total Q=57.73 MWh
# Online 2149, Q=53.67 MWh, SoC=0.8983
# Power(MW): Pt=-2.7217, Pc=-2.7217, Pd=-0.0
# Ctrl: 0=1693; 1=456;
# EVA: ts=20.5[H], 5000 EVs, Total Q=56.12 MWh
# Online 2069, Q=51.63 MWh, SoC=0.8671
# Power(MW): Pt=-3.3799, Pc=-3.3799, Pd=-0.0
# Ctrl: 0=1498; 1=571;
# EVA: ts=22.4833[H], 5000 EVs, Total Q=49.69 MWh
# Online 1910, Q=47.64 MWh, SoC=0.9177
# Power(MW): Pt=-1.7788, Pc=-1.7788, Pd=-0.0
# Ctrl: 0=1612; 1=298;
# EVA: ts=23.4833[H], 5000 EVs, Total Q=24.98 MWh
# Online 994, Q=24.64 MWh, SoC=0.9358
# Power(MW): Pt=-0.7876, Pc=-0.7876, Pd=-0.0
# Ctrl: 0=861; 1=133;
# EVA: ts=20.0[H], 5000 EVs, Total Q=54.01 MWh
# Online 1979, Q=49.41 MWh, SoC=0.8442
# Power(MW): Pt=-3.746, Pc=-3.746, Pd=-0.0
# Ctrl: 0=1346; 1=633;
# EVA: ts=22.9667[H], 5000 EVs, Total Q=40.86 MWh
# Online 1590, Q=39.68 MWh, SoC=0.9289
# Power(MW): Pt=-1.3534, Pc=-1.3534, Pd=-0.0
# Ctrl: 0=1363; 1=227;
# EVA: ts=23.9667[H], 5000 EVs, Total Q=2.51 MWh
# Online 100, Q=2.51 MWh, SoC=0.9277
# Power(MW): Pt=-0.0862, Pc=-0.0862, Pd=-0.0
# Ctrl: 0=85; 1=15;
# EVA: ts=21.9833[H], 5000 EVs, Total Q=55.1 MWh
# Online 2096, Q=52.28 MWh, SoC=0.9054
# Power(MW): Pt=-2.38, Pc=-2.38, Pd=-0.0
# Ctrl: 0=1697; 1=399;
# EVA: ts=21.0[H], 5000 EVs, Total Q=58.08 MWh
# Online 2147, Q=53.6 MWh, SoC=0.8848
# Power(MW): Pt=-2.9876, Pc=-2.9876, Pd=-0.0
# Ctrl: 0=1644; 1=503;
# EVA: ts=21.4833[H], 5000 EVs, Total Q=57.76 MWh
# Online 2152, Q=53.75 MWh, SoC=0.8988
# Power(MW): Pt=-2.7164, Pc=-2.7164, Pd=-0.0
# Ctrl: 0=1697; 1=455;
# EVA: ts=22.9833[H], 5000 EVs, Total Q=40.51 MWh
# Online 1576, Q=39.32 MWh, SoC=0.9295
# Power(MW): Pt=-1.3424, Pc=-1.3424, Pd=-0.0
# Ctrl: 0=1351; 1=225;
# EVA: ts=22.5[H], 5000 EVs, Total Q=49.51 MWh
# Online 1905, Q=47.5 MWh, SoC=0.9185
# Power(MW): Pt=-1.7728, Pc=-1.7728, Pd=-0.0
# Ctrl: 0=1608; 1=297;
# EVA: ts=23.5[H], 5000 EVs, Total Q=24.26 MWh
# Online 965, Q=23.91 MWh, SoC=0.9385
# Power(MW): Pt=-0.7411, Pc=-0.7411, Pd=-0.0
# Ctrl: 0=840; 1=125;
# EVA: ts=23.9833[H], 5000 EVs, Total Q=1.17 MWh
# Online 47, Q=1.17 MWh, SoC=0.9208
# Power(MW): Pt=-0.0517, Pc=-0.0517, Pd=-0.0
# Ctrl: 0=38; 1=9;
# EVA: ts=22.0[H], 5000 EVs, Total Q=54.85 MWh
# Online 2087, Q=52.06 MWh, SoC=0.9066
# Power(MW): Pt=-2.3507, Pc=-2.3507, Pd=-0.0
# Ctrl: 0=1693; 1=394;
# EVA: ts=21.5[H], 5000 EVs, Total Q=57.68 MWh
# Online 2153, Q=53.77 MWh, SoC=0.8984
# Power(MW): Pt=-2.7257, Pc=-2.7257, Pd=-0.0
# Ctrl: 0=1697; 1=456;
# EVA: ts=23.0[H], 5000 EVs, Total Q=40.05 MWh
# Online 1559, Q=38.89 MWh, SoC=0.9295
# Power(MW): Pt=-1.3238, Pc=-1.3238, Pd=-0.0
# Ctrl: 0=1337; 1=222;

# %%
plt.style.use('ieee')
frc = pd.DataFrame(np.array(answer), columns=['time', 'frcu', 'frcd', 'ne'])
frc.time *= 60
newdf = pd.DataFrame(np.repeat(frc.iloc[range(0,1440,5)].values, 5, axis=0), columns=frc.columns)
frcn = frc[['frcu', 'frcd']] - newdf[['frcu', 'frcd']]
frcn.plot(x='time', y=['frcu'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/mambaforge/envs/andes/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/mambaforge/envs/andes/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/mambaforge/envs/andes/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [20], in <cell line: 6>()
#       4 newdf = pd.DataFrame(np.repeat(frc.iloc[range(0,1440,5)].values, 5, axis=0), columns=frc.columns)
#       5 frcn = frc[['frcu', 'frcd']] - newdf[['frcu', 'frcd']]
# ----> 6 frcn.plot(x='time', y=['frcu'])
#
# File ~/mambaforge/envs/andes/lib/python3.9/site-packages/pandas/plotting/_core.py:937, in PlotAccessor.__call__(self, *args, **kwargs)
#     935 if is_integer(x) and not data.columns.holds_integer():
#     936     x = data_cols[x]
# --> 937 elif not isinstance(data[x], ABCSeries):
#     938     raise ValueError("x must be a label or position")
#     939 data = data.set_index(x)
#
# File ~/mambaforge/envs/andes/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/mambaforge/envs/andes/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'time'

# %%
frc_data = -1 * np.ones((len(np.arange(1/60, 24, 1/60)), 4))

for i, end_time in enumerate(np.arange(1/60, 24, 1/60)):
    sse1 = ev_ssm(ts=end_time, N=5000, step=1, tp=40,
                  lr=0.1, lp=60, seed=2022, name="EVA")
    frcu, frcd = sse1.g_frc()
    frc_data[i] = [end_time, frcu, frcd, sse1.ne]
# Out:
# EVA: ts=0.0167[H], 5000 EVs, Total Q=32.36 MWh
# Online 24, Q=0.6 MWh, SoC=0.2976
# Power(MW): Pt=-0.1519, Pc=-0.1519, Pd=-0.0
# Ctrl: 1=24;
# EVA: ts=0.0333[H], 5000 EVs, Total Q=32.71 MWh
# Online 49, Q=1.22 MWh, SoC=0.3017
# Power(MW): Pt=-0.3065, Pc=-0.3065, Pd=-0.0
# Ctrl: 1=49;
# EVA: ts=0.05[H], 5000 EVs, Total Q=32.9 MWh
# Online 70, Q=1.74 MWh, SoC=0.3046
# Power(MW): Pt=-0.4386, Pc=-0.4386, Pd=-0.0
# Ctrl: 1=70;
# EVA: ts=0.0667[H], 5000 EVs, Total Q=33.31 MWh
# Online 94, Q=2.35 MWh, SoC=0.3077
# Power(MW): Pt=-0.5816, Pc=-0.5816, Pd=-0.0
# Ctrl: 1=94;
# EVA: ts=0.0833[H], 5000 EVs, Total Q=33.72 MWh
# Online 117, Q=2.93 MWh, SoC=0.3067
# Power(MW): Pt=-0.7199, Pc=-0.7199, Pd=-0.0
# Ctrl: 1=117;
# EVA: ts=0.1[H], 5000 EVs, Total Q=34.21 MWh
# Online 143, Q=3.57 MWh, SoC=0.3079
# Power(MW): Pt=-0.8782, Pc=-0.8782, Pd=-0.0
# Ctrl: 1=143;
# EVA: ts=0.1167[H], 5000 EVs, Total Q=34.48 MWh
# Online 171, Q=4.26 MWh, SoC=0.3114
# Power(MW): Pt=-1.0484, Pc=-1.0484, Pd=-0.0
# Ctrl: 1=171;
# EVA: ts=0.1333[H], 5000 EVs, Total Q=34.78 MWh
# Online 191, Q=4.76 MWh, SoC=0.3147
# Power(MW): Pt=-1.1689, Pc=-1.1689, Pd=-0.0
# Ctrl: 1=191;
# EVA: ts=0.15[H], 5000 EVs, Total Q=35.04 MWh
# Online 225, Q=5.61 MWh, SoC=0.3161
# Power(MW): Pt=-1.3722, Pc=-1.3722, Pd=-0.0
# Ctrl: 1=225;
# EVA: ts=0.1667[H], 5000 EVs, Total Q=35.35 MWh
# Online 256, Q=6.39 MWh, SoC=0.3189
# Power(MW): Pt=-1.5568, Pc=-1.5568, Pd=-0.0
# Ctrl: 1=256;
# EVA: ts=0.1833[H], 5000 EVs, Total Q=35.61 MWh
# Online 289, Q=7.18 MWh, SoC=0.3212
# Power(MW): Pt=-1.7524, Pc=-1.7524, Pd=-0.0
# Ctrl: 1=289;
# EVA: ts=0.2[H], 5000 EVs, Total Q=35.88 MWh
# Online 311, Q=7.73 MWh, SoC=0.3222
# Power(MW): Pt=-1.8858, Pc=-1.8858, Pd=-0.0
# Ctrl: 1=311;
# EVA: ts=0.2167[H], 5000 EVs, Total Q=36.29 MWh
# Online 338, Q=8.39 MWh, SoC=0.3255
# Power(MW): Pt=-2.047, Pc=-2.047, Pd=-0.0
# Ctrl: 1=338;
# EVA: ts=0.2333[H], 5000 EVs, Total Q=36.64 MWh
# Online 367, Q=9.08 MWh, SoC=0.3266
# Power(MW): Pt=-2.222, Pc=-2.222, Pd=-0.0
# Ctrl: 1=367;
# EVA: ts=0.25[H], 5000 EVs, Total Q=37.06 MWh
# Online 397, Q=9.81 MWh, SoC=0.3283
# Power(MW): Pt=-2.3983, Pc=-2.3983, Pd=-0.0
# Ctrl: 1=397;
# EVA: ts=0.2667[H], 5000 EVs, Total Q=37.52 MWh
# Online 419, Q=10.33 MWh, SoC=0.3297
# Power(MW): Pt=-2.5317, Pc=-2.5317, Pd=-0.0
# Ctrl: 1=419;
# EVA: ts=0.2833[H], 5000 EVs, Total Q=37.74 MWh
# Online 444, Q=10.96 MWh, SoC=0.3314
# Power(MW): Pt=-2.6806, Pc=-2.6806, Pd=-0.0
# Ctrl: 1=444;
# EVA: ts=0.3[H], 5000 EVs, Total Q=38.05 MWh
# Online 471, Q=11.64 MWh, SoC=0.3335
# Power(MW): Pt=-2.8405, Pc=-2.8405, Pd=-0.0
# Ctrl: 1=471;
# EVA: ts=0.3167[H], 5000 EVs, Total Q=38.4 MWh
# Online 488, Q=12.06 MWh, SoC=0.3359
# Power(MW): Pt=-2.9473, Pc=-2.9473, Pd=-0.0
# Ctrl: 1=488;
# EVA: ts=0.3333[H], 5000 EVs, Total Q=38.56 MWh
# Online 507, Q=12.53 MWh, SoC=0.3388
# Power(MW): Pt=-3.0664, Pc=-3.0664, Pd=-0.0
# Ctrl: 1=507;
# EVA: ts=0.35[H], 5000 EVs, Total Q=38.79 MWh
# Online 523, Q=12.92 MWh, SoC=0.342
# Power(MW): Pt=-3.1602, Pc=-3.1602, Pd=-0.0
# Ctrl: 1=523;
# EVA: ts=0.3667[H], 5000 EVs, Total Q=39.09 MWh
# Online 545, Q=13.48 MWh, SoC=0.3439
# Power(MW): Pt=-3.2873, Pc=-3.2873, Pd=-0.0
# Ctrl: 1=545;
# EVA: ts=0.3833[H], 5000 EVs, Total Q=39.48 MWh
# Online 566, Q=14.0 MWh, SoC=0.3455
# Power(MW): Pt=-3.4107, Pc=-3.4107, Pd=-0.0
# Ctrl: 1=566;
# EVA: ts=0.4[H], 5000 EVs, Total Q=39.75 MWh
# Online 585, Q=14.47 MWh, SoC=0.3477
# Power(MW): Pt=-3.5269, Pc=-3.5269, Pd=-0.0
# Ctrl: 1=585;
# EVA: ts=0.4167[H], 5000 EVs, Total Q=40.17 MWh
# Online 604, Q=14.95 MWh, SoC=0.3497
# Power(MW): Pt=-3.6401, Pc=-3.6401, Pd=-0.0
# Ctrl: 1=604;
# EVA: ts=0.4333[H], 5000 EVs, Total Q=40.62 MWh
# Online 626, Q=15.49 MWh, SoC=0.3517
# Power(MW): Pt=-3.7719, Pc=-3.7719, Pd=-0.0
# Ctrl: 1=626;
# EVA: ts=0.45[H], 5000 EVs, Total Q=40.93 MWh
# Online 650, Q=16.1 MWh, SoC=0.3527
# Power(MW): Pt=-3.9155, Pc=-3.9155, Pd=-0.0
# Ctrl: 1=650;
# EVA: ts=0.4667[H], 5000 EVs, Total Q=41.16 MWh
# Online 667, Q=16.51 MWh, SoC=0.3549
# Power(MW): Pt=-4.0146, Pc=-4.0146, Pd=-0.0
# Ctrl: 1=667;
# EVA: ts=0.4833[H], 5000 EVs, Total Q=41.48 MWh
# Online 688, Q=17.03 MWh, SoC=0.3563
# Power(MW): Pt=-4.1418, Pc=-4.1418, Pd=-0.0
# Ctrl: 1=688;
# EVA: ts=0.5[H], 5000 EVs, Total Q=41.72 MWh
# Online 708, Q=17.54 MWh, SoC=0.358
# Power(MW): Pt=-4.2632, Pc=-4.2632, Pd=-0.0
# Ctrl: 1=708;
# EVA: ts=0.5167[H], 5000 EVs, Total Q=42.04 MWh
# Online 735, Q=18.21 MWh, SoC=0.3597
# Power(MW): Pt=-4.4204, Pc=-4.4204, Pd=-0.0
# Ctrl: 1=735;
# EVA: ts=0.5333[H], 5000 EVs, Total Q=42.14 MWh
# Online 757, Q=18.77 MWh, SoC=0.3618
# Power(MW): Pt=-4.5518, Pc=-4.5518, Pd=-0.0
# Ctrl: 1=757;
# EVA: ts=0.55[H], 5000 EVs, Total Q=42.38 MWh
# Online 780, Q=19.35 MWh, SoC=0.3634
# Power(MW): Pt=-4.6859, Pc=-4.6859, Pd=-0.0
# Ctrl: 1=780;
# EVA: ts=0.5667[H], 5000 EVs, Total Q=42.45 MWh
# Online 805, Q=19.98 MWh, SoC=0.3651
# Power(MW): Pt=-4.8353, Pc=-4.8353, Pd=-0.0
# Ctrl: 1=805;
# EVA: ts=0.5833[H], 5000 EVs, Total Q=42.68 MWh
# Online 822, Q=20.42 MWh, SoC=0.367
# Power(MW): Pt=-4.9367, Pc=-4.9367, Pd=-0.0
# Ctrl: 1=822;
# EVA: ts=0.6[H], 5000 EVs, Total Q=42.87 MWh
# Online 834, Q=20.7 MWh, SoC=0.37
# Power(MW): Pt=-5.0077, Pc=-5.0077, Pd=-0.0
# Ctrl: 1=834;
# EVA: ts=0.6167[H], 5000 EVs, Total Q=43.2 MWh
# Online 853, Q=21.2 MWh, SoC=0.3722
# Power(MW): Pt=-5.1238, Pc=-5.1238, Pd=-0.0
# Ctrl: 1=853;
# EVA: ts=0.6333[H], 5000 EVs, Total Q=43.52 MWh
# Online 883, Q=21.97 MWh, SoC=0.3739
# Power(MW): Pt=-5.3057, Pc=-5.3057, Pd=-0.0
# Ctrl: 1=883;
# EVA: ts=0.65[H], 5000 EVs, Total Q=43.87 MWh
# Online 902, Q=22.45 MWh, SoC=0.376
# Power(MW): Pt=-5.4226, Pc=-5.4226, Pd=-0.0
# Ctrl: 1=902;
# EVA: ts=0.6667[H], 5000 EVs, Total Q=44.12 MWh
# Online 919, Q=22.87 MWh, SoC=0.3784
# Power(MW): Pt=-5.5284, Pc=-5.5284, Pd=-0.0
# Ctrl: 1=919;
# EVA: ts=0.6833[H], 5000 EVs, Total Q=44.39 MWh
# Online 938, Q=23.37 MWh, SoC=0.3803
# Power(MW): Pt=-5.6414, Pc=-5.6414, Pd=-0.0
# Ctrl: 1=938;
# EVA: ts=0.7[H], 5000 EVs, Total Q=44.52 MWh
# Online 955, Q=23.82 MWh, SoC=0.3826
# Power(MW): Pt=-5.7397, Pc=-5.7397, Pd=-0.0
# Ctrl: 1=955;
# EVA: ts=0.7167[H], 5000 EVs, Total Q=44.78 MWh
# Online 973, Q=24.25 MWh, SoC=0.3849
# Power(MW): Pt=-5.8495, Pc=-5.8495, Pd=-0.0
# Ctrl: 1=973;
# EVA: ts=0.7333[H], 5000 EVs, Total Q=45.1 MWh
# Online 987, Q=24.62 MWh, SoC=0.3875
# Power(MW): Pt=-5.9316, Pc=-5.9316, Pd=-0.0
# Ctrl: 1=987;
# EVA: ts=0.75[H], 5000 EVs, Total Q=45.35 MWh
# Online 1009, Q=25.18 MWh, SoC=0.389
# Power(MW): Pt=-6.0618, Pc=-6.0618, Pd=-0.0
# Ctrl: 1=1009;
# EVA: ts=0.7667[H], 5000 EVs, Total Q=45.46 MWh
# Online 1028, Q=25.66 MWh, SoC=0.3908
# Power(MW): Pt=-6.1822, Pc=-6.1822, Pd=-0.0
# Ctrl: 1=1028;
# EVA: ts=0.7833[H], 5000 EVs, Total Q=45.56 MWh
# Online 1040, Q=25.97 MWh, SoC=0.3932
# Power(MW): Pt=-6.2553, Pc=-6.2553, Pd=-0.0
# Ctrl: 1=1040;
# EVA: ts=0.8[H], 5000 EVs, Total Q=45.76 MWh
# Online 1058, Q=26.43 MWh, SoC=0.3956
# Power(MW): Pt=-6.3637, Pc=-6.3637, Pd=-0.0
# Ctrl: 1=1058;
# EVA: ts=0.8167[H], 5000 EVs, Total Q=45.95 MWh
# Online 1078, Q=26.94 MWh, SoC=0.3974
# Power(MW): Pt=-6.4856, Pc=-6.4856, Pd=-0.0
# Ctrl: 1=1078;
# EVA: ts=0.8333[H], 5000 EVs, Total Q=46.22 MWh
# Online 1103, Q=27.59 MWh, SoC=0.3992
# Power(MW): Pt=-6.6359, Pc=-6.6359, Pd=-0.0
# Ctrl: 1=1103;
# EVA: ts=0.85[H], 5000 EVs, Total Q=46.45 MWh
# Online 1120, Q=28.04 MWh, SoC=0.4012
# Power(MW): Pt=-6.7337, Pc=-6.7337, Pd=-0.0
# Ctrl: 1=1120;
# EVA: ts=0.8667[H], 5000 EVs, Total Q=46.71 MWh
# Online 1137, Q=28.44 MWh, SoC=0.4035
# Power(MW): Pt=-6.8375, Pc=-6.8375, Pd=-0.0
# Ctrl: 1=1137;
# EVA: ts=0.8833[H], 5000 EVs, Total Q=46.89 MWh
# Online 1154, Q=28.87 MWh, SoC=0.4056
# Power(MW): Pt=-6.9369, Pc=-6.9369, Pd=-0.0
# Ctrl: 1=1154;
# EVA: ts=0.9[H], 5000 EVs, Total Q=47.1 MWh
# Online 1173, Q=29.33 MWh, SoC=0.4077
# Power(MW): Pt=-7.047, Pc=-7.047, Pd=-0.0
# Ctrl: 1=1173;
# EVA: ts=0.9167[H], 5000 EVs, Total Q=47.34 MWh
# Online 1187, Q=29.69 MWh, SoC=0.4101
# Power(MW): Pt=-7.1296, Pc=-7.1296, Pd=-0.0
# Ctrl: 1=1187;
# EVA: ts=0.9333[H], 5000 EVs, Total Q=47.44 MWh
# Online 1200, Q=30.02 MWh, SoC=0.4127
# Power(MW): Pt=-7.2132, Pc=-7.2132, Pd=-0.0
# Ctrl: 1=1200;
# EVA: ts=0.95[H], 5000 EVs, Total Q=47.66 MWh
# Online 1214, Q=30.38 MWh, SoC=0.415
# Power(MW): Pt=-7.2977, Pc=-7.2977, Pd=-0.0
# Ctrl: 1=1214;
# EVA: ts=0.9667[H], 5000 EVs, Total Q=47.82 MWh
# Online 1228, Q=30.73 MWh, SoC=0.4173
# Power(MW): Pt=-7.3814, Pc=-7.3814, Pd=-0.0
# Ctrl: 1=1228;
# EVA: ts=0.9833[H], 5000 EVs, Total Q=48.07 MWh
# Online 1241, Q=31.06 MWh, SoC=0.4195
# Power(MW): Pt=-7.4598, Pc=-7.4598, Pd=-0.0
# Ctrl: 1=1241;
# EVA: ts=1.0[H], 5000 EVs, Total Q=48.35 MWh
# Online 1262, Q=31.58 MWh, SoC=0.4213
# Power(MW): Pt=-7.5822, Pc=-7.5822, Pd=-0.0
# Ctrl: 1=1262;
# EVA: ts=1.0167[H], 5000 EVs, Total Q=48.52 MWh
# Online 1283, Q=32.12 MWh, SoC=0.4228
# Power(MW): Pt=-7.7056, Pc=-7.7056, Pd=-0.0
# Ctrl: 1=1283;
# EVA: ts=1.0333[H], 5000 EVs, Total Q=48.83 MWh
# Online 1297, Q=32.47 MWh, SoC=0.4249
# Power(MW): Pt=-7.7897, Pc=-7.7897, Pd=-0.0
# Ctrl: 1=1297;
# EVA: ts=1.05[H], 5000 EVs, Total Q=49.01 MWh
# Online 1304, Q=32.66 MWh, SoC=0.4277
# Power(MW): Pt=-7.832, Pc=-7.832, Pd=-0.0
# Ctrl: 1=1304;
# EVA: ts=1.0667[H], 5000 EVs, Total Q=49.15 MWh
# Online 1320, Q=33.07 MWh, SoC=0.43
# Power(MW): Pt=-7.9284, Pc=-7.9284, Pd=-0.0
# Ctrl: 1=1320;
# EVA: ts=1.0833[H], 5000 EVs, Total Q=49.36 MWh
# Online 1335, Q=33.46 MWh, SoC=0.4321
# Power(MW): Pt=-8.0234, Pc=-8.0234, Pd=-0.0
# Ctrl: 1=1335;
# EVA: ts=1.1[H], 5000 EVs, Total Q=49.44 MWh
# Online 1356, Q=33.95 MWh, SoC=0.4339
# Power(MW): Pt=-8.1519, Pc=-8.1519, Pd=-0.0
# Ctrl: 1=1356;
# EVA: ts=1.1167[H], 5000 EVs, Total Q=49.67 MWh
# Online 1366, Q=34.22 MWh, SoC=0.4366
# Power(MW): Pt=-8.2074, Pc=-8.2074, Pd=-0.0
# Ctrl: 1=1366;
# EVA: ts=1.1333[H], 5000 EVs, Total Q=49.88 MWh
# Online 1377, Q=34.5 MWh, SoC=0.4392
# Power(MW): Pt=-8.2738, Pc=-8.2738, Pd=-0.0
# Ctrl: 1=1377;
# EVA: ts=1.15[H], 5000 EVs, Total Q=50.1 MWh
# Online 1388, Q=34.76 MWh, SoC=0.4418
# Power(MW): Pt=-8.3425, Pc=-8.3425, Pd=-0.0
# Ctrl: 1=1388;
# EVA: ts=1.1667[H], 5000 EVs, Total Q=50.33 MWh
# Online 1400, Q=35.07 MWh, SoC=0.4441
# Power(MW): Pt=-8.4145, Pc=-8.4145, Pd=-0.0
# Ctrl: 1=1400;
# EVA: ts=1.1833[H], 5000 EVs, Total Q=50.51 MWh
# Online 1409, Q=35.3 MWh, SoC=0.4468
# Power(MW): Pt=-8.4688, Pc=-8.4688, Pd=-0.0
# Ctrl: 1=1409;
# EVA: ts=1.2[H], 5000 EVs, Total Q=50.72 MWh
# Online 1420, Q=35.57 MWh, SoC=0.4494
# Power(MW): Pt=-8.5365, Pc=-8.5365, Pd=-0.0
# Ctrl: 1=1420;
# EVA: ts=1.2167[H], 5000 EVs, Total Q=50.99 MWh
# Online 1437, Q=36.01 MWh, SoC=0.451
# Power(MW): Pt=-8.6344, Pc=-8.6344, Pd=-0.0
# Ctrl: 1=1437;
# EVA: ts=1.2333[H], 5000 EVs, Total Q=51.19 MWh
# Online 1451, Q=36.36 MWh, SoC=0.4531
# Power(MW): Pt=-8.72, Pc=-8.72, Pd=-0.0
# Ctrl: 1=1451;
# EVA: ts=1.25[H], 5000 EVs, Total Q=51.4 MWh
# Online 1467, Q=36.75 MWh, SoC=0.4549
# Power(MW): Pt=-8.8184, Pc=-8.8184, Pd=-0.0
# Ctrl: 1=1467;
# EVA: ts=1.2667[H], 5000 EVs, Total Q=51.52 MWh
# Online 1485, Q=37.19 MWh, SoC=0.4568
# Power(MW): Pt=-8.9299, Pc=-8.9299, Pd=-0.0
# Ctrl: 1=1485;
# EVA: ts=1.2833[H], 5000 EVs, Total Q=51.7 MWh
# Online 1494, Q=37.41 MWh, SoC=0.4595
# Power(MW): Pt=-8.982, Pc=-8.982, Pd=-0.0
# Ctrl: 1=1494;
# EVA: ts=1.3[H], 5000 EVs, Total Q=51.89 MWh
# Online 1506, Q=37.7 MWh, SoC=0.4621
# Power(MW): Pt=-9.051, Pc=-9.051, Pd=-0.0
# Ctrl: 1=1506;
# EVA: ts=1.3167[H], 5000 EVs, Total Q=52.02 MWh
# Online 1519, Q=38.02 MWh, SoC=0.4643
# Power(MW): Pt=-9.1256, Pc=-9.1256, Pd=-0.0
# Ctrl: 1=1519;
# EVA: ts=1.3333[H], 5000 EVs, Total Q=52.15 MWh
# Online 1526, Q=38.2 MWh, SoC=0.4672
# Power(MW): Pt=-9.1695, Pc=-9.1695, Pd=-0.0
# Ctrl: 1=1526;
# EVA: ts=1.35[H], 5000 EVs, Total Q=52.3 MWh
# Online 1535, Q=38.43 MWh, SoC=0.4699
# Power(MW): Pt=-9.2222, Pc=-9.2222, Pd=-0.0
# Ctrl: 1=1535;
# EVA: ts=1.3667[H], 5000 EVs, Total Q=52.42 MWh
# Online 1547, Q=38.73 MWh, SoC=0.4722
# Power(MW): Pt=-9.2944, Pc=-9.2944, Pd=-0.0
# Ctrl: 1=1547;
# EVA: ts=1.3833[H], 5000 EVs, Total Q=52.52 MWh
# Online 1562, Q=39.1 MWh, SoC=0.4742
# Power(MW): Pt=-9.3834, Pc=-9.3834, Pd=-0.0
# Ctrl: 1=1562;
# EVA: ts=1.4[H], 5000 EVs, Total Q=52.65 MWh
# Online 1573, Q=39.36 MWh, SoC=0.4765
# Power(MW): Pt=-9.4491, Pc=-9.4491, Pd=-0.0
# Ctrl: 1=1573;
# EVA: ts=1.4167[H], 5000 EVs, Total Q=52.75 MWh
# Online 1590, Q=39.79 MWh, SoC=0.4782
# Power(MW): Pt=-9.5512, Pc=-9.5512, Pd=-0.0
# Ctrl: 1=1590;
# EVA: ts=1.4333[H], 5000 EVs, Total Q=52.89 MWh
# Online 1607, Q=40.21 MWh, SoC=0.4801
# Power(MW): Pt=-9.6342, Pc=-9.6342, Pd=-0.0
# Ctrl: 1=1604; 0=3;
# EVA: ts=1.45[H], 5000 EVs, Total Q=53.1 MWh
# Online 1620, Q=40.52 MWh, SoC=0.4827
# Power(MW): Pt=-9.7089, Pc=-9.7089, Pd=-0.0
# Ctrl: 1=1616; 0=4;
# EVA: ts=1.4667[H], 5000 EVs, Total Q=53.28 MWh
# Online 1628, Q=40.73 MWh, SoC=0.4852
# Power(MW): Pt=-9.7564, Pc=-9.7564, Pd=-0.0
# Ctrl: 1=1624; 0=4;
# EVA: ts=1.4833[H], 5000 EVs, Total Q=53.47 MWh
# Online 1641, Q=41.05 MWh, SoC=0.4875
# Power(MW): Pt=-9.8362, Pc=-9.8362, Pd=-0.0
# Ctrl: 1=1637; 0=4;
# EVA: ts=1.5[H], 5000 EVs, Total Q=53.56 MWh
# Online 1650, Q=41.29 MWh, SoC=0.4901
# Power(MW): Pt=-9.8916, Pc=-9.8916, Pd=-0.0
# Ctrl: 1=1646; 0=4;
# EVA: ts=1.5167[H], 5000 EVs, Total Q=53.72 MWh
# Online 1663, Q=41.61 MWh, SoC=0.4922
# Power(MW): Pt=-9.9681, Pc=-9.9681, Pd=-0.0
# Ctrl: 1=1659; 0=4;
# EVA: ts=1.5333[H], 5000 EVs, Total Q=53.76 MWh
# Online 1666, Q=41.68 MWh, SoC=0.4954
# Power(MW): Pt=-9.9864, Pc=-9.9864, Pd=-0.0
# Ctrl: 1=1662; 0=4;
# EVA: ts=1.55[H], 5000 EVs, Total Q=53.82 MWh
# Online 1674, Q=41.89 MWh, SoC=0.498
# Power(MW): Pt=-10.032, Pc=-10.032, Pd=-0.0
# Ctrl: 1=1670; 0=4;
# EVA: ts=1.5667[H], 5000 EVs, Total Q=53.96 MWh
# Online 1676, Q=41.95 MWh, SoC=0.5013
# Power(MW): Pt=-10.0459, Pc=-10.0459, Pd=-0.0
# Ctrl: 1=1672; 0=4;
# EVA: ts=1.5833[H], 5000 EVs, Total Q=54.11 MWh
# Online 1686, Q=42.2 MWh, SoC=0.5038
# Power(MW): Pt=-10.0994, Pc=-10.0994, Pd=-0.0
# Ctrl: 1=1681; 0=5;
# EVA: ts=1.6[H], 5000 EVs, Total Q=54.27 MWh
# Online 1692, Q=42.33 MWh, SoC=0.5067
# Power(MW): Pt=-10.1319, Pc=-10.1319, Pd=-0.0
# Ctrl: 1=1687; 0=5;
# EVA: ts=1.6167[H], 5000 EVs, Total Q=54.34 MWh
# Online 1706, Q=42.67 MWh, SoC=0.5086
# Power(MW): Pt=-10.2052, Pc=-10.2052, Pd=-0.0
# Ctrl: 1=1700; 0=6;
# EVA: ts=1.6333[H], 5000 EVs, Total Q=54.45 MWh
# Online 1718, Q=42.98 MWh, SoC=0.5107
# Power(MW): Pt=-10.265, Pc=-10.265, Pd=-0.0
# Ctrl: 1=1710; 0=8;
# EVA: ts=1.65[H], 5000 EVs, Total Q=54.55 MWh
# Online 1732, Q=43.31 MWh, SoC=0.5124
# Power(MW): Pt=-10.3506, Pc=-10.3506, Pd=-0.0
# Ctrl: 1=1724; 0=8;
# EVA: ts=1.6667[H], 5000 EVs, Total Q=54.68 MWh
# Online 1743, Q=43.58 MWh, SoC=0.5148
# Power(MW): Pt=-10.4058, Pc=-10.4058, Pd=-0.0
# Ctrl: 1=1733; 0=10;
# EVA: ts=1.6833[H], 5000 EVs, Total Q=54.8 MWh
# Online 1754, Q=43.85 MWh, SoC=0.5172
# Power(MW): Pt=-10.4508, Pc=-10.4508, Pd=-0.0
# Ctrl: 1=1741; 0=13;
# EVA: ts=1.7[H], 5000 EVs, Total Q=54.9 MWh
# Online 1759, Q=43.98 MWh, SoC=0.5202
# Power(MW): Pt=-10.4627, Pc=-10.4627, Pd=-0.0
# Ctrl: 1=1743; 0=16;
# EVA: ts=1.7167[H], 5000 EVs, Total Q=54.98 MWh
# Online 1769, Q=44.24 MWh, SoC=0.5226
# Power(MW): Pt=-10.5085, Pc=-10.5085, Pd=-0.0
# Ctrl: 1=1751; 0=18;
# EVA: ts=1.7333[H], 5000 EVs, Total Q=55.07 MWh
# Online 1782, Q=44.56 MWh, SoC=0.5247
# Power(MW): Pt=-10.5731, Pc=-10.5731, Pd=-0.0
# Ctrl: 1=1762; 0=20;
# EVA: ts=1.75[H], 5000 EVs, Total Q=55.2 MWh
# Online 1792, Q=44.81 MWh, SoC=0.5271
# Power(MW): Pt=-10.6027, Pc=-10.6027, Pd=-0.0
# Ctrl: 1=1767; 0=25;
# EVA: ts=1.7667[H], 5000 EVs, Total Q=55.3 MWh
# Online 1797, Q=44.93 MWh, SoC=0.5302
# Power(MW): Pt=-10.6083, Pc=-10.6083, Pd=-0.0
# Ctrl: 1=1768; 0=29;
# EVA: ts=1.7833[H], 5000 EVs, Total Q=55.36 MWh
# Online 1802, Q=45.05 MWh, SoC=0.5332
# Power(MW): Pt=-10.6124, Pc=-10.6124, Pd=-0.0
# Ctrl: 1=1769; 0=33;
# EVA: ts=1.8[H], 5000 EVs, Total Q=55.58 MWh
# Online 1810, Q=45.24 MWh, SoC=0.5359
# Power(MW): Pt=-10.654, Pc=-10.654, Pd=-0.0
# Ctrl: 1=1776; 0=34;
# EVA: ts=1.8167[H], 5000 EVs, Total Q=55.66 MWh
# Online 1818, Q=45.44 MWh, SoC=0.5386
# Power(MW): Pt=-10.6618, Pc=-10.6618, Pd=-0.0
# Ctrl: 1=1778; 0=40;
# EVA: ts=1.8333[H], 5000 EVs, Total Q=55.71 MWh
# Online 1829, Q=45.71 MWh, SoC=0.5408
# Power(MW): Pt=-10.7064, Pc=-10.7064, Pd=-0.0
# Ctrl: 1=1786; 0=43;
# EVA: ts=1.85[H], 5000 EVs, Total Q=55.73 MWh
# Online 1837, Q=45.91 MWh, SoC=0.5431
# Power(MW): Pt=-10.7118, Pc=-10.7118, Pd=-0.0
# Ctrl: 1=1788; 0=49;
# EVA: ts=1.8667[H], 5000 EVs, Total Q=55.83 MWh
# Online 1847, Q=46.15 MWh, SoC=0.5456
# Power(MW): Pt=-10.7533, Pc=-10.7533, Pd=-0.0
# Ctrl: 1=1795; 0=52;
# EVA: ts=1.8833[H], 5000 EVs, Total Q=55.83 MWh
# Online 1853, Q=46.3 MWh, SoC=0.5483
# Power(MW): Pt=-10.7719, Pc=-10.7719, Pd=-0.0
# Ctrl: 1=1799; 0=54;
# EVA: ts=1.9[H], 5000 EVs, Total Q=56.02 MWh
# Online 1863, Q=46.54 MWh, SoC=0.5507
# Power(MW): Pt=-10.7885, Pc=-10.7885, Pd=-0.0
# Ctrl: 1=1802; 0=61;
# EVA: ts=1.9167[H], 5000 EVs, Total Q=56.11 MWh
# Online 1873, Q=46.78 MWh, SoC=0.553
# Power(MW): Pt=-10.8151, Pc=-10.8151, Pd=-0.0
# Ctrl: 1=1807; 0=66;
# EVA: ts=1.9333[H], 5000 EVs, Total Q=56.21 MWh
# Online 1878, Q=46.9 MWh, SoC=0.556
# Power(MW): Pt=-10.8073, Pc=-10.8073, Pd=-0.0
# Ctrl: 1=1806; 0=72;
# EVA: ts=1.95[H], 5000 EVs, Total Q=56.23 MWh
# Online 1885, Q=47.08 MWh, SoC=0.5584
# Power(MW): Pt=-10.8164, Pc=-10.8164, Pd=-0.0
# Ctrl: 1=1808; 0=77;
# EVA: ts=1.9667[H], 5000 EVs, Total Q=56.4 MWh
# Online 1891, Q=47.23 MWh, SoC=0.5612
# Power(MW): Pt=-10.8158, Pc=-10.8158, Pd=-0.0
# Ctrl: 1=1808; 0=83;
# EVA: ts=1.9833[H], 5000 EVs, Total Q=56.54 MWh
# Online 1900, Q=47.46 MWh, SoC=0.5636
# Power(MW): Pt=-10.8441, Pc=-10.8441, Pd=-0.0
# Ctrl: 1=1813; 0=87;
# EVA: ts=2.0[H], 5000 EVs, Total Q=56.56 MWh
# Online 1911, Q=47.73 MWh, SoC=0.5656
# Power(MW): Pt=-10.8832, Pc=-10.8832, Pd=-0.0
# Ctrl: 1=1820; 0=91;
# EVA: ts=2.0167[H], 5000 EVs, Total Q=56.6 MWh
# Online 1915, Q=47.82 MWh, SoC=0.5684
# Power(MW): Pt=-10.8822, Pc=-10.8822, Pd=-0.0
# Ctrl: 1=1820; 0=95;
# EVA: ts=2.0333[H], 5000 EVs, Total Q=56.6 MWh
# Online 1927, Q=48.13 MWh, SoC=0.5704
# Power(MW): Pt=-10.9328, Pc=-10.9328, Pd=-0.0
# Ctrl: 1=1829; 0=98;
# EVA: ts=2.05[H], 5000 EVs, Total Q=56.66 MWh
# Online 1933, Q=48.28 MWh, SoC=0.5731
# Power(MW): Pt=-10.9092, Pc=-10.9092, Pd=-0.0
# Ctrl: 1=1826; 0=107;
# EVA: ts=2.0667[H], 5000 EVs, Total Q=56.64 MWh
# Online 1938, Q=48.4 MWh, SoC=0.576
# Power(MW): Pt=-10.8793, Pc=-10.8793, Pd=-0.0
# Ctrl: 1=1822; 0=116;
# EVA: ts=2.0833[H], 5000 EVs, Total Q=56.71 MWh
# Online 1946, Q=48.6 MWh, SoC=0.5782
# Power(MW): Pt=-10.8472, Pc=-10.8472, Pd=-0.0
# Ctrl: 1=1818; 0=128;
# EVA: ts=2.1[H], 5000 EVs, Total Q=56.76 MWh
# Online 1948, Q=48.66 MWh, SoC=0.5814
# Power(MW): Pt=-10.8271, Pc=-10.8271, Pd=-0.0
# Ctrl: 1=1815; 0=133;
# EVA: ts=2.1167[H], 5000 EVs, Total Q=56.79 MWh
# Online 1955, Q=48.85 MWh, SoC=0.5835
# Power(MW): Pt=-10.807, Pc=-10.807, Pd=-0.0
# Ctrl: 1=1812; 0=143;
# EVA: ts=2.1333[H], 5000 EVs, Total Q=56.83 MWh
# Online 1962, Q=49.02 MWh, SoC=0.5858
# Power(MW): Pt=-10.7925, Pc=-10.7925, Pd=-0.0
# Ctrl: 1=1810; 0=152;
# EVA: ts=2.15[H], 5000 EVs, Total Q=56.87 MWh
# Online 1970, Q=49.22 MWh, SoC=0.5881
# Power(MW): Pt=-10.7857, Pc=-10.7857, Pd=-0.0
# Ctrl: 1=1809; 0=161;
# EVA: ts=2.1667[H], 5000 EVs, Total Q=57.0 MWh
# Online 1979, Q=49.45 MWh, SoC=0.5905
# Power(MW): Pt=-10.7877, Pc=-10.7877, Pd=-0.0
# Ctrl: 1=1810; 0=169;
# EVA: ts=2.1833[H], 5000 EVs, Total Q=57.17 MWh
# Online 1986, Q=49.63 MWh, SoC=0.593
# Power(MW): Pt=-10.7527, Pc=-10.7527, Pd=-0.0
# Ctrl: 1=1805; 0=181;
# EVA: ts=2.2[H], 5000 EVs, Total Q=57.25 MWh
# Online 1995, Q=49.84 MWh, SoC=0.5953
# Power(MW): Pt=-10.7485, Pc=-10.7485, Pd=-0.0
# Ctrl: 1=1805; 0=190;
# EVA: ts=2.2167[H], 5000 EVs, Total Q=57.36 MWh
# Online 2005, Q=50.08 MWh, SoC=0.5973
# Power(MW): Pt=-10.736, Pc=-10.736, Pd=-0.0
# Ctrl: 1=1803; 0=202;
# EVA: ts=2.2333[H], 5000 EVs, Total Q=57.5 MWh
# Online 2012, Q=50.26 MWh, SoC=0.5997
# Power(MW): Pt=-10.745, Pc=-10.745, Pd=-0.0
# Ctrl: 1=1804; 0=208;
# EVA: ts=2.25[H], 5000 EVs, Total Q=57.61 MWh
# Online 2021, Q=50.49 MWh, SoC=0.602
# Power(MW): Pt=-10.7424, Pc=-10.7424, Pd=-0.0
# Ctrl: 1=1804; 0=217;
# EVA: ts=2.2667[H], 5000 EVs, Total Q=57.64 MWh
# Online 2027, Q=50.64 MWh, SoC=0.6048
# Power(MW): Pt=-10.7335, Pc=-10.7335, Pd=-0.0
# Ctrl: 1=1803; 0=224;
# EVA: ts=2.2833[H], 5000 EVs, Total Q=57.66 MWh
# Online 2033, Q=50.79 MWh, SoC=0.6074
# Power(MW): Pt=-10.6964, Pc=-10.6964, Pd=-0.0
# Ctrl: 1=1797; 0=236;
# EVA: ts=2.3[H], 5000 EVs, Total Q=57.71 MWh
# Online 2040, Q=50.98 MWh, SoC=0.6099
# Power(MW): Pt=-10.6292, Pc=-10.6292, Pd=-0.0
# Ctrl: 1=1787; 0=253;
# EVA: ts=2.3167[H], 5000 EVs, Total Q=57.71 MWh
# Online 2045, Q=51.09 MWh, SoC=0.6125
# Power(MW): Pt=-10.5666, Pc=-10.5666, Pd=-0.0
# Ctrl: 1=1777; 0=268;
# EVA: ts=2.3333[H], 5000 EVs, Total Q=57.76 MWh
# Online 2050, Q=51.22 MWh, SoC=0.6154
# Power(MW): Pt=-10.5469, Pc=-10.5469, Pd=-0.0
# Ctrl: 1=1774; 0=276;
# EVA: ts=2.35[H], 5000 EVs, Total Q=57.77 MWh
# Online 2055, Q=51.35 MWh, SoC=0.6181
# Power(MW): Pt=-10.5204, Pc=-10.5204, Pd=-0.0
# Ctrl: 1=1770; 0=285;
# EVA: ts=2.3667[H], 5000 EVs, Total Q=57.79 MWh
# Online 2058, Q=51.42 MWh, SoC=0.6208
# Power(MW): Pt=-10.4622, Pc=-10.4622, Pd=-0.0
# Ctrl: 1=1761; 0=297;
# EVA: ts=2.3833[H], 5000 EVs, Total Q=57.83 MWh
# Online 2063, Q=51.54 MWh, SoC=0.6237
# Power(MW): Pt=-10.4146, Pc=-10.4146, Pd=-0.0
# Ctrl: 1=1752; 0=311;
# EVA: ts=2.4[H], 5000 EVs, Total Q=57.86 MWh
# Online 2069, Q=51.68 MWh, SoC=0.6265
# Power(MW): Pt=-10.3524, Pc=-10.3524, Pd=-0.0
# Ctrl: 1=1742; 0=327;
# EVA: ts=2.4167[H], 5000 EVs, Total Q=57.89 MWh
# Online 2073, Q=51.78 MWh, SoC=0.6295
# Power(MW): Pt=-10.2534, Pc=-10.2534, Pd=-0.0
# Ctrl: 1=1726; 0=347;
# EVA: ts=2.4333[H], 5000 EVs, Total Q=57.86 MWh
# Online 2079, Q=51.92 MWh, SoC=0.632
# Power(MW): Pt=-10.216, Pc=-10.216, Pd=-0.0
# Ctrl: 1=1720; 0=359;
# EVA: ts=2.45[H], 5000 EVs, Total Q=57.97 MWh
# Online 2087, Q=52.1 MWh, SoC=0.6343
# Power(MW): Pt=-10.2153, Pc=-10.2153, Pd=-0.0
# Ctrl: 1=1720; 0=367;
# EVA: ts=2.4667[H], 5000 EVs, Total Q=58.04 MWh
# Online 2095, Q=52.31 MWh, SoC=0.6366
# Power(MW): Pt=-10.1757, Pc=-10.1757, Pd=-0.0
# Ctrl: 1=1714; 0=381;
# EVA: ts=2.4833[H], 5000 EVs, Total Q=58.09 MWh
# Online 2101, Q=52.47 MWh, SoC=0.6392
# Power(MW): Pt=-10.1075, Pc=-10.1075, Pd=-0.0
# Ctrl: 1=1702; 0=399;
# EVA: ts=2.5[H], 5000 EVs, Total Q=58.16 MWh
# Online 2105, Q=52.57 MWh, SoC=0.6421
# Power(MW): Pt=-10.0277, Pc=-10.0277, Pd=-0.0
# Ctrl: 1=1689; 0=416;
# EVA: ts=2.5167[H], 5000 EVs, Total Q=58.24 MWh
# Online 2111, Q=52.72 MWh, SoC=0.6447
# Power(MW): Pt=-9.9267, Pc=-9.9267, Pd=-0.0
# Ctrl: 1=1673; 0=438;
# EVA: ts=2.5333[H], 5000 EVs, Total Q=58.26 MWh
# Online 2114, Q=52.79 MWh, SoC=0.6479
# Power(MW): Pt=-9.8486, Pc=-9.8486, Pd=-0.0
# Ctrl: 1=1661; 0=453;
# EVA: ts=2.55[H], 5000 EVs, Total Q=58.32 MWh
# Online 2117, Q=52.86 MWh, SoC=0.651
# Power(MW): Pt=-9.7891, Pc=-9.7891, Pd=-0.0
# Ctrl: 1=1651; 0=466;
# EVA: ts=2.5667[H], 5000 EVs, Total Q=58.34 MWh
# Online 2121, Q=52.97 MWh, SoC=0.6535
# Power(MW): Pt=-9.7, Pc=-9.7, Pd=-0.0
# Ctrl: 1=1637; 0=484;
# EVA: ts=2.5833[H], 5000 EVs, Total Q=58.37 MWh
# Online 2127, Q=53.12 MWh, SoC=0.6561
# Power(MW): Pt=-9.6182, Pc=-9.6182, Pd=-0.0
# Ctrl: 1=1624; 0=503;
# EVA: ts=2.6[H], 5000 EVs, Total Q=58.46 MWh
# Online 2135, Q=53.31 MWh, SoC=0.6583
# Power(MW): Pt=-9.6291, Pc=-9.6291, Pd=-0.0
# Ctrl: 1=1626; 0=509;
# EVA: ts=2.6167[H], 5000 EVs, Total Q=58.46 MWh
# Online 2137, Q=53.35 MWh, SoC=0.6614
# Power(MW): Pt=-9.5393, Pc=-9.5393, Pd=-0.0
# Ctrl: 1=1612; 0=525;
# EVA: ts=2.6333[H], 5000 EVs, Total Q=58.46 MWh
# Online 2141, Q=53.46 MWh, SoC=0.6643
# Power(MW): Pt=-9.45, Pc=-9.45, Pd=-0.0
# Ctrl: 1=1598; 0=543;
# EVA: ts=2.65[H], 5000 EVs, Total Q=58.48 MWh
# Online 2145, Q=53.56 MWh, SoC=0.667
# Power(MW): Pt=-9.368, Pc=-9.368, Pd=-0.0
# Ctrl: 1=1585; 0=560;
# EVA: ts=2.6667[H], 5000 EVs, Total Q=58.48 MWh
# Online 2149, Q=53.66 MWh, SoC=0.6697
# Power(MW): Pt=-9.3132, Pc=-9.3132, Pd=-0.0
# Ctrl: 1=1576; 0=573;
# EVA: ts=2.6833[H], 5000 EVs, Total Q=58.54 MWh
# Online 2153, Q=53.76 MWh, SoC=0.6726
# Power(MW): Pt=-9.2533, Pc=-9.2533, Pd=-0.0
# Ctrl: 1=1566; 0=587;
# EVA: ts=2.7[H], 5000 EVs, Total Q=58.53 MWh
# Online 2155, Q=53.81 MWh, SoC=0.6755
# Power(MW): Pt=-9.2179, Pc=-9.2179, Pd=-0.0
# Ctrl: 1=1560; 0=595;
# EVA: ts=2.7167[H], 5000 EVs, Total Q=58.54 MWh
# Online 2156, Q=53.83 MWh, SoC=0.6785
# Power(MW): Pt=-9.1392, Pc=-9.1392, Pd=-0.0
# Ctrl: 1=1547; 0=609;
# EVA: ts=2.7333[H], 5000 EVs, Total Q=58.61 MWh
# Online 2159, Q=53.91 MWh, SoC=0.6815
# Power(MW): Pt=-9.0498, Pc=-9.0498, Pd=-0.0
# Ctrl: 1=1532; 0=627;
# EVA: ts=2.75[H], 5000 EVs, Total Q=58.61 MWh
# Online 2165, Q=54.06 MWh, SoC=0.684
# Power(MW): Pt=-8.9571, Pc=-8.9571, Pd=-0.0
# Ctrl: 1=1517; 0=648;
# EVA: ts=2.7667[H], 5000 EVs, Total Q=58.54 MWh
# Online 2164, Q=54.04 MWh, SoC=0.6868
# Power(MW): Pt=-8.8426, Pc=-8.8426, Pd=-0.0
# Ctrl: 1=1497; 0=667;
# EVA: ts=2.7833[H], 5000 EVs, Total Q=58.51 MWh
# Online 2165, Q=54.07 MWh, SoC=0.69
# Power(MW): Pt=-8.7402, Pc=-8.7402, Pd=-0.0
# Ctrl: 1=1480; 0=685;
# EVA: ts=2.8[H], 5000 EVs, Total Q=58.51 MWh
# Online 2174, Q=54.29 MWh, SoC=0.6918
# Power(MW): Pt=-8.7142, Pc=-8.7142, Pd=-0.0
# Ctrl: 1=1476; 0=698;
# EVA: ts=2.8167[H], 5000 EVs, Total Q=58.52 MWh
# Online 2175, Q=54.32 MWh, SoC=0.6947
# Power(MW): Pt=-8.6107, Pc=-8.6107, Pd=-0.0
# Ctrl: 1=1460; 0=715;
# EVA: ts=2.8333[H], 5000 EVs, Total Q=58.51 MWh
# Online 2176, Q=54.34 MWh, SoC=0.6978
# Power(MW): Pt=-8.5719, Pc=-8.5719, Pd=-0.0
# Ctrl: 1=1453; 0=723;
# EVA: ts=2.85[H], 5000 EVs, Total Q=58.54 MWh
# Online 2178, Q=54.39 MWh, SoC=0.7009
# Power(MW): Pt=-8.4493, Pc=-8.4493, Pd=-0.0
# Ctrl: 1=1433; 0=745;
# EVA: ts=2.8667[H], 5000 EVs, Total Q=58.57 MWh
# Online 2183, Q=54.52 MWh, SoC=0.7034
# Power(MW): Pt=-8.3824, Pc=-8.3824, Pd=-0.0
# Ctrl: 1=1422; 0=761;
# EVA: ts=2.8833[H], 5000 EVs, Total Q=58.55 MWh
# Online 2183, Q=54.52 MWh, SoC=0.7066
# Power(MW): Pt=-8.2921, Pc=-8.2921, Pd=-0.0
# Ctrl: 1=1407; 0=776;
# EVA: ts=2.9[H], 5000 EVs, Total Q=58.55 MWh
# Online 2190, Q=54.69 MWh, SoC=0.7087
# Power(MW): Pt=-8.2497, Pc=-8.2497, Pd=-0.0
# Ctrl: 1=1400; 0=790;
# EVA: ts=2.9167[H], 5000 EVs, Total Q=58.54 MWh
# Online 2194, Q=54.78 MWh, SoC=0.7114
# Power(MW): Pt=-8.1801, Pc=-8.1801, Pd=-0.0
# Ctrl: 1=1388; 0=806;
# EVA: ts=2.9333[H], 5000 EVs, Total Q=58.54 MWh
# Online 2198, Q=54.88 MWh, SoC=0.7141
# Power(MW): Pt=-8.1081, Pc=-8.1081, Pd=-0.0
# Ctrl: 1=1376; 0=822;
# EVA: ts=2.95[H], 5000 EVs, Total Q=58.57 MWh
# Online 2201, Q=54.95 MWh, SoC=0.7169
# Power(MW): Pt=-8.0134, Pc=-8.0134, Pd=-0.0
# Ctrl: 1=1361; 0=840;
# EVA: ts=2.9667[H], 5000 EVs, Total Q=58.6 MWh
# Online 2208, Q=55.12 MWh, SoC=0.719
# Power(MW): Pt=-7.9573, Pc=-7.9573, Pd=-0.0
# Ctrl: 1=1352; 0=856;
# EVA: ts=2.9833[H], 5000 EVs, Total Q=58.57 MWh
# Online 2212, Q=55.23 MWh, SoC=0.7211
# Power(MW): Pt=-7.8625, Pc=-7.8625, Pd=-0.0
# Ctrl: 1=1336; 0=876;
# EVA: ts=3.0[H], 5000 EVs, Total Q=58.51 MWh
# Online 2211, Q=55.19 MWh, SoC=0.7245
# Power(MW): Pt=-7.7741, Pc=-7.7741, Pd=-0.0
# Ctrl: 1=1321; 0=890;
# EVA: ts=3.0167[H], 5000 EVs, Total Q=58.53 MWh
# Online 2215, Q=55.28 MWh, SoC=0.7268
# Power(MW): Pt=-7.7199, Pc=-7.7199, Pd=-0.0
# Ctrl: 1=1312; 0=903;
# EVA: ts=3.0333[H], 5000 EVs, Total Q=58.53 MWh
# Online 2212, Q=55.21 MWh, SoC=0.7302
# Power(MW): Pt=-7.631, Pc=-7.631, Pd=-0.0
# Ctrl: 1=1297; 0=915;
# EVA: ts=3.05[H], 5000 EVs, Total Q=58.49 MWh
# Online 2213, Q=55.24 MWh, SoC=0.7328
# Power(MW): Pt=-7.5198, Pc=-7.5198, Pd=-0.0
# Ctrl: 1=1278; 0=935;
# EVA: ts=3.0667[H], 5000 EVs, Total Q=58.49 MWh
# Online 2213, Q=55.24 MWh, SoC=0.7361
# Power(MW): Pt=-7.4222, Pc=-7.4222, Pd=-0.0
# Ctrl: 1=1262; 0=951;
# EVA: ts=3.0833[H], 5000 EVs, Total Q=58.51 MWh
# Online 2217, Q=55.35 MWh, SoC=0.7386
# Power(MW): Pt=-7.31, Pc=-7.31, Pd=-0.0
# Ctrl: 1=1244; 0=973;
# EVA: ts=3.1[H], 5000 EVs, Total Q=58.44 MWh
# Online 2216, Q=55.33 MWh, SoC=0.7413
# Power(MW): Pt=-7.231, Pc=-7.231, Pd=-0.0
# Ctrl: 1=1231; 0=985;
# EVA: ts=3.1167[H], 5000 EVs, Total Q=58.44 MWh
# Online 2219, Q=55.4 MWh, SoC=0.7439
# Power(MW): Pt=-7.1739, Pc=-7.1739, Pd=-0.0
# Ctrl: 1=1222; 0=997;
# EVA: ts=3.1333[H], 5000 EVs, Total Q=58.41 MWh
# Online 2221, Q=55.45 MWh, SoC=0.7465
# Power(MW): Pt=-7.0706, Pc=-7.0706, Pd=-0.0
# Ctrl: 1=1205; 0=1016;
# EVA: ts=3.15[H], 5000 EVs, Total Q=58.47 MWh
# Online 2222, Q=55.49 MWh, SoC=0.7494
# Power(MW): Pt=-6.942, Pc=-6.942, Pd=-0.0
# Ctrl: 1=1183; 0=1039;
# EVA: ts=3.1667[H], 5000 EVs, Total Q=58.5 MWh
# Online 2225, Q=55.57 MWh, SoC=0.7515
# Power(MW): Pt=-6.8835, Pc=-6.8835, Pd=-0.0
# Ctrl: 1=1173; 0=1052;
# EVA: ts=3.1833[H], 5000 EVs, Total Q=58.55 MWh
# Online 2233, Q=55.78 MWh, SoC=0.7531
# Power(MW): Pt=-6.8641, Pc=-6.8641, Pd=-0.0
# Ctrl: 1=1170; 0=1063;
# EVA: ts=3.2[H], 5000 EVs, Total Q=58.62 MWh
# Online 2236, Q=55.85 MWh, SoC=0.7556
# Power(MW): Pt=-6.8034, Pc=-6.8034, Pd=-0.0
# Ctrl: 1=1159; 0=1077;
# EVA: ts=3.2167[H], 5000 EVs, Total Q=58.62 MWh
# Online 2242, Q=55.99 MWh, SoC=0.7576
# Power(MW): Pt=-6.7225, Pc=-6.7225, Pd=-0.0
# Ctrl: 1=1145; 0=1097;
# EVA: ts=3.2333[H], 5000 EVs, Total Q=58.62 MWh
# Online 2247, Q=56.13 MWh, SoC=0.7594
# Power(MW): Pt=-6.6759, Pc=-6.6759, Pd=-0.0
# Ctrl: 1=1137; 0=1110;
# EVA: ts=3.25[H], 5000 EVs, Total Q=58.57 MWh
# Online 2247, Q=56.13 MWh, SoC=0.7616
# Power(MW): Pt=-6.5777, Pc=-6.5777, Pd=-0.0
# Ctrl: 0=1126; 1=1121;
# EVA: ts=3.2667[H], 5000 EVs, Total Q=58.54 MWh
# Online 2246, Q=56.11 MWh, SoC=0.7645
# Power(MW): Pt=-6.4685, Pc=-6.4685, Pd=-0.0
# Ctrl: 0=1143; 1=1103;
# EVA: ts=3.2833[H], 5000 EVs, Total Q=58.52 MWh
# Online 2247, Q=56.13 MWh, SoC=0.7671
# Power(MW): Pt=-6.3777, Pc=-6.3777, Pd=-0.0
# Ctrl: 0=1160; 1=1087;
# EVA: ts=3.3[H], 5000 EVs, Total Q=58.54 MWh
# Online 2249, Q=56.18 MWh, SoC=0.7696
# Power(MW): Pt=-6.3182, Pc=-6.3182, Pd=-0.0
# Ctrl: 0=1172; 1=1077;
# EVA: ts=3.3167[H], 5000 EVs, Total Q=58.57 MWh
# Online 2250, Q=56.2 MWh, SoC=0.7721
# Power(MW): Pt=-6.2895, Pc=-6.2895, Pd=-0.0
# Ctrl: 0=1178; 1=1072;
# EVA: ts=3.3333[H], 5000 EVs, Total Q=58.55 MWh
# Online 2250, Q=56.2 MWh, SoC=0.7749
# Power(MW): Pt=-6.1815, Pc=-6.1815, Pd=-0.0
# Ctrl: 0=1196; 1=1054;
# EVA: ts=3.35[H], 5000 EVs, Total Q=58.55 MWh
# Online 2251, Q=56.23 MWh, SoC=0.7777
# Power(MW): Pt=-6.1005, Pc=-6.1005, Pd=-0.0
# Ctrl: 0=1210; 1=1041;
# EVA: ts=3.3667[H], 5000 EVs, Total Q=58.52 MWh
# Online 2253, Q=56.28 MWh, SoC=0.78
# Power(MW): Pt=-6.0397, Pc=-6.0397, Pd=-0.0
# Ctrl: 0=1222; 1=1031;
# EVA: ts=3.3833[H], 5000 EVs, Total Q=58.52 MWh
# Online 2255, Q=56.32 MWh, SoC=0.7826
# Power(MW): Pt=-5.9637, Pc=-5.9637, Pd=-0.0
# Ctrl: 0=1237; 1=1018;
# EVA: ts=3.4[H], 5000 EVs, Total Q=58.47 MWh
# Online 2253, Q=56.28 MWh, SoC=0.7854
# Power(MW): Pt=-5.8929, Pc=-5.8929, Pd=-0.0
# Ctrl: 0=1247; 1=1006;
# EVA: ts=3.4167[H], 5000 EVs, Total Q=58.5 MWh
# Online 2254, Q=56.31 MWh, SoC=0.788
# Power(MW): Pt=-5.8132, Pc=-5.8132, Pd=-0.0
# Ctrl: 0=1261; 1=993;
# EVA: ts=3.4333[H], 5000 EVs, Total Q=58.5 MWh
# Online 2253, Q=56.29 MWh, SoC=0.7909
# Power(MW): Pt=-5.7832, Pc=-5.7832, Pd=-0.0
# Ctrl: 0=1265; 1=988;
# EVA: ts=3.45[H], 5000 EVs, Total Q=58.53 MWh
# Online 2257, Q=56.39 MWh, SoC=0.7927
# Power(MW): Pt=-5.7384, Pc=-5.7384, Pd=-0.0
# Ctrl: 0=1277; 1=980;
# EVA: ts=3.4667[H], 5000 EVs, Total Q=58.51 MWh
# Online 2259, Q=56.43 MWh, SoC=0.7948
# Power(MW): Pt=-5.6176, Pc=-5.6176, Pd=-0.0
# Ctrl: 0=1299; 1=960;
# EVA: ts=3.4833[H], 5000 EVs, Total Q=58.51 MWh
# Online 2262, Q=56.5 MWh, SoC=0.797
# Power(MW): Pt=-5.5766, Pc=-5.5766, Pd=-0.0
# Ctrl: 0=1309; 1=953;
# EVA: ts=3.5[H], 5000 EVs, Total Q=58.55 MWh
# Online 2265, Q=56.58 MWh, SoC=0.7991
# Power(MW): Pt=-5.5252, Pc=-5.5252, Pd=-0.0
# Ctrl: 0=1320; 1=945;
# EVA: ts=3.5167[H], 5000 EVs, Total Q=58.5 MWh
# Online 2266, Q=56.59 MWh, SoC=0.8014
# Power(MW): Pt=-5.4074, Pc=-5.4074, Pd=-0.0
# Ctrl: 0=1341; 1=925;
# EVA: ts=3.5333[H], 5000 EVs, Total Q=58.47 MWh
# Online 2266, Q=56.6 MWh, SoC=0.804
# Power(MW): Pt=-5.326, Pc=-5.326, Pd=-0.0
# Ctrl: 0=1354; 1=912;
# EVA: ts=3.55[H], 5000 EVs, Total Q=58.5 MWh
# Online 2269, Q=56.67 MWh, SoC=0.806
# Power(MW): Pt=-5.2724, Pc=-5.2724, Pd=-0.0
# Ctrl: 0=1366; 1=903;
# EVA: ts=3.5667[H], 5000 EVs, Total Q=58.48 MWh
# Online 2269, Q=56.68 MWh, SoC=0.8081
# Power(MW): Pt=-5.1856, Pc=-5.1856, Pd=-0.0
# Ctrl: 0=1381; 1=888;
# EVA: ts=3.5833[H], 5000 EVs, Total Q=58.46 MWh
# Online 2268, Q=56.66 MWh, SoC=0.8105
# Power(MW): Pt=-5.1201, Pc=-5.1201, Pd=-0.0
# Ctrl: 0=1391; 1=877;
# EVA: ts=3.6[H], 5000 EVs, Total Q=58.41 MWh
# Online 2270, Q=56.71 MWh, SoC=0.8121
# Power(MW): Pt=-5.0788, Pc=-5.0788, Pd=-0.0
# Ctrl: 0=1400; 1=870;
# EVA: ts=3.6167[H], 5000 EVs, Total Q=58.35 MWh
# Online 2268, Q=56.66 MWh, SoC=0.8146
# Power(MW): Pt=-5.0081, Pc=-5.0081, Pd=-0.0
# Ctrl: 0=1410; 1=858;
# EVA: ts=3.6333[H], 5000 EVs, Total Q=58.43 MWh
# Online 2268, Q=56.66 MWh, SoC=0.8172
# Power(MW): Pt=-4.931, Pc=-4.931, Pd=-0.0
# Ctrl: 0=1423; 1=845;
# EVA: ts=3.65[H], 5000 EVs, Total Q=58.41 MWh
# Online 2269, Q=56.68 MWh, SoC=0.8194
# Power(MW): Pt=-4.8839, Pc=-4.8839, Pd=-0.0
# Ctrl: 0=1432; 1=837;
# EVA: ts=3.6667[H], 5000 EVs, Total Q=58.33 MWh
# Online 2266, Q=56.61 MWh, SoC=0.822
# Power(MW): Pt=-4.8351, Pc=-4.8351, Pd=-0.0
# Ctrl: 0=1438; 1=828;
# EVA: ts=3.6833[H], 5000 EVs, Total Q=58.28 MWh
# Online 2267, Q=56.64 MWh, SoC=0.8238
# Power(MW): Pt=-4.8006, Pc=-4.8006, Pd=-0.0
# Ctrl: 0=1445; 1=822;
# EVA: ts=3.7[H], 5000 EVs, Total Q=58.25 MWh
# Online 2268, Q=56.66 MWh, SoC=0.826
# Power(MW): Pt=-4.6942, Pc=-4.6942, Pd=-0.0
# Ctrl: 0=1464; 1=804;
# EVA: ts=3.7167[H], 5000 EVs, Total Q=58.25 MWh
# Online 2269, Q=56.68 MWh, SoC=0.8281
# Power(MW): Pt=-4.6275, Pc=-4.6275, Pd=-0.0
# Ctrl: 0=1476; 1=793;
# EVA: ts=3.7333[H], 5000 EVs, Total Q=58.2 MWh
# Online 2271, Q=56.73 MWh, SoC=0.8297
# Power(MW): Pt=-4.5789, Pc=-4.5789, Pd=-0.0
# Ctrl: 0=1486; 1=785;
# EVA: ts=3.75[H], 5000 EVs, Total Q=58.13 MWh
# Online 2268, Q=56.65 MWh, SoC=0.8322
# Power(MW): Pt=-4.5398, Pc=-4.5398, Pd=-0.0
# Ctrl: 0=1490; 1=778;
# EVA: ts=3.7667[H], 5000 EVs, Total Q=58.07 MWh
# Online 2268, Q=56.65 MWh, SoC=0.8342
# Power(MW): Pt=-4.4946, Pc=-4.4946, Pd=-0.0
# Ctrl: 0=1498; 1=770;
# EVA: ts=3.7833[H], 5000 EVs, Total Q=58.07 MWh
# Online 2268, Q=56.65 MWh, SoC=0.8366
# Power(MW): Pt=-4.4347, Pc=-4.4347, Pd=-0.0
# Ctrl: 0=1508; 1=760;
# EVA: ts=3.8[H], 5000 EVs, Total Q=58.05 MWh
# Online 2267, Q=56.63 MWh, SoC=0.8391
# Power(MW): Pt=-4.3756, Pc=-4.3756, Pd=-0.0
# Ctrl: 0=1517; 1=750;
# EVA: ts=3.8167[H], 5000 EVs, Total Q=58.08 MWh
# Online 2267, Q=56.63 MWh, SoC=0.8409
# Power(MW): Pt=-4.3461, Pc=-4.3461, Pd=-0.0
# Ctrl: 0=1522; 1=745;
# EVA: ts=3.8333[H], 5000 EVs, Total Q=58.05 MWh
# Online 2267, Q=56.63 MWh, SoC=0.8432
# Power(MW): Pt=-4.2892, Pc=-4.2892, Pd=-0.0
# Ctrl: 0=1532; 1=735;
# EVA: ts=3.85[H], 5000 EVs, Total Q=58.02 MWh
# Online 2267, Q=56.63 MWh, SoC=0.8453
# Power(MW): Pt=-4.1775, Pc=-4.1775, Pd=-0.0
# Ctrl: 0=1551; 1=716;
# EVA: ts=3.8667[H], 5000 EVs, Total Q=57.98 MWh
# Online 2266, Q=56.61 MWh, SoC=0.8472
# Power(MW): Pt=-4.1056, Pc=-4.1056, Pd=-0.0
# Ctrl: 0=1562; 1=704;
# EVA: ts=3.8833[H], 5000 EVs, Total Q=57.92 MWh
# Online 2264, Q=56.56 MWh, SoC=0.8494
# Power(MW): Pt=-4.0705, Pc=-4.0705, Pd=-0.0
# Ctrl: 0=1566; 1=698;
# EVA: ts=3.9[H], 5000 EVs, Total Q=57.92 MWh
# Online 2265, Q=56.58 MWh, SoC=0.8514
# Power(MW): Pt=-4.0391, Pc=-4.0391, Pd=-0.0
# Ctrl: 0=1572; 1=693;
# EVA: ts=3.9167[H], 5000 EVs, Total Q=57.9 MWh
# Online 2264, Q=56.55 MWh, SoC=0.8537
# Power(MW): Pt=-3.9744, Pc=-3.9744, Pd=-0.0
# Ctrl: 0=1582; 1=682;
# EVA: ts=3.9333[H], 5000 EVs, Total Q=57.79 MWh
# Online 2259, Q=56.42 MWh, SoC=0.8562
# Power(MW): Pt=-3.9206, Pc=-3.9206, Pd=-0.0
# Ctrl: 0=1586; 1=673;
# EVA: ts=3.95[H], 5000 EVs, Total Q=57.74 MWh
# Online 2258, Q=56.4 MWh, SoC=0.8581
# Power(MW): Pt=-3.8612, Pc=-3.8612, Pd=-0.0
# Ctrl: 0=1595; 1=663;
# EVA: ts=3.9667[H], 5000 EVs, Total Q=57.74 MWh
# Online 2259, Q=56.42 MWh, SoC=0.86
# Power(MW): Pt=-3.8285, Pc=-3.8285, Pd=-0.0
# Ctrl: 0=1602; 1=657;
# EVA: ts=3.9833[H], 5000 EVs, Total Q=57.68 MWh
# Online 2258, Q=56.39 MWh, SoC=0.8621
# Power(MW): Pt=-3.782, Pc=-3.782, Pd=-0.0
# Ctrl: 0=1609; 1=649;
# EVA: ts=4.0[H], 5000 EVs, Total Q=57.66 MWh
# Online 2257, Q=56.36 MWh, SoC=0.8639
# Power(MW): Pt=-3.7526, Pc=-3.7526, Pd=-0.0
# Ctrl: 0=1613; 1=644;
# EVA: ts=4.0167[H], 5000 EVs, Total Q=57.68 MWh
# Online 2259, Q=56.41 MWh, SoC=0.8656
# Power(MW): Pt=-3.7267, Pc=-3.7267, Pd=-0.0
# Ctrl: 0=1620; 1=639;
# EVA: ts=4.0333[H], 5000 EVs, Total Q=57.67 MWh
# Online 2260, Q=56.43 MWh, SoC=0.8668
# Power(MW): Pt=-3.6674, Pc=-3.6674, Pd=-0.0
# Ctrl: 0=1631; 1=629;
# EVA: ts=4.05[H], 5000 EVs, Total Q=57.67 MWh
# Online 2259, Q=56.41 MWh, SoC=0.8689
# Power(MW): Pt=-3.6165, Pc=-3.6165, Pd=-0.0
# Ctrl: 0=1639; 1=620;
# EVA: ts=4.0667[H], 5000 EVs, Total Q=57.67 MWh
# Online 2258, Q=56.38 MWh, SoC=0.871
# Power(MW): Pt=-3.5402, Pc=-3.5402, Pd=-0.0
# Ctrl: 0=1651; 1=607;
# EVA: ts=4.0833[H], 5000 EVs, Total Q=57.66 MWh
# Online 2258, Q=56.38 MWh, SoC=0.8727
# Power(MW): Pt=-3.5092, Pc=-3.5092, Pd=-0.0
# Ctrl: 0=1656; 1=602;
# EVA: ts=4.1[H], 5000 EVs, Total Q=57.58 MWh
# Online 2256, Q=56.32 MWh, SoC=0.8745
# Power(MW): Pt=-3.4446, Pc=-3.4446, Pd=-0.0
# Ctrl: 0=1665; 1=591;
# EVA: ts=4.1167[H], 5000 EVs, Total Q=57.52 MWh
# Online 2254, Q=56.26 MWh, SoC=0.8766
# Power(MW): Pt=-3.3761, Pc=-3.3761, Pd=-0.0
# Ctrl: 0=1675; 1=579;
# EVA: ts=4.1333[H], 5000 EVs, Total Q=57.5 MWh
# Online 2254, Q=56.26 MWh, SoC=0.8783
# Power(MW): Pt=-3.3297, Pc=-3.3297, Pd=-0.0
# Ctrl: 0=1683; 1=571;
# EVA: ts=4.15[H], 5000 EVs, Total Q=57.47 MWh
# Online 2255, Q=56.29 MWh, SoC=0.8793
# Power(MW): Pt=-3.3, Pc=-3.3, Pd=-0.0
# Ctrl: 0=1689; 1=566;
# EVA: ts=4.1667[H], 5000 EVs, Total Q=57.45 MWh
# Online 2257, Q=56.34 MWh, SoC=0.8803
# Power(MW): Pt=-3.2722, Pc=-3.2722, Pd=-0.0
# Ctrl: 0=1696; 1=561;
# EVA: ts=4.1833[H], 5000 EVs, Total Q=57.45 MWh
# Online 2256, Q=56.33 MWh, SoC=0.8817
# Power(MW): Pt=-3.2324, Pc=-3.2324, Pd=-0.0
# Ctrl: 0=1702; 1=554;
# EVA: ts=4.2[H], 5000 EVs, Total Q=57.42 MWh
# Online 2257, Q=56.35 MWh, SoC=0.8828
# Power(MW): Pt=-3.1287, Pc=-3.1287, Pd=-0.0
# Ctrl: 0=1721; 1=536;
# EVA: ts=4.2167[H], 5000 EVs, Total Q=57.31 MWh
# Online 2253, Q=56.24 MWh, SoC=0.8845
# Power(MW): Pt=-3.0851, Pc=-3.0851, Pd=-0.0
# Ctrl: 0=1724; 1=529;
# EVA: ts=4.2333[H], 5000 EVs, Total Q=57.31 MWh
# Online 2253, Q=56.24 MWh, SoC=0.8861
# Power(MW): Pt=-3.0633, Pc=-3.0633, Pd=-0.0
# Ctrl: 0=1728; 1=525;
# EVA: ts=4.25[H], 5000 EVs, Total Q=57.35 MWh
# Online 2255, Q=56.28 MWh, SoC=0.8874
# Power(MW): Pt=-2.9946, Pc=-2.9946, Pd=-0.0
# Ctrl: 0=1742; 1=513;
# EVA: ts=4.2667[H], 5000 EVs, Total Q=57.28 MWh
# Online 2253, Q=56.23 MWh, SoC=0.8891
# Power(MW): Pt=-2.9536, Pc=-2.9536, Pd=-0.0
# Ctrl: 0=1747; 1=506;
# EVA: ts=4.2833[H], 5000 EVs, Total Q=57.23 MWh
# Online 2251, Q=56.18 MWh, SoC=0.8907
# Power(MW): Pt=-2.9114, Pc=-2.9114, Pd=-0.0
# Ctrl: 0=1752; 1=499;
# EVA: ts=4.3[H], 5000 EVs, Total Q=57.16 MWh
# Online 2250, Q=56.16 MWh, SoC=0.8922
# Power(MW): Pt=-2.8942, Pc=-2.8942, Pd=-0.0
# Ctrl: 0=1754; 1=496;
# EVA: ts=4.3167[H], 5000 EVs, Total Q=57.19 MWh
# Online 2252, Q=56.22 MWh, SoC=0.8933
# Power(MW): Pt=-2.8637, Pc=-2.8637, Pd=-0.0
# Ctrl: 0=1762; 1=490;
# EVA: ts=4.3333[H], 5000 EVs, Total Q=57.15 MWh
# Online 2251, Q=56.21 MWh, SoC=0.8946
# Power(MW): Pt=-2.8299, Pc=-2.8299, Pd=-0.0
# Ctrl: 0=1767; 1=484;
# EVA: ts=4.35[H], 5000 EVs, Total Q=57.09 MWh
# Online 2249, Q=56.15 MWh, SoC=0.8962
# Power(MW): Pt=-2.7825, Pc=-2.7825, Pd=-0.0
# Ctrl: 0=1773; 1=476;
# EVA: ts=4.3667[H], 5000 EVs, Total Q=57.04 MWh
# Online 2247, Q=56.1 MWh, SoC=0.8978
# Power(MW): Pt=-2.7482, Pc=-2.7482, Pd=-0.0
# Ctrl: 0=1777; 1=470;
# EVA: ts=4.3833[H], 5000 EVs, Total Q=56.99 MWh
# Online 2245, Q=56.05 MWh, SoC=0.8994
# Power(MW): Pt=-2.706, Pc=-2.706, Pd=-0.0
# Ctrl: 0=1782; 1=463;

# %%
sse0 = ev_ssm(ts=18.0, N=50000, step=1, tp=40,
             lr=0.1, lp=60, seed=2022, name="EVA")

# %%
# %run -i 'cosim_setup_dispatch.py'

# %%
# %run -i 'cosim_linktable.py'

# Change ``rru``, ``rrd``, ``rsfr``, ``t_total`` for necessary.
t_total = 3600

rru, rrd, rsfr = 1.0, 1.0, 0.04

# Define functions and constants used in loop
# %run -i 'cosim_const.py'

# %%
pgf = pd.read_csv('cosim_18_F_pg.csv')
pgs = pd.read_csv('cosim_18_S_pg.csv')
pgh = pd.read_csv('cosim_18_H_pg.csv')
agcf = pd.read_csv('cosim_18_F_agcm.csv')
agcs = pd.read_csv('cosim_18_S_agcm.csv')
agch = pd.read_csv('cosim_18_H_agcm.csv')
outf = pd.read_csv('cosim_18_F_out.csv')
outs = pd.read_csv('cosim_18_S_out.csv')
outh = pd.read_csv('cosim_18_H_out.csv')
outf['fd'] = outf['freq'] - ssa.config.freq
outs['fd'] = outs['freq'] - ssa.config.freq
outh['fd'] = outh['freq'] - ssa.config.freq

evf = pd.read_csv('cosim_18_F_sse.csv')
evs = pd.read_csv('cosim_18_S_sse.csv')
evh = pd.read_csv('cosim_18_H_sse.csv')
evdf = pd.read_csv('cosim_18_F_evdata.csv')
evds = pd.read_csv('cosim_18_S_evdata.csv')
evdh = pd.read_csv('cosim_18_H_evdata.csv')

sfrf = pd.read_csv('cosim_18_F_sfr.csv')
sfrs = pd.read_csv('cosim_18_S_sfr.csv')
sfrh = pd.read_csv('cosim_18_H_sfr.csv')

evagcf = pd.read_csv('cosim_18_F_evagc.csv').T
evsocf = pd.read_csv('cosim_18_F_evsoc.csv').T
evsocf.sort_values(by=['0'], axis=1, inplace=True)
evagcs = pd.read_csv('cosim_18_S_evagc.csv').T
evsocs = pd.read_csv('cosim_18_S_evsoc.csv').T
evsocs.sort_values(by=['0'], axis=1, inplace=True)
evagch = pd.read_csv('cosim_18_H_evagc.csv').T
evsoch = pd.read_csv('cosim_18_H_evsoc.csv').T
evsoch.sort_values(by=['0'], axis=1, inplace=True)

reader = csv.reader(open('cosim_18_F_rted.csv', 'r'))
rted_res = {}
for row in reader:
   k, v = row
   rted_res[k] = v

# %%
ACE_integral = 0
ACE_raw = 0
raw = -1 * np.ones((3600, 3))
for end_time in range(3600):
    acep = outs['ACE'][(outs['Time'] >= end_time-0.03)&(outs['Time'] <= end_time)].mean()
    ACE_integral += acep
    ACE_raw = -(Kp*acep + Ki*ACE_integral)
    raw[end_time] = [end_time, ACE_raw, ACE_integral]
raws = pd.DataFrame(raw, columns=['Time', 'raw', 'itg'])
    
ACE_integral = 0
ACE_raw = 0
raw = -1 * np.ones((3600, 3))
for end_time in range(3600):
    acep = outf['ACE'][(outf['Time'] >= end_time-0.03)&(outf['Time'] <= end_time)].mean()
    ACE_integral += acep
    ACE_raw = -(Kp*acep + Ki*ACE_integral)
    raw[end_time] = [end_time, ACE_raw, ACE_integral]
rawf = pd.DataFrame(raw, columns=['Time', 'raw', 'itg'])

fig, ax = plt.subplots()
raws.plot(x='Time', y='raw', fig=fig, ax=ax)
rawf.plot(x='Time', y='raw', fig=fig, ax=ax)

# %%
# fig, ax = plt.subplots()
# outs.plot(x='Time', y='ACE', fig=fig, ax=ax)
# outf.plot(x='Time', y='ACE', fig=fig, ax=ax)

# %%
import matplotlib.font_manager

# %%
# --- read load from ssa ---
ptotal = ssa.PQ.as_df()['p0'].sum()
print('ANDES total load is:',ptotal.round(4),'p.u.')

# --- scale load curve ---
ddata_path = '/case/dsyn.csv'
ddata = dir_path + ddata_path
d_syn = pd.read_csv(ddata)

# the coefficient can be adjusted to fit the case
if caseH == 10:
    d_syn['sload'] = 0.8*(d_syn['ha10'] - d_syn['ha10'].min()) / d_syn['ha10'].min() + 0.7
if caseH == 18:
    d_syn['sload'] = 0.8*(d_syn['ha18'] - d_syn['ha18'].min()) / d_syn['ha18'].min() + 0.7

# extensify load fluctuation
avg = d_syn['sload'].rolling(50).mean()
d_syn['sload'] = 15 * (d_syn['sload'] - avg) + avg
d_syn['sload'] *= ptotal * ssa.config.mva

# calculate expected load
step = 300
d_exp = d_syn.groupby(d_syn.index // step).mean().copy()
d_exp['time'] = range(0,3600,300)

# align starting point of load with starting point of dispatch results
d_syn['sload'][0] = d_exp['sload'].iloc[0]
d_syn['sload'][1:100] = None
d_syn['sload'] = d_syn['sload'].interpolate(method='polynomial', order=3)

plt.style.use('ieee')
# --- plot load curve ---
fig_load, ax_load = plt.subplots(figsize=(3.5, 3))
ax_load.plot(d_syn['time'], d_syn['sload'], linestyle='-')
ax_load.set_xlim([0, 3600])
ax_load.set_ylabel('Active power [MW]')
ax_load.set_xlabel('Time [s]')
ax_load.grid()
plt.tight_layout()
fig_load.savefig("load_curve.png", bbox_inches="tight")

plt.style.use('ieee')
fig, ax = plt.subplots(1, 1, figsize=(3.5, 3))

ax.plot(3600*(np.array(evs.time)-18), evs['ne'])
ax.set_xlim([0, 3600])
ax.set_xlabel('Time [s]')
ax.set_ylabel('Numbers')
ax.grid()

# %%
noagcev = evagcf.abs().sum() == 0
noagcev = noagcev[noagcev].index
noagcev

# %%
col_index = []
for k in range(0, 16):
    col_index = col_index + [list(np.array(range(0, 100)) + 100*k)]
col = []
for c in col_index:
    col = col + [list(evsocf.columns[[c]].values)]

fig, ax = plt.subplots(4, 4, figsize=(16, 10))
plt.subplots_adjust(left=None, bottom=None, right=None,
                    top=None, wspace=0.25, hspace=0.4)

alpha=0.8
for i in range(4):
    for j in range(4):
        idx = 15 - (4*i + j)
        ax[i, j].fill_between(range(3600), linestyle='-', color='tab:blue', hatch='||', alpha=1, label=f'Case1',
                              y1=evsocs[col[idx]].mean(axis=1) + 1.96 * evsocs[col[idx]].sem(axis=1),
                              y2=evsocs[col[idx]].mean(axis=1) - 1.96 * evsocs[col[idx]].sem(axis=1))
        ax[i, j].fill_between(range(3600), linestyle='-', color='tab:green', hatch='//', alpha=0.9, label=f'Case2',
                              y1=evsoch[col[idx]].mean(axis=1) + 1.96 * evsoch[col[idx]].sem(axis=1),
                              y2=evsoch[col[idx]].mean(axis=1) - 1.96 * evsoch[col[idx]].sem(axis=1))
        ax[i, j].fill_between(range(3600), linestyle='-', color='tab:orange', hatch='\\\\', alpha=0.8, label=f'Case3',
                              y1=evsocf[col[idx]].mean(axis=1) + 1.96 * evsocf[col[idx]].sem(axis=1),
                              y2=evsocf[col[idx]].mean(axis=1) - 1.96 * evsocf[col[idx]].sem(axis=1))
        ax[i, j].legend()
        ax[i, j].set_xlim([0, 3600])
        ax[i, j].set_xlabel('Time [s]')
        ax[i, j].set_ylabel('95% CI of SOC [%]')
        yticks = list(ax[i, j].get_yticks())
        ax[i, j].set_yticks(yticks[0:-1], [np.round(ytk*100, 4) for ytk in yticks[0:-1]])
        ax[i, j].set_title(f'SOC level {idx*5+20}-{idx*5+25}%')
#         ax[i, j].set_ylim([0.58, 1.02])

# %%
col_index = []
for k in range(0, 16):
    col_index = col_index + [list(np.array(range(0, 100)) + 100*k)]
col = []
for c in col_index:
    col = col + [list(evsocf.columns[[c]].values)]

fig, ax = plt.subplots(4, 4, figsize=(16, 10))
plt.subplots_adjust(left=None, bottom=None, right=None,
                    top=None, wspace=0.35, hspace=0.4)

for i in range(4):
    for j in range(4):
        idx = 15 - (4*i + j)
        ax[i, j].plot(range(3600), evsocs[col[idx]].mean(axis=1), linestyle='-', color='tab:blue', label=f'Case1')
        ax[i, j].plot(range(3600), evsoch[col[idx]].mean(axis=1), linestyle='-.', color='tab:green', label=f'Case2')
        ax[i, j].plot(range(3600), evsocf[col[idx]].mean(axis=1), linestyle='--', color='tab:orange', label=f'Case3')
        ax[i, j].legend()
        ax[i, j].set_xlim([0, 3600])
        ax[i, j].set_xlabel('Time [s]')
        ax[i, j].set_ylabel('Average SOC [%]')
        yticks = list(ax[i, j].get_yticks())
        ax[i, j].set_yticks(yticks[0:-1], [np.round(ytk*100, 4) for ytk in yticks[0:-1]])
        ax[i, j].set_title(f'SOC level {idx*5+20}-{idx*5+25}%')
#         ax[i, j].set_ylim([0.58, 1.02])

# %%
evif['dt'].max()

# %%
evif = evdh.copy()
evif['sx0'] = sse0.ev['sx']
evif['socf'] = evif['soc']
evif['socs'] = evds['soc']
evif['socgap'] = evif['socs'] - evif['socf']
evif['dt'] = evif['socgap'] * evif['Q'] / evif['Pc'] / evif['nc']
# set negative value to 0
evif['dt'][evif['dt']<0] = 0
# set demanded charged EV to 0
evif['dt'][evif['socf']>=evif['socd']] = 0
# Convert to minutes
evif['dt'] = evif['dt'] * 60

fig, ax = plt.subplots(1, 1, figsize=(5, 3))
evif.groupby(by='sx0').mean()['dt'].plot.bar(fig=fig, ax=ax)
ax.set_xlabel('Initial SOC level')
ax.set_xticklabels([f"{i*5}-{i*5+5}%" for i in evif.groupby('sx0').mean().index.tolist()],
                   rotation = 270)
ax.set_ylabel('Time [Min]')

# %%
# Delayed time by participating SFR

evif = evdf.copy()
evif['sx0'] = sse0.ev['sx']
evif['socf'] = evif['soc']
evif['socs'] = evds['soc']
evif['socgap'] = evif['socs'] - evif['socf']
evif['dt'] = evif['socgap'] * evif['Q'] / evif['Pc'] / evif['nc']
# set negative value to 0
evif['dt'][evif['dt']<0] = 0
# set demanded charged EV to 0
evif['dt'][evif['socf']>=evif['socd']] = 0

evih = evdh.copy()
evih['sx0'] = sse0.ev['sx']
evih['soc0'] = sse0.ev['soc']
evih['socf'] = evdh['soc']
evih['socs'] = evds['soc']
evih['socgap'] = evih['soc'] - evih['socs']
evih['dt'] = evih['socgap'] * evih['Q'] / evih['Pc'] / evih['nc']
evih['dt'][evih['dt']<0] = 0

plt.style.use('ieee')
ax = evif.boxplot(column=['dt'], by='sx0', figsize=(5, 3))
ax.set_title('')
ax.set_xlabel('SOC level')
ax.set_xticklabels([f"{i*5}-{i*5+5}%" for i in evif.groupby('sx0').mean().index.tolist()],
                   rotation = 270)
ax.set_ylabel('Time [H]')
fig = ax.get_figure()
fig.suptitle('')

ax2 = evih.boxplot(column=['dt'], by='sx0', figsize=(5, 3))
ax2.set_title('')
ax2.set_xlabel('SOC level')
ax2.set_xticklabels([i+1 for i in evif.groupby('sx0').mean().index.tolist()])
ax2.set_ylabel('Time [H]')
fig2 = ax2.get_figure()
fig2.suptitle('')

# %%
epsilon = 18
k = 10 * ssa.ACEc.bias.v / epsilon / epsilon # mHz
length = 60

outscp = outs.copy()
outscp['Time'] = outscp['Time'] / length
outscp['Time'] = outscp['Time'].astype(int)
outscp = outscp.groupby('Time').mean()
outscp['prod'] = 100* (2 - k * outscp['ACE'] * outscp['fd'])

outhcp = outh.copy()
outhcp['Time'] = outhcp['Time'] / length
outhcp['Time'] = outhcp['Time'].astype(int)
outhcp = outhcp.groupby('Time').mean()
outhcp['prod'] = 100* (2 - k * outhcp['ACE'] * outhcp['fd'])

outfcp = outf.copy()
outfcp['Time'] = outfcp['Time'] / length
outfcp['Time'] = outfcp['Time'].astype(int)
outfcp = outfcp.groupby('Time').mean()
outfcp['prod'] = 100* (2 - k * outfcp['ACE'] * outfcp['fd'])

print(f"case1={outscp['prod'].mean()}, case2={outhcp['prod'].mean()}, case3={outfcp['prod'].mean()}")

# fig, ax = plt.subplots(figsize=(3.5, 3))
# outscp.plot(y='prod', kind='kde', color='tab:blue', linestyle='-',
#             legend=False, linewidth=1, fig=fig, ax=ax, label='Case1')
# outhcp.plot(y='prod', kind='kde', color='tab:green', linestyle='-',
#             legend=False, linewidth=1, fig=fig, ax=ax, label='Case2')
# outfcp.plot(y='prod', kind='kde', color='tab:orange', linestyle='--',
#             legend=False, linewidth=1, fig=fig, ax=ax, label='Case3')
# ax.legend()
# ax.set_xlabel('CPS1')
# outscp.plot(y='prod', kind='hist', density=True, bins=30, color='tab:blue',
#             legend=False, fig=fig, ax=ax, label='Case1')
# outfcp.plot(y='prod', kind='hist', density=True, bins=30, color='tab:orange',
#             legend=False, fig=fig, ax=ax, label='Case2')

# %%
# --- generation cost ---
gtf = 0
gts = 0
gth = 0
for i in pgf.index:
    cf = ssd.cost.c2.values * np.power(pgf.loc[i].values, 2) \
        + ssd.cost.c1.values * pgf.loc[i].values \
        + ssd.cost.c1.values
    cs = ssd.cost.c2.values * np.power(pgs.loc[i].values, 2) \
        + ssd.cost.c1.values * pgs.loc[i].values \
        + ssd.cost.c1.values
    ch = ssd.cost.c2.values * np.power(pgh.loc[i].values, 2) \
        + ssd.cost.c1.values * pgh.loc[i].values \
        + ssd.cost.c1.values
    gtf += np.sum(cf)
    gts += np.sum(cs)
    gth += np.sum(ch)

# --- SFR mileage cost ---
ftf = 0
fts = 0
fth = 0
for i in agcf.columns:
    cf = ssd.cost.c1.abs().values * agcf[i].values
    cs = ssd.cost.c1.abs().values * agcs[i].values
    ch = ssd.cost.c1.abs().values * agch[i].values
    ftf += np.sum(cf)
    fts += np.sum(cs)
    fth += np.sum(ch)

print(f"Total Mile: Case3={np.round(agcf.sum().sum(), 2)}, Case2={np.round(agch.sum().sum(), 2)}, Case1={np.round(agcs.sum().sum(), 2)}")
print(f"EV AGC Mile: case3: {agcf.loc[9].sum()}, case2: {agch.loc[9].sum()}, case1: {agcs.loc[9].sum()}")
print(f"Total cost: Case3={np.round(gtf+ftf, 2)}, Case2={np.round(gth+fth, 2)}, Case1={np.round(gts+fts, 2)}")

# %%
plt.style.use('ieee')
fig, ax = plt.subplots(1, 3, figsize=(18, 4))
plt.subplots_adjust(left=None, bottom=None, right=None,
                    top=None, wspace=0.18, hspace=None)
# ACE
outs.plot(x='Time', y='ACE', ax=ax[0], fig=fig, label='Case1', linestyle='-', color='tab:blue')
outh.plot(x='Time', y='ACE', ax=ax[0], fig=fig, label='Case2', linestyle='-', color='tab:green')
outf.plot(x='Time', y='ACE', ax=ax[0], fig=fig, label='Case3', linestyle='--', color='tab:orange')
# COI freq.
outs.plot(x='Time', y='freq', ax=ax[1], fig=fig, label='Case1', linestyle='-', color='tab:blue')
outh.plot(x='Time', y='freq', ax=ax[1], fig=fig, label='Case2', linestyle='-', color='tab:green')
outf.plot(x='Time', y='freq', ax=ax[1], fig=fig, label='Case3', linestyle='--', color='tab:orange')
# COI std.
outs.plot(x='Time', y='fd', kind='hist', density=True, bins=30, color='tab:blue', alpha=1,
          legend=False, linewidth=1, fig=fig, ax=ax[2], label='Case1')
outh.plot(x='Time', y='fd', kind='hist', density=True, bins=30, color='tab:green', alpha=0.9,
          legend=False, linewidth=1, fig=fig, ax=ax[2], label='Case1')
outf.plot(x='Time', y='fd', kind='hist', density=True, bins=30, color='tab:orange', alpha=0.8,
          legend=False, linewidth=1, fig=fig, ax=ax[2], label='Case2')
# outs.plot(x='Time', y='fd', kind='kde', color='tab:blue',
#           legend=False, fig=fig, ax=ax[2], label='Case1')
# outf.plot(x='Time', y='fd', kind='kde', color='tab:orange',
#           legend=False, fig=fig, ax=ax[2], label='Case2')

ax[0].set_xlim([0, 3600])
ax[1].set_xlim([0, 3600])
ax[0].set_xlabel('Time [s]')
ax[1].set_xlabel('Time [s]')
ax[0].set_ylabel('ACE [MW]')
ax[1].set_ylabel('Freq. [Hz]')
ax[2].set_xlabel('Freq. Deviation [Hz]')
ax[2].set_ylabel('Density')
ax[2].legend()

print(f"Freq. D.: case1={outs['fd'].std()}, case2={outh['fd'].std()}, case3={outf['fd'].std()}")
print(f"ACE D.: case1={outs['ACE'].std()}, case2={outh['ACE'].std()}, case3={outf['ACE'].std()}")

# %% [markdown]
# No SFR, if soc >= socd
# SFR, soc < socd
# incldue all EVs,
# delayed_time = (socd - soc) * Q / Pc / nc
#
# total_charging_time (soc_init + soc_gap -> scod)

# %%
# evif[['soc0', 'socf', 'socd', 'socgap', 'Q', 'Pc', 'dt', 'nc']]

# %%
import matplotlib.font_manager

# %%
plt.style.use('ieee')
fig, ax = plt.subplots(1, 3, figsize=(18, 4))
plt.subplots_adjust(left=None, bottom=None, right=None,
                    top=None, wspace=0.18, hspace=None)

ax[2].plot(3600*(np.array(evs.time)-18), evs.Prc, label='Case1 EV AGC response', linestyle='-', color='tab:blue')
ax[2].plot(3600*(np.array(evs.time)-18), evh.Prc, label='Case2 EV AGC response', linestyle='-', color='tab:green')
ax[2].plot(3600*(np.array(evs.time)-18), evf.Prc, label='Case3 EV AGC response', linestyle='-', color='tab:orange')
ax[2].plot(3600*(np.array(evs.time)-18), evs.Pt, label='Case1 EV total output', linestyle='--', color='tab:blue')
ax[2].plot(3600*(np.array(evs.time)-18), evh.Pt, label='Case2 EV total output', linestyle='--', color='tab:green')
ax[2].plot(3600*(np.array(evs.time)-18), evf.Pt, label='Case3 EV total output', linestyle='--', color='tab:orange')
ax[2].legend()
ax[2].set_xlim([0, 3600])
ax[2].set_xlabel('Time [s]')
ax[2].set_ylabel('EV output power [MW]')

sfrs.plot(x='time', y='ace', ax=ax[0], fig=fig, label='Case1', linestyle='-', color='tab:blue')
sfrh.plot(x='time', y='ace', ax=ax[0], fig=fig, label='Case2', linestyle='-', color='tab:green')
sfrf.plot(x='time', y='ace', ax=ax[0], fig=fig, label='Case3', linestyle='-', color='tab:orange')
sfrs.plot(x='time', y='up', ax=ax[0], fig=fig, label='RegUp capacity', linestyle='--', color='black')
sfrs.plot(x='time', y='dn', ax=ax[0], fig=fig, label='RegDn capacity', linestyle='--', color='black')
ax[0].set_xlim([0, 3600])
ax[0].set_xlabel('Time [s]')
ax[0].set_ylabel('Total AGC signal [MW]')

outs.plot(x='Time', y='paux9', ax=ax[1], fig=fig, label='Case1', linestyle='-', color='tab:blue')
outh.plot(x='Time', y='paux9', ax=ax[1], fig=fig, label='Case2', linestyle='-', color='tab:green')
outf.plot(x='Time', y='paux9', ax=ax[1], fig=fig, label='Case3', linestyle='-', color='tab:orange')
ax[1].set_xlim([0, 3600])
ax[1].set_xlabel('Time [s]')
ax[1].set_ylabel('G3 AGC response [MW]')

# %%
plt.style.use('ieee')

bu_df = pd.read_csv('cosim_18_S_bu.csv')
bd_df = pd.read_csv('cosim_18_S_bd.csv')

color = ['tab:blue', 'yellow', 'tab:green',
         'tab:red', 'tab:purple', 'tab:brown',
         'tab:pink', 'tab:gray', 'tab:olive', 'tab:cyan', 'tab:orange']

figs, axes = plt.subplots(1, 2, figsize=(10.5, 3))
plt.subplots_adjust(left=None, bottom=None, right=None,
                    top=None, wspace=0.38, hspace=None)
new_cols = ['PV_1', 'PV_2', 'PV_3', 'PV_4', 'PV_5', 'PV_6',
            'PV_7', 'PV_8', 'PV_9', 'Slack_10', 'PV_10']
bu_df[new_cols].plot.bar(stacked=True, ax=axes[0], legend=False, color=color)
bd_df[new_cols].plot.bar(stacked=True, ax=axes[1], legend=False, color=color)

for ax in axes:
    ax.tick_params(axis='x', labelrotation = 0)
    ax.set_ylim([0, 1])
    ax.set_yticklabels([f'{np.round(i*100,0)}%' for i in np.arange(0, 1.1, 0.2)])
    ax.set_xticklabels([i for i in range(1,13,1)])
    ax.set_xlabel('RTED interval')
axes[0].set_title('(a) Case 1: RegUp balancing factor')
axes[1].set_title('(b) Case 1: RegDn balancing factor')
lines_labels = [ax.get_legend_handles_labels() for ax in axes]
lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]
line_plot = lines[0:11]
line_plot.reverse()
label_g = ['G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9', 'G10', 'EV']
label_g.reverse()
figs.legend(line_plot, label_g, loc='center')

# %%
plt.style.use('ieee')

bu_df = pd.read_csv('cosim_18_H_bu.csv')
bd_df = pd.read_csv('cosim_18_H_bd.csv')

color = ['tab:blue', 'yellow', 'tab:green',
         'tab:red', 'tab:purple', 'tab:brown',
         'tab:pink', 'tab:gray', 'tab:olive', 'tab:cyan', 'tab:orange']

figs, axes = plt.subplots(1, 2, figsize=(10.5, 3))
plt.subplots_adjust(left=None, bottom=None, right=None,
                    top=None, wspace=0.38, hspace=None)
new_cols = ['PV_1', 'PV_2', 'PV_3', 'PV_4', 'PV_5', 'PV_6',
            'PV_7', 'PV_8', 'PV_9', 'Slack_10', 'PV_10']
bu_df[new_cols].plot.bar(stacked=True, ax=axes[0], legend=False, color=color)
bd_df[new_cols].plot.bar(stacked=True, ax=axes[1], legend=False, color=color)

for ax in axes:
    ax.tick_params(axis='x', labelrotation = 0)
    ax.set_ylim([0, 1])
    ax.set_yticklabels([f'{np.round(i*100,0)}%' for i in np.arange(0, 1.1, 0.2)])
    ax.set_xticklabels([i for i in range(1,13,1)])
    ax.set_xlabel('RTED interval')
axes[0].set_title('(c) Case 2: RegUp balancing factor')
axes[1].set_title('(d) Case 2: RegDn balancing factor')
lines_labels = [ax.get_legend_handles_labels() for ax in axes]
lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]
line_plot = lines[0:11]
line_plot.reverse()
label_g = ['G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9', 'G10', 'EV']
label_g.reverse()
figs.legend(line_plot, label_g, loc='center')

# %%
plt.style.use('ieee')

bu_df = pd.read_csv('cosim_18_F_bu.csv')
bd_df = pd.read_csv('cosim_18_F_bd.csv')

color = ['tab:blue', 'yellow', 'tab:green',
         'tab:red', 'tab:purple', 'tab:brown',
         'tab:pink', 'tab:gray', 'tab:olive', 'tab:cyan', 'tab:orange']

figs, axes = plt.subplots(1, 2, figsize=(10.5, 3))
plt.subplots_adjust(left=None, bottom=None, right=None,
                    top=None, wspace=0.38, hspace=None)
new_cols = ['PV_1', 'PV_2', 'PV_3', 'PV_4', 'PV_5', 'PV_6',
            'PV_7', 'PV_8', 'PV_9', 'Slack_10', 'PV_10']
bu_df[new_cols].plot.bar(stacked=True, ax=axes[0], legend=False, color=color)
bd_df[new_cols].plot.bar(stacked=True, ax=axes[1], legend=False, color=color)

for ax in axes:
    ax.tick_params(axis='x', labelrotation = 0)
    ax.set_ylim([0, 1])
    ax.set_yticklabels([f'{np.round(i*100,0)}%' for i in np.arange(0, 1.1, 0.2)])
    ax.set_xticklabels([i for i in range(1,13,1)])
    ax.set_xlabel('RTED interval')
axes[0].set_title('(c) Case 3: RegUp balancing factor')
axes[1].set_title('(d) Case 3: RegDn balancing factor')
lines_labels = [ax.get_legend_handles_labels() for ax in axes]
lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]
line_plot = lines[0:11]
line_plot.reverse()
label_g = ['G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9', 'G10', 'EV']
label_g.reverse()
figs.legend(line_plot, label_g, loc='center')
